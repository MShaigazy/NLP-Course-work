# %% [markdown]
# # Part 1 News articles classification

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
                        
from sklearn.externals import joblib
import pickle
import logging
import warnings 
from time import time 
import pandas as pd
import numpy as np
from collections import Counter
import time
import string
import re
from os import listdir
from numpy import array
from numpy import asarray
from numpy import zeros

import gensim
from gensim.models import Word2Vec 


import nltk
from nltk.tokenize import sent_tokenize, word_tokenize 
from nltk.corpus import stopwords

import random
import spacy
import talos
from talos.utils import hidden_layers

from sklearn.pipeline import Pipeline



import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot



from sklearn  import preprocessing
from sklearn.model_selection   import cross_val_score, GridSearchCV, cross_validate, RandomizedSearchCV
from sklearn.metrics           import accuracy_score, confusion_matrix, classification_report
from sklearn.preprocessing     import LabelEncoder
# Out:
# /Users/shaigazy/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# Using TensorFlow backend.

# %% [markdown]
# # Datasets exploring

# %% [markdown]
# Datasets loading and overview the first rows of the data

# %%
train_data=pd.read_csv('train.csv', header=None, na_values=None, names = ['label', 'article_title', 'article_text'])
test_data=pd.read_csv('test.csv', header=None, na_values=None, names = ['label', 'article_title', 'article_text'])

# %%
train_data.head(5)
# Out:
#    label                                      article_title  \
# 0      2            Wizards Guard Blake Out 10-12 Week (AP)
# 1      4              Brief: HP acquires Synstar for \$293M
# 2      3  US Airways #39; pilots vote for 18 salary redu...
# 3      4                    Radiation risks 'need updating'
# 4      1       President's fate is on the line in Venezuela
#
#                                         article_text
# 0  AP - Washington Wizards point guard Steve Blak...
# 1  In a move designed to help it better compete i...
# 2  US Airways #39; pilots voted to approve a new ...
# 3  A UK panel examining radiation risks says offi...
# 4  CARACAS -- Partisans on both sides are calling...

# %%
test_data.head(5)
# Out:
#    label                                      article_title  \
# 0      3                    Qwest: The end of the beginning
# 1      1    Sadr Militiamen Still in Control of Iraq Shrine
# 2      4                 Google Unveils Scholar Search Tool
# 3      2                        Titans OT Munoz has surgery
# 4      4  When outsourcing, don't forget security, exper...
#
#                                         article_text
# 0  Thursday #39;s agreement between Qwest Communi...
# 1   NAJAF, Iraq (Reuters) - Rebel Shi'ite fighter...
# 2  JACKSONVILLE, FL -- The online search engine l...
# 3  Knoxville, TN (Sports Network) - Tennessee Tit...
# 4  When outsourcing IT operations offshore, compa...

# %% [markdown]
# Checking for missing and zero values

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
# label            40000 non-null int64
# article_title    40000 non-null object
# article_text     40000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 937.6+ KB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 3 columns):
# label            4000 non-null int64
# article_title    4000 non-null object
# article_text     4000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 93.8+ KB

# %%
train_data.isnull().values.any()
# Out:
# False

# %%
test_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# Datasets contain no zero and missing values

# %% [markdown]
# Assigning appropriate column names and label mapping to the news topics

# %%
#Defining target variable
y_train = train_data['label']
y_test = test_data['label']

# %% [markdown]
# Mapping label numbers to the news topic category

# %%
train_data['category_name']=train_data['label'].map({1:'world', 2:'sports',3:'business', 4:'sci/tech' })
test_data['category_name']=test_data['label'].map({1:'world', 2:'sports',3:'business', 4:'sci/tech' })

# %% [markdown]
# Merging the news title and text columns into one to obtain more comprehensive information

# %%
train_data['full_text'] = train_data['article_title'] + " " + train_data['article_text']
test_data['full_text'] = test_data['article_title'] + " " + test_data['article_text']

# %%
train_data.head(5)
# Out:
#    label                                      article_title  \
# 0      2            Wizards Guard Blake Out 10-12 Week (AP)
# 1      4              Brief: HP acquires Synstar for \$293M
# 2      3  US Airways #39; pilots vote for 18 salary redu...
# 3      4                    Radiation risks 'need updating'
# 4      1       President's fate is on the line in Venezuela
#
#                                         article_text category_name  \
# 0  AP - Washington Wizards point guard Steve Blak...        sports
# 1  In a move designed to help it better compete i...      sci/tech
# 2  US Airways #39; pilots voted to approve a new ...      business
# 3  A UK panel examining radiation risks says offi...      sci/tech
# 4  CARACAS -- Partisans on both sides are calling...         world
#
#                                            full_text
# 0  Wizards Guard Blake Out 10-12 Week (AP) AP - W...
# 1  Brief: HP acquires Synstar for \$293M In a mov...
# 2  US Airways #39; pilots vote for 18 salary redu...
# 3  Radiation risks 'need updating' A UK panel exa...
# 4  President's fate is on the line in Venezuela C...

# %% [markdown]
# # Exploring the Training Dataset

# %% [markdown]
# Printing and visualisation the frequency distribution of the class attributes

# %%
distr = train_data['category_name'].value_counts()
print(distr)
plt.figure(figsize=(10,4))
distr.plot(kind='bar')
# Out:
# business    10000
# sci/tech    10000
# world       10000
# sports      10000
# Name: category_name, dtype: int64

# %% [markdown]
# The classes are very well balanced

# %% [markdown]
# Word counting

# %%
#New column with word number
train_data['word_number'] = train_data['full_text'].apply(lambda x: len(x.split(' ')))

#Number of unique words
uniq_raw = []
for sent in train_data['full_text']:
    for word in (sent.split(' ')):
        uniq_raw.append(word)

print('Total number of words in the training dataset:', train_data['word_number'].sum(),'\n')
print('Total number of unique words in the training dataset:', len(set(uniq_raw)),'\n')
print('Average number of words in the training dataset:', train_data['word_number'].mean())
# Out:
# Total number of words in the training dataset: 1537305
#
# Total number of unique words in the training dataset: 104855
#
# Average number of words in the training dataset: 38.432625

# %%
train_data['word_number'].describe()
# Out:
# count    40000.000000
# mean        38.432625
# std         10.529942
# min          9.000000
# 25%         32.000000
# 50%         38.000000
# 75%         44.000000
# max        178.000000
# Name: word_number, dtype: float64

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=train_data, x='category_name', y='word_number', width=.5);

# %% [markdown]
# Document length

# %%
train_data['length'] = train_data['full_text'].str.len()
plt.figure(figsize=(15,6))
sns.boxplot(data=train_data, x='category_name', y='length', width=.5)

# %%
train_data['length'].describe()
# Out:
# count    40000.000000
# mean       236.633875
# std         66.501613
# min        100.000000
# 25%        196.000000
# 50%        232.000000
# 75%        266.000000
# max       1006.000000
# Name: length, dtype: float64

# %%
train_data.head(5)
# Out:
#    label                                      article_title  \
# 0      2            Wizards Guard Blake Out 10-12 Week (AP)
# 1      4              Brief: HP acquires Synstar for \$293M
# 2      3  US Airways #39; pilots vote for 18 salary redu...
# 3      4                    Radiation risks 'need updating'
# 4      1       President's fate is on the line in Venezuela
#
#                                         article_text category_name  \
# 0  AP - Washington Wizards point guard Steve Blak...        sports
# 1  In a move designed to help it better compete i...      sci/tech
# 2  US Airways #39; pilots voted to approve a new ...      business
# 3  A UK panel examining radiation risks says offi...      sci/tech
# 4  CARACAS -- Partisans on both sides are calling...         world
#
#                                            full_text  word_number  length
# 0  Wizards Guard Blake Out 10-12 Week (AP) AP - W...           31     170
# 1  Brief: HP acquires Synstar for \$293M In a mov...           32     201
# 2  US Airways #39; pilots vote for 18 salary redu...           38     217
# 3  Radiation risks 'need updating' A UK panel exa...           28     166
# 4  President's fate is on the line in Venezuela C...           54     340

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# The data pre-processing stage of the training dataset includes lowercase each word and remove punctuations, non-alphabetical symbols, stopwords and one-character words.

# %% [markdown]
# Function to delete URL objects

# %%
def remove_urls (txt):
    txt = re.sub(r'http\S+', '', txt)
    txt = re.sub(r'target\S+', '', txt)
    txt = re.sub(r'qtype\S+', '', txt)
    txt = re.sub(r'qcat\S+', '', txt)
    return(txt)

# %% [markdown]
# Function to clean a text

# %%
def clean_doc(doc):
    tokens = doc.split()
    tokens = [word.lower() for word in tokens]
    tokens = [remove_urls(word) for word in tokens]
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    tokens = [re_punc.sub('', w) for w in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    tokens = [word for word in tokens if len(word) > 1]

    return " ".join(tokens)

# %% [markdown]
# After applying clean_doc function, cleaned text stored in the clean_data list. The total number of words significantly decrease from 1,537,305 to 982,083

# %%
#document loading function
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text.split('\n')

# %%
#loading file
#clean_data = load_doc('clean_data.txt')

# %%
clean_data = []
for i in range(0, len(train_data)):
    clean_t=clean_doc(train_data['full_text'][i])
    clean_data.append(clean_t)

uniq_clean =[]
for sent in clean_data:
    for word in (sent.split(' ')):
        uniq_clean.append(word)

    
print('The number of words before cleaning:', train_data['word_number'].sum(),'\n')    
print('The number of words after cleaning:', sum([len(i.split()) for i in clean_data]),'\n')
print('The number of unique words after cleaning:', len(set(uniq_clean)))
# Out:
# The number of words before cleaning: 1537305
#
# The number of words after cleaning: 982083
#
# The number of unique words after cleaning: 53202

# %%
# document save function
def save_doc(lines, filename):
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

# %%
#saving file
#filename = 'clean_data.txt'
#save_doc(clean_data, filename)

# %% [markdown]
# The code below allows to compare how particular row from the text was cleaned

# %%
print('\033[1m'+'Text before cleaning:'+'\033[0m' +'\n', train_data['full_text'][13229], '\n')
print('\033[1m'+'Text after cleaning:'+'\033[0m'+'\n', clean_data[13229])
# Out:
# Text before cleaning:
#  Chrysler to Build Sedans in Austria  DETROIT (Reuters) - DaimlerChrysler AG's &lt;A HREF="http://www.investor.reuters.com/FullQuote.aspx?ticker=DCX.N target=/stocks/quickinfo/fullquote"&gt;DCX.N&lt;/A&gt; &lt;A HREF="http://www.investor.reuters.com/FullQuote.aspx?ticker=DCXGn.DE target=/stocks/quickinfo/fullquote"&gt;DCXGn.DE&lt;/A&gt;  Chrysler division on Wednesday said it will start building its  hot-selling 300C sedan at a plant operated by Magna Steyr in  Graz, Austria, early next year.
#
# Text after cleaning:
#  chrysler build sedans austria detroit reuters daimlerchrysler ags lta href lta href chrysler division wednesday said start building hotselling sedan plant operated magna steyr graz austria early next year

# %% [markdown]
# Cleaning test dataset with defined earlier clean_doc text cleaning function

# %%
#loading file
#clean_test_data = load_doc('clean_test_data.txt')

# %%
clean_test_data = []
for i in range(0, len(test_data)):
    clean_t=clean_doc(test_data['full_text'][i])
    clean_test_data.append(clean_t)

# %%
#saving file
#filename = 'clean_test_data.txt'
#save_doc(clean_test_data, filename)

# %% [markdown]
# #  Text representation with TF-IDF

# %% [markdown]
# The next step is a feature engineering process, where text representation techniques such as TF-IDF and Word2vec applied to transform text data into a matrix of token counts and word embeddings.

# %% [markdown]
# Term Frequency-Inverse Document Frequency (TF-IDF) is a bag-of-words technique, which converts word sequences into numerical representation – vectors.

# %% [markdown]
# Applying TfidfVectorizer() function with default arguments (ngram_range = (1,1), min_df =1, max_df = 1, max_features = None) on the training dataset provide with the following results:

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(clean_data)

# %%
print('Vocabulary size:', len(vectorizer.vocabulary_))
print('Vocabulary content:\n {}'.format(vectorizer.vocabulary_))
# Out:
# Vocabulary size: 53202
# Vocabulary content:
#  {'wizards': 52271, 'guard': 19561, 'blake': 5070, 'week': 51560, 'ap': 2285, 'washington': 51305, 'point': 34934, 'steve': 44895, 'miss': 29130, 'first': 16574, 'month': 29483, 'season': 41504, 'injuring': 22655, 'ankle': 1999, 'pickup': 34433, 'game': 18129, 'brief': 5978, 'hp': 21454, 'acquires': 363, 'synstar': 46188, 'move': 29762, 'designed': 11915, 'help': 20552, 'better': 4684, 'compete': 9171, 'europe': 14977, 'hewlettpackard': 20694, 'said': 40650, 'acquired': 359, 'plc': 34787, 'ukbased': 49290, 'technology': 46668, 'services': 41979, 'firm': 16561, 'million': 28900, 'us': 50089, 'airways': 1030, 'pilots': 34508, 'vote': 50991, 'salary': 40710, 'reduction': 38549, 'voted': 50993, 'approve': 2423, 'new': 30794, 'labor': 25207, 'agreement': 887, 'yesterday': 52880, 'reduce': 38544, 'salaries': 40709, 'percent': 34019, 'save': 41021, 'airline': 1003, 'year': 52818, 'radiation': 37776, 'risks': 39880, 'need': 30596, 'updating': 49976, 'uk': 49288, 'panel': 33355, 'examining': 15149, 'says': 41058, 'official': 31932, 'estimates': 14892, 'dangers': 11007, 'health': 20380, 'may': 27977, 'wide': 51926, 'mark': 27645, 'substantially': 45474, 'presidents': 35643, 'fate': 15982, 'line': 26195, 'venezuela': 50497, 'caracas': 7068, 'partisans': 33545, 'sides': 42724, 'calling': 6815, 'polarized': 34970, 'important': 22096, 'election': 14022, 'venezuelas': 50500, 'history': 20972, 'presidential': 35638, 'recall': 38307, 'referendum': 38597, 'today': 47935, 'determine': 12001, 'course': 10193, 'democracy': 11688, 'could': 10105, 'buffet': 6309, 'world': 52427, 'oil': 32085, 'prices': 35738, 'campaigns': 6879, 'also': 1462, 'utterly': 50267, 'convinced': 9825, 'win': 52070, 'australia': 3280, 'virgin': 50803, 'blue': 5248, 'increases': 22275, 'fuel': 17864, 'surcharge': 45820, 'hikes': 20873, 'sydney': 46123, 'australian': 3285, 'announced': 2028, 'sharply': 42261, 'increasing': 22276, 'imposed': 22106, 'compensate': 9166, 'rising': 39870, 'chinese': 8069, 'sub': 45391, 'detected': 11984, 'japan': 23757, 'waters': 51382, 'japanese': 23759, 'government': 19103, 'officials': 31938, 'thursday': 47645, 'confirmed': 9443, 'navy': 30454, 'submarine': 45417, 'intrusively': 23143, 'entered': 14585, 'day': 11164, 'earlier': 13597, 'discovered': 12452, 'early': 13600, 'wednesday': 51534, 'wartorn': 51289, 'wonderland': 52340, 'honduras': 21215, 'central': 7550, 'american': 1607, 'countries': 10161, 'embroiled': 14227, 'war': 51202, 'become': 4298, 'hot': 21358, 'markets': 27681, 'affordable': 721, 'beachfront': 4212, 'property': 36094, 'celebrates': 7477, 'suzuki': 45933, 'breaking': 5888, 'record': 38413, 'baseball': 4026, 'fans': 15867, 'across': 387, 'saturday': 40984, 'honored': 21235, 'ichiro': 21786, 'seattle': 41538, 'mariners': 27630, 'player': 34752, 'broke': 6108, 'major': 27299, 'league': 25663, 'hits': 20997, 'stage': 44537, 'one': 32259, 'else': 14153, 'compares': 9144, 'els': 14152, 'two': 49108, 'years': 52843, 'ago': 866, 'ernie': 14781, 'explained': 15458, 'possible': 35221, 'tiger': 47716, 'woods': 52360, 'overtaken': 33067, 'rankings': 37989, 'time': 47755, 'south': 43925, 'african': 750, 'paper': 33392, 'sirius': 42984, 'pricey': 35743, 'despite': 11949, 'howard': 21435, 'stern': 44884, 'shares': 42224, 'satellite': 40964, 'radio': 37783, 'inc': 22186, 'sirio': 42983, 'quote': 36984, 'profile': 35953, 'research': 39226, 'look': 26608, 'company': 9119, 'fiveyear': 16706, 'pact': 33189, 'shock': 42449, 'jock': 24030, 'air': 968, 'program': 35982, 'building': 6329, 'code': 8723, 'back': 3575, 'seat': 41532, 'insurance': 22850, 'claim': 8342, 'projections': 36016, 'hurricane': 21609, 'charley': 7796, 'climbing': 8495, 'billion': 4866, 'industry': 22444, 'believe': 4444, 'standards': 44603, 'uniform': 49678, 'florida': 16933, 'update': 49970, 'population': 35121, 'strain': 45124, 'finances': 16445, 'aging': 857, 'public': 36318, 'hurt': 21624, 'economy': 13763, 'without': 52246, 'swift': 46044, 'fixes': 16719, 'social': 43632, ...

# %% [markdown]
# Next, changing min_df and max_df parameters revealed that only the four most frequent terms (new, reuters, said, us) appear in 10% of the corpus, and therefore these parameters can remain the default values.

# %%
vectorizer = TfidfVectorizer(min_df=0.1)
X = vectorizer.fit_transform(clean_data)

# %%
print('Vocabulary size:', len(vectorizer.vocabulary_))
vectorizer.get_feature_names()
# Out:
# Vocabulary size: 4
# ['new', 'reuter', 'said', 'us']

# %%
vectorizer = TfidfVectorizer(max_df=0.1)
X = vectorizer.fit_transform(clean_data)

# %%
print('Vocabulary size:', len(vectorizer.vocabulary_))
vectorizer.get_feature_names()
# Out:
# Vocabulary size: 53202
# ['aa',
#  'aaa',
#  'aachen',
#  'aal',
#  'aalborg',
#  'aap',
#  'aapl',
#  'aaplnas',
#  'aaplnasdaq',
#  'aaplo',
#  'aarde',
#  'aaron',
#  'aarp',
#  'aarshiad',
#  'aasketball',
#  'aau',
#  'ab',
#  'ababa',
#  'abagnale',
#  'abandon',
#  'abandoned',
#  'abandoning',
#  'abandonment',
#  'abandons',
#  'abarrel',
#  'abate',
#  'abated',
#  'abb',
#  'abbas',
#  'abbass',
#  'abbey',
#  'abbn',
#  'abbnvx',
#  'abbott',
#  'abboud',
#  'abbreviated',
#  'abby',
#  'abc',
#  'abcn',
#  'abcnews',
#  'abcs',
#  'abctv',
#  'abd',
#  'abdallah',
#  'abdel',
#  'abdellah',
#  'abdelraham',
#  'abdicate',
#  'abdicated',
#  'abdicates',
#  'abdicating',
#  'abdication',
#  'abdomen',
#  'abdoulaye',
#  'abduct',
#  'abducted',
#  'abductees',
#  'abducting',
#  'abduction',
#  'abductions',
#  'abductors',
#  'abdul',
#  'abdullah',
#  'abdullahi',
#  'abdur',
#  'abdurrahim',
#  'aber',
#  'abercrombie',
#  'aberdeen',
#  'aberdeenshire',
#  'abhorrent',
#  'abi',
#  'abia',
#  'abide',
#  'abiding',
#  'abidjan',
#  'abig',
#  'abigail',
#  'abijan',
#  'abilities',
#  'ability',
#  'abimael',
#  'abiomed',
#  'abject',
#  'abjure',
#  'abkhazia',
#  'ablaze',
#  'able',
#  'abn',
#  'abnormal',
#  'aboard',
#  'abolish',
#  'abolishing',
#  'abolition',
#  'aboriginal',
#  'aboriginalpopulation',
#  'aborigines',
#  'abort',
#  'aborted',
#  'abortion',
#  'abortionrights',
#  'abortions',
#  'abortive',
#  'aboud',
#  'aboul',
#  'abound',
#  'abounds',
#  'aboutcheneys',
#  'aboutexport',
#  'aboutface',
#  'abouthis',
#  'aboutits',
#  'aboutprofit',
#  'aboutsupply',
#  'aboveaverage',
#  'abovedjiboutis',
#  'abovethe',
#  'abraham',
#  'abramov',
#  'abramovich',
#  'abramovichs',
#  'abrams',
#  'abrasive',
#  'abreast',
#  'abrief',
#  'abroad',
#  'abrupt',
#  'abruptly',
#  'abs',
#  'absa',
#  'absalon',
#  'absence',
#  'absences',
#  'absent',
#  'absentee',
#  'absenteeism',
#  'absentees',
#  'absentia',
#  'absolute',
#  'absolutely',
#  'absolved',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'absorbs',
#  'abstain',
#  'abstentions',
#  'abstinence',
#  'abstract',
#  'abstracts',
#  'absurd',
#  'abtahi',
#  'abtnys',
#  'abu',
#  'abuducted',
#  'abuja',
#  'abukar',
#  'abul',
#  'abullah',
#  'abumusab',
#  'abundance',
#  'abundant',
#  'abureaucratic',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusescommitted',
#  'abusesltpgt',
#  'abusing',
#  'abusingprisoners',
#  'abusive',
#  'abusy',
#  'abuzz',
#  'abysmal',
#  'abyss',
#  'ac',
#  'acacia',
#  'academia',
#  'academic',
#  'academically',
#  'academics',
#  'academy',
#  'acar',
#  'acase',
#  'acastillo',
#  'acc',
#  'accbig',
#  'accc',
#  'acceded',
#  'accel',
#  'accelerate',
#  'accelerated',
#  'accelerates',
#  'accelerating',
#  'acceleration',
#  'accelerator',
#  'accelerators',
#  'accent',
#  'accenture',
#  'accept',
#  'acceptability',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'acceptedking',
#  'accepting',
#  'accepts',
#  'acceptwhat',
#  'access',
#  'accessanywhere',
#  'accessdenied',
#  'accessed',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accession',
#  'accessit',
#  'accessories',
#  'accessory',
#  'accessprice',
#  'accesss',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidents',
#  'acclaim',
#  'acclaimed',
#  'acclaimis',
#  'acclimated',
#  'acclimatization',
#  'acclimatize',
#  'accoding',
#  'accolade',
#  'accolades',
#  'accommodate',
#  'accommodating',
#  'accommodations',
#  'accommodative',
#  'accompanied',
#  'accompanies',
#  'accompany',
#  'accompanying',
#  'accompli',
#  'accomplice',
#  'accomplish',
#  'accomplished',
#  'accomplishing',
#  'accomplishment',
#  'accomplishments',
#  'accoona',
#  'accoonacom',
#  'accor',
#  'accord',
#  'accordance',
#  'according',
#  'accordingto',
#  'accords',
#  'accosted',
#  'account',
#  'accountability',
#  'accountable',
#  'accountancy',
#  'accountant',
#  'accountants',
#  'accounted',
#  'accounting',
#  'accountingirregularities',
#  'accountingprobe',
#  'accountingrules',
#  'accountingshares',
#  'accountingstandards',
#  'accountingthe',
#  'accountingto',
#  'accountingwebcom',
#  'accounts',
#  'accredit',
#  'accreditato',
#  'accredited',
#  'accredo',
#  'accrue',
#  'accs',
#  'accumulate',
#  'accumulated',
#  'accumulating',
#  'accumulation',
#  'accumulative',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accused',
#  'accusedat',
#  'accuser',
#  'accusers',
#  'accuses',
#  'accusing',
#  'accustomed',
#  'accutane',
#  'acdo',
#  'ace',
#  'aced',
#  'aceh',
#  'acen',
#  'acer',
#  'aceremony',
#  'acers',
#  'aces',
#  'acetylcholine',
#  'achara',
#  'ache',
#  'achievable',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'achild',
#  'achille',
#  'achilles',
#  'achin',
#  'aching',
#  'achingly',
#  'acholesterolrich',
#  'acia',
#  'acid',
#  'acidic',
#  'acidity',
#  'acids',
#  'acis',
#  'ackermacosko',
#  'ackerman',
#  'acknowledge',
#  'acknowledged',
#  'acknowledges',
#  'acknowledging',
#  'acknowledgment',
#  'acl',
#  'aclassic',
#  'aclose',
#  'aclosed',
#  'aclothing',
#  'acn',
#  'acne',
#  'acnelike',
#  'acollector',
#  'acolytes',
#  'aconfrontational',
#  'acongressional',
#  'acorns',
#  'acoustic',
#  'acquaintances',
#  'acquainted',
#  'acquiert',
#  'acquiesce',
#  'acquiescence',
#  'acquire',
#  'acquired',
#  'acquiredambev',
#  'acquiremedicaldevice',
#  'acquirer',
#  'acquires',
#  'acquiring',
#  'acquisistion',
#  'acquisition',
#  'acquisitionof',
#  'acquisitionrelated',
#  'acquisitions',
#  'acquisitionsrelated',
#  'acquisitive',
#  'acquistion',
#  'acquits',
#  'acquittal',
#  'acquitted',
#  'acquitting',
#  'acres',
#  'acrimonious',
#  'acritics',
#  'acrobat',
#  'acrobatic',
#  'acrobatically',
#  'acrobatics',
#  'acronym',
#  'acronyms',
#  'acropolis',
#  'across',
#  'acrosshas',
#  'acrosstheboard',
#  'acs',
#  'act',
#  'actat',
#  'acted',
#  'acting',
#  'action',
#  'actionfilled',
#  'actionno',
#  'actionpacked',
#  'actions',
#  'activate',
#  'activated',
#  'activatein',
#  'activates',
#  'active',
#  'activeduty',
#  'activehome',
#  'actively',
#  'activematrix',
#  'actives',
#  'activesync',
#  'activision',
#  'activisions',
#  'activism',
#  'activist',
#  'activists',
#  'activistshareholders',
#  'activities',
#  'activitiesbut',
#  'activity',
#  'acto',
#  'acton',
#  'actonboxboro',
#  'actor',
#  'actors',
#  'actorturnedgovernor',
#  'actress',
#  'actresses',
#  'acts',
#  'actual',
#  'actually',
#  'actuators',
#  'acupuncture',
#  'acura',
#  'acusations',
#  'acusphere',
#  'acute',
#  'acutecare',
#  'ad',
#  'adage',
#  'adam',
#  'adamant',
#  'adams',
#  'adamsoshiomhole',
#  'adapt',
#  'adaptable',
#  'adaptec',
#  'adapted',
#  'adapter',
#  'adapters',
#  'adapting',
#  'adaptive',
#  'adaptor',
#  'adaptors',
#  'adapts',
#  'adatta',
#  'adaware',
#  'aday',
#  'adb',
#  'adbe',
#  'add',
#  'addai',
#  'added',
#  'addendum',
#  'addicks',
#  'addict',
#  'addicted',
#  'addiction',
#  'addictive',
#  'addicts',
#  'addin',
#  'adding',
#  'addins',
#  'addis',
#  'addition',
#  'additional',
#  'additions',
#  'additive',
#  'addled',
#  'addon',
#  'addons',
#  'address',
#  'addressed',
#  'addresses',
#  'addressing',
#  'adds',
#  'addsolar',
#  'adducted',
#  'adebayo',
#  'adecidedly',
#  'adecline',
#  'adelaide',
#  'adelaideborn',
#  'adelman',
#  'adelphia',
#  'adelphiacommunications',
#  'adept',
#  'adequacy',
#  'adequate',
#  'adequately',
#  'adevastating',
#  'adewale',
#  'adhd',
#  'adhering',
#  'adhocmitteilung',
#  'adi',
#  'adic',
#  'adidas',
#  'adieu',
#  'adifficult',
#  'adirect',
#  'adisumarno',
#  'adjacent',
#  'adjoining',
#  'adjourn',
#  'adjourned',
#  'adjourning',
#  'adjournment',
#  'adjunct',
#  'adjust',
#  'adjustablerate',
#  'adjusted',
#  'adjusters',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'adjusts',
#  'adler',
#  'admin',
#  'administration',
#  'administrations',
#  'administrationsaid',
#  'administrationsindustryfriendly',
#  'administrative',
#  'administrator',
#  'administrators',
#  'admins',
#  'admirably',
#  'admiration',
#  'admire',
#  'admired',
#  'admirers',
#  'admires',
#  'admirethe',
#  'admissible',
#  'admission',
#  'admissions',
#  'admit',
#  'admits',
#  'admitted',
#  'admitting',
#  'admonished',
#  'admonishes',
#  'adnan',
#  'ado',
#  'adobe',
#  'adobes',
#  'adolescence',
#  'adolescent',
#  'adolescents',
#  'adolf',
#  'adolph',
#  'adom',
#  'adopt',
#  'adopted',
#  'adoptees',
#  'adopters',
#  'adopting',
#  'adoption',
#  'adoptive',
#  'adopts',
#  'adored',
#  'adoring',
#  'adorned',
#  'adpowers',
#  'adreas',
#  'adrenaline',
#  'adrevenue',
#  'adriaen',
#  'adrian',
#  'adriana',
#  'adrianbeltre',
#  'adriano',
#  'adriatic',
#  'adrift',
#  'ads',
#  'adsense',
#  'adsensemany',
#  'adsometimes',
#  'adt',
#  'adtech',
#  'adtranz',
#  'adu',
#  'aduhas',
#  'adulation',
#  'adult',
#  'adultery',
#  'adulthood',
#  'adultonly',
#  'adults',
#  'adultstrength',
#  'aduser',
#  'adv',
#  'advance',
#  'advanced',
#  'advancedforce',
#  'advancedmicro',
#  'advancedphones',
#  'advancement',
#  'advancements',
#  'advancers',
#  'advances',
#  'advancing',
#  'advancis',
#  'advani',
#  'advanta',
#  'advantage',
#  'advantaged',
#  'advantages',
#  'advantest',
#  'advent',
#  'adventure',
#  'adventuregame',
#  'adventurer',
#  'adventurers',
#  'adventures',
#  'adventuresome',
#  'adventurous',
#  'advergames',
#  'adversary',
#  'adverse',
#  'adversely',
#  'adversity',
#  'advert',
#  'advertise',
#  'advertised',
#  'advertisement',
#  'advertisements',
#  'advertiser',
#  'advertisers',
#  'advertising',
#  'advice',
#  'advicefuck',
#  'advise',
#  'advised',
#  'adviser',
#  'advisers',
#  'advises',
#  'advising',
#  'advisor',
#  'advisories',
#  'advisors',
#  'advisory',
#  'advo',
#  'advocacy',
#  'advocate',
#  'advocated',
#  'advocatedby',
#  'advocates',
#  'adware',
#  'adwatch',
#  'adweekcom',
#  'adwords',
#  'adwordsaol',
#  'adwordsin',
#  'adwordsr',
#  'adwordsrealpagescom',
#  'adyesterday',
#  'aegean',
#  'aek',
#  'aer',
#  'aere',
#  'aerial',
#  'aeronautic',
#  'aeronautical',
#  'aeronautics',
#  'aeroplanes',
#  'aeros',
#  'aerosols',
#  'aerospace',
#  'aerospacetomedicalproducts',
#  'aest',
#  'aesthetic',
#  'aether',
#  'aetna',
#  'afa',
#  'afactory',
#  'afamiliar',
#  'afanasenkov',
#  'afar',
#  'afb',
#  'afc',
#  'afcom',
#  'afcs',
#  'afellow',
#  'affair',
#  'affairs',
#  'affect',
#  'affected',
#  'affecting',
#  'affection',
#  'affections',
#  'affects',
#  'affidavit',
#  'affiliate',
#  'affiliated',
#  'affiliates',
#  'affiliation',
#  'affinity',
#  'affirmed',
#  'affirming',
#  'affirms',
#  'affix',
#  'affixed',
#  'affleck',
#  'afflicting',
#  'afflictions',
#  'afflicts',
#  'affluent',
#  'afford',
#  'affordability',
#  'affordable',
#  'affronts',
#  'afganistan',
#  'afghan',
#  'afghanistan',
#  'afghanistanap',
#  'afghanistanltbrgtlike',
#  'afghanistanmay',
#  'afghanistans',
#  'afghanistanshistoric',
#  'afghans',
#  'afi',
#  'afield',
#  'afinding',
#  'afist',
#  'afl',
#  'aflcio',
#  'aflied',
#  'afloat',
#  'aflutter',
#  'afoot',
#  'aformer',
#  'afoul',
#  'afourth',
#  'afp',
#  'afpfile',
#  'afraid',
#  'africa',
#  'africabased',
#  'african',
#  'africanamericans',
#  'africanborn',
#  'africancountries',
#  'africanregistered',
#  'africans',
#  'africas',
#  'afrikaner',
#  'afrol',
#  'afrrica',
#  'aftab',
#  'aftera',
#  'aftercare',
#  'afterdeclaring',
#  'afterdemand',
#  'afterglow',
#  'afterhours',
#  'afterhurricane',
#  'afterit',
#  'aftermarket',
#  'aftermath',
#  'aftermathof',
#  'afternoon',
#  'afternoons',
#  'afterordering',
#  'afterschool',
#  'aftershock',
#  'aftershocks',
#  'aftershow',
#  'aftersummer',
#  'aftertax',
#  'afterthe',
#  'afterthursdays',
#  'aftertwo',
#  'afterward',
#  'afterwards',
#  'afterweatherrelated',
#  'afterwednesdays',
#  'afuel',
#  'afullblown',
#  'afullfledged',
#  'afx',
#  'afxeurope',
#  'afxuk',
#  'ag',
#  'aga',
#  'agadez',
#  'againasked',
#  'againstmicrosoft',
#  'againstseemingly',
#  'againstthe',
#  'againsttheodds',
#  'againstus',
#  'againstviruses',
#  'againt',
#  'againwhat',
#  'agallon',
#  'agame',
#  'agarwal',
#  'agassi',
#  'agassifederer',
#  'agate',
#  'age',
#  'aged',
#  'ageing',
#  'ageism',
#  'agence',
#  'agencia',
#  'agencies',
#  'agenciesreported',
#  'agenciessetting',
#  'agencourt',
#  'agency',
#  'agencycited',
#  'agencyreported',
#  'agencys',
#  'agenda',
#  'agendas',
#  'agent',
#  'agents',
#  'agentsseized',
#  'ageold',
#  'agepoll',
#  'agere',
#  'ages',
#  'agfagevaert',
#  'aggadan',
#  'aggies',
#  'aggravate',
#  'aggravated',
#  'aggravates',
#  'aggravating',
#  'aggregate',
#  'aggregating',
#  'aggregator',
#  'aggregators',
#  'aggression',
#  'aggressive',
#  'aggressively',
#  'aggressivelypricing',
#  'aggressor',
#  'aggressors',
#  'aghazade',
#  'agi',
#  'agianst',
#  'agiasoteli',
#  'agilysys',
#  'aging',
#  'agios',
#  'aglau',
#  'agli',
#  'aglobal',
#  'aglow',
#  'agm',
#  'agni',
#  'agniii',
#  'ago',
#  'agois',
#  'agonising',
#  'agonisingly',
#  'agonized',
#  'agonizes',
#  'agonizing',
#  'agonizingly',
#  'agony',
#  'agoos',
#  'agoscientists',
#  'agp',
#  'agra',
#  'agreat',
#  'agree',
#  'agreed',
#  'agreedlate',
#  'agreedtakeover',
#  'agreedto',
#  'agreeed',
#  'agreeing',
#  'agreement',
#  'agreementon',
#  'agreements',
#  'agrees',
#  'agressive',
#  'agribiz',
#  'agribusiness',
#  'agricole',
#  'agricultural',
#  'agriculture',
#  'agricultureminister',
#  'agronow',
#  'aground',
#  'agrowing',
#  'ags',
#  'agusti',
#  'agustin',
#  'agusto',
#  'agy',
#  'ah',
#  'ahalf',
#  'ahead',
#  'aheadltagtltbrgtsolaris',
#  'aheads',
#  'aheart',
#  'ahern',
#  'ahigh',
#  'ahigherthanexpected',
#  'ahighprofile',
#  'ahightech',
#  'ahispanic',
#  'ahl',
#  'ahloo',
#  'ahlyow',
#  'ahmad',
#  'ahman',
#  'ahmannltpgtltpgt',
#  'ahmanson',
#  'ahmed',
#  'ahn',
#  'ahold',
#  'aholiday',
#  'ahref',
#  'ahrq',
#  'ahsanul',
#  'ahydroelectric',
#  'ai',
#  'aicc',
#  'aid',
#  'aidan',
#  'aide',
#  'aided',
#  'aides',
#  'aidesdismissed',
#  'aidessaid',
#  'aideturnedfoe',
#  'aidforpeace',
#  'aiding',
#  'aids',
#  'aidshiv',
#  'aidto',
#  'aig',
#  'aigs',
#  'aikman',
#  'aiko',
#  'ailing',
#  'ailment',
#  'ailments',
#  'ails',
#  'ailsa',
#  'aim',
#  'aimbot',
#  'aimbots',
#  'aimed',
#  'aiming',
#  'aims',
#  'aimtc',
#  'ainge',
#  'ainslie',
#  'aint',
#  'aip',
#  'air',
#  'airasia',
#  'airbags',
#  'airball',
#  'airballs',
#  'airbase',
#  'airborne',
#  'airbreathing',
#  'airbus',
#  'airbusboeing',
#  'airbuses',
#  'airbuss',
#  'aircargo',
#  'airconditioned',
#  'aircraft',
#  'aircraftaid',
#  'aircraftbacked',
#  'airdrop',
#  'aired',
#  'aires',
#  'airespace',
#  'airexpress',
#  'airfare',
#  'airfares',
#  'airfield',
#  'airforce',
#  'airgate',
#  'airgo',
#  'airindia',
#  'airing',
#  'airintake',
#  'airless',
#  ...]

# %% [markdown]
# Sorting IDF scores provides with information about most and less frequent words in the corpus

# %%
features = np.array(vectorizer.get_feature_names())
sort_idf = np.argsort(vectorizer.idf_)
print('Features with lowest idf:', features[sort_idf[:3]]),'\n'
print('Features with highest idf:', features[sort_idf[-3:]])
# Out:
# Features with lowest idf: ['year' 'compani' 'ap']
# Features with highest idf: ['kach' 'kahnlehmann' 'zyman']

# %% [markdown]
# Finally, sorting TF-IDF scores provides with weighted relevance of the words

# %%
sort_tfidf = X.max(axis=0).toarray().ravel().argsort()

print('Features with lowest tfidf:',features[sort_tfidf[:3]], '\n')
print('Features with highest tfidf:', features[sort_tfidf[-3:]])
# Out:
# Features with lowest tfidf: ['backend' 'familyth' 'granular']
#
# Features with highest tfidf: ['dilithium' 'java' 'gigaset']

# %% [markdown]
# The next step is to train variuous machine learning algorithms with different numbers of ngram_range and max_features

# %% [markdown]
# # Training ML algorithms

# %% [markdown]
# The next step is to train machine learning algorithms such as Naïve Bayes, Linear SVM, Logistic Regression and Random Forest with different numbers of ngram_range (unigram, bigram, trigram) and max_features (7000, 15000) values.

# %%
#function to display full information of tables
pd.set_option('display.max_colwidth', 0)

# %% [markdown]
# The list of hyperparameters to tune

# %%
n_estimators = [10, 100, 200, 400]
max_features = ['auto', 'sqrt']
max_depth = [30,60,90, None]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
criterion = ['entropy', 'gini']



param = [{'vec__ngram_range': ((1, 1), (1, 2), (1,3)), 
          'vec__max_features': [7000, 15000],
          'clf'   : [LinearSVC()],
          'clf__C':[0.05, 0.1, 0.5, 1, 5, 10]
         },
         
         {'vec__ngram_range': ((1, 1), (1, 2), (1,3)), 
          'vec__max_features': [7000, 15000],
          'clf'   : [MultinomialNB()]
         },
            
         {'vec__ngram_range': ((1, 1), (1, 2), (1,3)), 
          'vec__max_features': [7000, 15000],   
         'clf': [LogisticRegression(max_iter = 7000)],
         'clf__solver' : ['newton-cg', 'lbfgs', 'liblinear'],
         'clf__penalty' : ['l2'],
         'clf__C' : [100, 10, 1.0, 0.1, 0.01]}
        ]
         
random_grid = {'vec__ngram_range': ((1, 1), (1, 2), (1,3)), 
               'vec__max_features': (7000, 15000), 
               'r_f__n_estimators': n_estimators,
               'r_f__max_features': max_features,
               'r_f__max_depth': max_depth,
               'r_f__min_samples_split': min_samples_split,
               'r_f__min_samples_leaf': min_samples_leaf,
               'r_f__criterion': criterion
              }

# %% [markdown]
# Two pipeline: first for Linear SVM, Naive Bayes and Logistic Regression algorithms, second to train Random Forest algorithm

# %%
pipe = Pipeline([
    ('vec', TfidfVectorizer()),
    ('clf', LinearSVC()),
     ])

pipe_rf = Pipeline([
    ('vec', TfidfVectorizer()),
    ('r_f',  RandomForestClassifier()),
     ])

# %% [markdown]
# 3-fold grid and random search for selected algorithms with “accuracy” performance measure

# %%
search_m = GridSearchCV(pipe, param, cv = 3, return_train_score=True, scoring = 'accuracy', n_jobs=-1)
search_m.fit(clean_data, y_train)

df_m = pd.DataFrame.from_dict(search_m.cv_results_)
df_m[['params', 'mean_test_score', 'mean_train_score', 'rank_test_score']].sort_values('rank_test_score', ascending=True)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        params  \
# 16   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.5, 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 17   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.5, 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 15   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.5, 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 82   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 88   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 11   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.1, 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 83   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 89   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 10   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.1, 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 81   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 87   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 77   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 10, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 9    {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.1, 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 76   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 10, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 94   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 95   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 22   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 1, 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 23   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 1, 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 93   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 21   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 1, 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 7    {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.1, 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 79   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 85   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 8    {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.1, 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 80   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 86   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 75   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 10, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 6    {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.1, 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 92   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 91   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 26   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 5, 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 54   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 24   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 5, 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 119  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 125  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 118  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 124  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 131  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 3)}
# 130  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 2)}
# 116  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 122  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 115  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 121  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 43   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 49   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 50   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 44   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 48   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 42   {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 128  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 120  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 114  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 127  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 123  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs', 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 117  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'newton-cg', 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 31   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 10, 'vec__max_features': 7000, 'vec__ngram_range': (1, 2)}
# 126  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
# 32   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 10, 'vec__max_features': 7000, 'vec__ngram_range': (1, 3)}
# 129  {'clf': LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=500,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.01, 'clf__penalty': 'l2', 'clf__solver': 'liblinear', 'vec__max_features': 15000, 'vec__ngram_range': (1, 1)}
# 30   {'clf': LinearSVC(C=0.5, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 10, 'vec__max_features': 7000, 'vec__ngram_range': (1, 1)}
#
#      mean_test_score  mean_train_score  rank_test_score
# 16   0.907825         0.967550          1
# 17   0.907200         0.967150          2
# 15   0.906625         0.967262          3
# 82   0.906200         0.946075          4
# 88   0.906125         0.946075          5
# 11   0.906050         0.938262          6
# 83   0.905925         0.945913          7
# 89   0.905900         0.945900          8
# 10   0.905875         0.938737          9
# 81   0.905025         0.946075          10
# 87   0.905000         0.946088          11
# 77   0.904925         0.978100          12
# 9    0.904700         0.938112          13
# 76   0.904250         0.978662          14
# 94   0.904225         0.936587          15
# 95   0.904200         0.936412          16
# 22   0.903975         0.980275          17
# 23   0.903825         0.979837          18
# 93   0.903000         0.936300          19
# 21   0.902650         0.979000          20
# 7    0.902550         0.931225          21
# 79   0.902425         0.938500          22
# 85   0.902425         0.938512          22
# 8    0.902400         0.930712          24
# 80   0.902200         0.938012          25
# 86   0.902200         0.938000          25
# 75   0.902200         0.977062          27
# 6    0.901725         0.931200          28
# 92   0.901700         0.929225          29
# 91   0.901550         0.929675          30
# ..        ...              ...          ..
# 26   0.874825         0.986637          103
# 54   0.873825         0.993425          104
# 24   0.873550         0.987488          105
# 119  0.871400         0.879737          106
# 125  0.871400         0.879750          106
# 118  0.870850         0.879300          108
# 124  0.870850         0.879300          108
# 131  0.869500         0.877687          110
# 130  0.869175         0.877075          111
# 116  0.868425         0.876062          112
# 122  0.868425         0.876050          112
# 115  0.868075         0.875862          114
# 121  0.868025         0.875862          115
# 43   0.868000         0.998913          116
# 49   0.867875         0.998913          117
# 50   0.867750         0.998700          118
# 44   0.867575         0.998700          119
# 48   0.866500         0.998763          120
# 42   0.866500         0.998738          121
# 128  0.866375         0.873525          122
# 120  0.866300         0.873587          123
# 114  0.866300         0.873587          123
# 127  0.866175         0.873212          125
# 123  0.866100         0.873750          126
# 117  0.866100         0.873775          126
# 31   0.864775         0.994000          128
# 126  0.864400         0.870937          129
# 32   0.864325         0.993575          130
# 129  0.864175         0.871825          131
# 30   0.862750         0.993488          132
#
# [132 rows x 4 columns]

# %% [markdown]
# Because of the large hyperparameter space (576 different combinations), hyperparameter tuning has been performed with the Randomised search tool

# %%
search_rf = RandomizedSearchCV(pipe_rf, random_grid, cv = 3, return_train_score=True, scoring = 'accuracy', n_jobs=-1)
search_rf.fit(clean_data, y_train)

df_rf = pd.DataFrame.from_dict(search_rf.cv_results_)
df_rf[['params', 'mean_test_score', 'mean_train_score', 'rank_test_score']].sort_values(by=['rank_test_score'], ascending=True)
# Out:
#                                                                                                                                                                                                                           params  \
# 6  {'vec__ngram_range': (1, 2), 'vec__max_features': 15000, 'r_f__n_estimators': 400, 'r_f__min_samples_split': 10, 'r_f__min_samples_leaf': 1, 'r_f__max_features': 'auto', 'r_f__max_depth': None, 'r_f__criterion': 'gini'}
# 3  {'vec__ngram_range': (1, 1), 'vec__max_features': 15000, 'r_f__n_estimators': 100, 'r_f__min_samples_split': 10, 'r_f__min_samples_leaf': 2, 'r_f__max_features': 'auto', 'r_f__max_depth': None, 'r_f__criterion': 'gini'}
# 7  {'vec__ngram_range': (1, 3), 'vec__max_features': 7000, 'r_f__n_estimators': 200, 'r_f__min_samples_split': 10, 'r_f__min_samples_leaf': 2, 'r_f__max_features': 'auto', 'r_f__max_depth': None, 'r_f__criterion': 'entropy'}
# 9  {'vec__ngram_range': (1, 2), 'vec__max_features': 7000, 'r_f__n_estimators': 200, 'r_f__min_samples_split': 2, 'r_f__min_samples_leaf': 1, 'r_f__max_features': 'auto', 'r_f__max_depth': None, 'r_f__criterion': 'entropy'}
# 5  {'vec__ngram_range': (1, 1), 'vec__max_features': 7000, 'r_f__n_estimators': 200, 'r_f__min_samples_split': 10, 'r_f__min_samples_leaf': 1, 'r_f__max_features': 'sqrt', 'r_f__max_depth': 60, 'r_f__criterion': 'gini'}
# 8  {'vec__ngram_range': (1, 2), 'vec__max_features': 15000, 'r_f__n_estimators': 10, 'r_f__min_samples_split': 2, 'r_f__min_samples_leaf': 4, 'r_f__max_features': 'sqrt', 'r_f__max_depth': None, 'r_f__criterion': 'gini'}
# 1  {'vec__ngram_range': (1, 1), 'vec__max_features': 7000, 'r_f__n_estimators': 100, 'r_f__min_samples_split': 5, 'r_f__min_samples_leaf': 4, 'r_f__max_features': 'auto', 'r_f__max_depth': 90, 'r_f__criterion': 'gini'}
# 4  {'vec__ngram_range': (1, 3), 'vec__max_features': 15000, 'r_f__n_estimators': 100, 'r_f__min_samples_split': 10, 'r_f__min_samples_leaf': 1, 'r_f__max_features': 'sqrt', 'r_f__max_depth': 30, 'r_f__criterion': 'gini'}
# 2  {'vec__ngram_range': (1, 2), 'vec__max_features': 7000, 'r_f__n_estimators': 200, 'r_f__min_samples_split': 5, 'r_f__min_samples_leaf': 2, 'r_f__max_features': 'sqrt', 'r_f__max_depth': 30, 'r_f__criterion': 'gini'}
# 0  {'vec__ngram_range': (1, 2), 'vec__max_features': 7000, 'r_f__n_estimators': 400, 'r_f__min_samples_split': 5, 'r_f__min_samples_leaf': 4, 'r_f__max_features': 'auto', 'r_f__max_depth': 30, 'r_f__criterion': 'gini'}
#
#    mean_test_score  mean_train_score  rank_test_score
# 6  0.863800         0.997763          1
# 3  0.859325         0.931350          2
# 7  0.857075         0.936613          3
# 9  0.856975         0.999913          4
# 5  0.837325         0.934212          5
# 8  0.836150         0.871800          6
# 1  0.833525         0.858413          7
# 4  0.825000         0.873400          8
# 2  0.816775         0.847963          9
# 0  0.809750         0.827625          10

# %% [markdown]
# The highest score of about 90,8% obtained with Linear SVM algorithm, unigram and bigram sequence of words, size of vocabulary equal 15,000 and regularization hyperparameter (C) equal 0.5

# %%
svm_max = search_svm.cv_results_.get('mean_test_score').max()
r_f_max = search_rf.cv_results_.get('mean_test_score').max() 
NB_max =  search_NB.cv_results_.get('mean_test_score').max()
print ('Maximum validation accuracy\n \nSVM: {},\nRandom Forest: {},\nNaive Bayes: {}'.format(svm_max, r_f_max, NB_max))


Accuracy = [svm_max, r_f_max, NB_max]
Models = ['SVM','Random_Forest','Naive_Bayes']
Accuracy_pos = np.arange(len(Models))
plt.bar(Accuracy_pos, Accuracy)
plt.xticks(Accuracy_pos, Models)
plt.title('comparing the accuracy of each model')
plt.show()
# Out:
# Maximum validation accuracy
#
# SVM: 0.9078249605107684,
# Random Forest: 0.8637999829551761,
# Naive Bayes: 0.8999749461263155

# %% [markdown]
# Fit and transform the training text data with obtained earlier best parameters of ngram_range and max_features

# %%
#Loading vectorizer
#vectorizer = joblib.load('tfidf_vectroizer.pkl')

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features = 15000)
X_train = vectorizer.fit_transform(clean_data)

# %%
#saving vectorizer
#joblib.dump(vectorizer, 'tfidf_vectroizer.pkl')
# Out:
# ['tfidf_vectroizer.pkl']

# %% [markdown]
# Applying best value for the 'C' hyperparameter

# %%
best_mod_tf_idf = LinearSVC(C = 0.5)

# %% [markdown]
# Training time estimation for the Linear SVM algorithm

# %%
# %%timeit
best_mod_tf_idf.fit(X_train, y_train)
# Out:
# 507 ms ± 53.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#saving best model
joblib_file = "best_model_tfidf.pkl"
joblib.dump(best_mod_tf_idf, joblib_file)
# Out:
# ['best_model_tfidf.pkl']

# %% [markdown]
# # Evaluation on the test dataset

# %% [markdown]
# Transforming the test dataset with the same TF-IDF vectorizer and applying trained earlier Linear SVM model, the accuracy score around 91% have been achieved:

# %%
#Loading vectorizer
#vectorizer = joblib.load('tfidf_vectroizer.pkl')

# %%
X_test = vectorizer.transform(clean_test_data)

# %%
#loading best model
model_tfidf = joblib.load('best_model_tfidf.pkl')

# %%
#Creating the list with unique category names
aux_df = test_data[['category_name', 'label']].drop_duplicates().sort_values('label')

#prediction on the cleaned test dataset
y_pred = model_tfidf.predict(X_test)

print('Test dataset accuracy score:', accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred, target_names=aux_df['category_name'].values))

con = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,9))
ax_cor_b = sns.heatmap(con.T, square=False, annot=True, fmt='d', cbar=False,
            xticklabels=aux_df['category_name'].values, 
            yticklabels=aux_df['category_name'].values,
            cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.title('Confusion matrix')
plt.show()
# Out:
# Test dataset accuracy score: 0.91275
#
#               precision    recall  f1-score   support
#
#        world       0.93      0.90      0.92      1000
#       sports       0.95      0.98      0.97      1000
#     business       0.89      0.87      0.88      1000
#     sci/tech       0.88      0.89      0.89      1000
#
#     accuracy                           0.91      4000
#    macro avg       0.91      0.91      0.91      4000
# weighted avg       0.91      0.91      0.91      4000

# %% [markdown]
# The most accurately classified news topic is sports with f1-score equal to 0.97. More classification errors of the model occurred on the business and sci/tech topics both performing with 0.88 f1-score.

# %% [markdown]
# # Text Representation with Word2vec

# %% [markdown]
# Word2vec is a word embedding technique with the general assumption that words in the corpus share similar contexts and meaning and therefore might have similar vector representation.

# %% [markdown]
# The first step is to tokenised input text and transform it to list of lists format

# %%
sent = [row.split() for row in clean_data]

# %%
sent
# Out:
# [['wizard',
#   'guard',
#   'blake',
#   'week',
#   'ap',
#   'ap',
#   'washington',
#   'wizard',
#   'point',
#   'guard',
#   'steve',
#   'blake',
#   'miss',
#   'first',
#   'month',
#   'season',
#   'injur',
#   'ankl',
#   'pickup',
#   'game'],
#  ['brief',
#   'hp',
#   'acquir',
#   'synstar',
#   'move',
#   'design',
#   'help',
#   'better',
#   'compet',
#   'europ',
#   'hewlettpackard',
#   'said',
#   'acquir',
#   'synstar',
#   'plc',
#   'ukbas',
#   'technolog',
#   'servic',
#   'firm',
#   'million'],
#  ['us',
#   'airway',
#   'pilot',
#   'vote',
#   'salari',
#   'reduct',
#   'us',
#   'airway',
#   'pilot',
#   'vote',
#   'approv',
#   'new',
#   'labor',
#   'agreement',
#   'yesterday',
#   'reduc',
#   'salari',
#   'percent',
#   'save',
#   'airlin',
#   'million',
#   'year'],
#  ['radiat',
#   'risk',
#   'need',
#   'updat',
#   'uk',
#   'panel',
#   'examin',
#   'radiat',
#   'risk',
#   'say',
#   'offici',
#   'estim',
#   'danger',
#   'health',
#   'may',
#   'wide',
#   'mark',
#   'substanti'],
#  ['presid',
#   'fate',
#   'line',
#   'venezuela',
#   'caraca',
#   'partisan',
#   'side',
#   'call',
#   'polar',
#   'import',
#   'elect',
#   'venezuela',
#   'histori',
#   'presidenti',
#   'recal',
#   'referendum',
#   'today',
#   'determin',
#   'cours',
#   'democraci',
#   'could',
#   'buffet',
#   'world',
#   'oil',
#   'price',
#   'campaign',
#   'also',
#   'utterli',
#   'convinc',
#   'win'],
#  ['australia',
#   'virgin',
#   'blue',
#   'increas',
#   'fuel',
#   'surcharg',
#   'oil',
#   'hike',
#   'sydney',
#   'australian',
#   'airlin',
#   'virgin',
#   'blue',
#   'announc',
#   'sharpli',
#   'increas',
#   'fuel',
#   'surcharg',
#   'impos',
#   'may',
#   'compens',
#   'rise',
#   'world',
#   'oil',
#   'price'],
#  ['chines',
#   'sub',
#   'detect',
#   'japan',
#   'water',
#   'japanes',
#   'govern',
#   'offici',
#   'thursday',
#   'confirm',
#   'chines',
#   'navi',
#   'submarin',
#   'intrus',
#   'enter',
#   'japanes',
#   'water',
#   'day',
#   'earlier',
#   'submarin',
#   'discov',
#   'earli',
#   'wednesday'],
#  ['wartorn',
#   'wonderland',
#   'hondura',
#   'central',
#   'american',
#   'countri',
#   'embroil',
#   'war',
#   'becom',
#   'hot',
#   'market',
#   'afford',
#   'beachfront',
#   'properti'],
#  ['japan',
#   'celebr',
#   'suzuki',
#   'break',
#   'record',
#   'basebal',
#   'fan',
#   'across',
#   'japan',
#   'saturday',
#   'honor',
#   'ichiro',
#   'suzuki',
#   'seattl',
#   'marin',
#   'japanes',
#   'player',
#   'broke',
#   'major',
#   'leagu',
#   'basebal',
#   'record',
#   'season',
#   'hit'],
#  ['world',
#   'stage',
#   'one',
#   'els',
#   'compar',
#   'el',
#   'two',
#   'year',
#   'ago',
#   'erni',
#   'el',
#   'explain',
#   'possibl',
#   'tiger',
#   'wood',
#   'could',
#   'overtaken',
#   'world',
#   'rank',
#   'cours',
#   'time',
#   'south',
#   'african'],
#  ['paper',
#   'siriu',
#   'pricey',
#   'despit',
#   'howard',
#   'stern',
#   'share',
#   'siriu',
#   'satellit',
#   'radio',
#   'inc',
#   'sirio',
#   'quot',
#   'profil',
#   'research',
#   'look',
#   'pricey',
#   'despit',
#   'compani',
#   'new',
#   'fiveyear',
#   'million',
#   'pact',
#   'shock',
#   'jock',
#   'howard',
#   'stern',
#   'air',
#   'program'],
#  ['build',
#   'code',
#   'back',
#   'hot',
#   'seat',
#   'insur',
#   'claim',
#   'project',
#   'hurrican',
#   'charley',
#   'climb',
#   'billion',
#   'build',
#   'industri',
#   'believ',
#   'hurrican',
#   'standard',
#   'uniform',
#   'florida',
#   'build',
#   'code',
#   'may'],
#  ['updat',
#   'us',
#   'popul',
#   'strain',
#   'financ',
#   'age',
#   'us',
#   'popul',
#   'strain',
#   'public',
#   'financ',
#   'hurt',
#   'economi',
#   'without',
#   'swift',
#   'fix',
#   'social',
#   'safeti',
#   'net',
#   'rais',
#   'age'],
#  ['newsom',
#   'call',
#   'end',
#   'lockout',
#   'forc',
#   'move',
#   'yet',
#   'bring',
#   'end',
#   'disrupt',
#   'labor',
#   'disput',
#   'mayor',
#   'gavin',
#   'newsom',
#   'urg',
#   'oper',
#   'citi',
#   'promin',
#   'hotel',
#   'let',
#   'employe',
#   'return',
#   'work',
#   'press',
#   'side',
#   'reach',
#   'agreement',
#   'jan'],
#  ['rite',
#   'aid',
#   'cut',
#   'view',
#   'pharmaci',
#   'sale',
#   'slow',
#   'reuter',
#   'reuter',
#   'drugstor',
#   'chain',
#   'rite',
#   'aid',
#   'corp',
#   'tuesday',
#   'warn',
#   'fullyear',
#   'profit',
#   'revenu',
#   'would',
#   'fallshort',
#   'wall',
#   'street',
#   'expect',
#   'slow',
#   'pharmacysal',
#   'compani',
#   'tri',
#   'curb',
#   'healthcar',
#   'cost'],
#  ['dollar',
#   'drop',
#   'new',
#   'low',
#   'euro',
#   'dollar',
#   'whose',
#   'weak',
#   'fuel',
#   'concern',
#   'us',
#   'trade',
#   'budget',
#   'deficit',
#   'hit',
#   'new',
#   'low',
#   'euro',
#   'rose',
#   'yesterday',
#   'late',
#   'new',
#   'york',
#   'trade',
#   'euro',
#   'eas',
#   'back',
#   'intraday',
#   'high',
#   'still',
#   'monday',
#   'late',
#   'rate'],
#  ['mismatch',
#   'turn',
#   'competit',
#   'heninhardenn',
#   'face',
#   'rooki',
#   'appear',
#   'mismatch',
#   'took',
#   'turn',
#   'competit',
#   'second',
#   'set',
#   'heninhardenn',
#   'regroup',
#   'win'],
#  ['skorea',
#   'japan',
#   'keep',
#   'summit',
#   'shuttl',
#   'north',
#   'seoul',
#   'reuter',
#   'south',
#   'korean',
#   'presid',
#   'roh',
#   'moohyun',
#   'leav',
#   'twoday',
#   'offici',
#   'visit',
#   'japan',
#   'friday',
#   'summit',
#   'talk',
#   'focu',
#   'north',
#   'korean',
#   'nuclear',
#   'problem',
#   'japan',
#   'deterior',
#   'tie',
#   'communist',
#   'state'],
#  ['inflight',
#   'mobil',
#   'call',
#   'approv',
#   'plane',
#   'maker',
#   'airbu',
#   'report',
#   'progress',
#   'plan',
#   'enabl',
#   'passeng',
#   'use',
#   'mobil',
#   'phone',
#   'flight',
#   'begin',
#   'test',
#   'equip',
#   'aboard',
#   'airbu',
#   'plane',
#   'demonstr',
#   'mobil',
#   'phone',
#   'use',
#   'without',
#   'interf',
#   'navig',
#   'system'],
#  ['sharon',
#   'say',
#   'farrightist',
#   'tri',
#   'incit',
#   'war',
#   'ariel',
#   'sharon',
#   'isra',
#   'prime',
#   'minist',
#   'accus',
#   'farrightist',
#   'today',
#   'tri',
#   'incit',
#   'civil',
#   'war',
#   'urg',
#   'measur',
#   'curb',
#   'group',
#   'oppos',
#   'plan',
#   'withdraw',
#   'gaza',
#   'strip'],
#  ['bomb',
#   'pakistan',
#   'shiit',
#   'mosqu',
#   'kill',
#   'four',
#   'ap',
#   'ap',
#   'suicid',
#   'bomb',
#   'shiit',
#   'mosqu',
#   'sunday',
#   'eastern',
#   'citi',
#   'kill',
#   'four',
#   'peopl',
#   'includ',
#   'two',
#   'secur',
#   'guard',
#   'lost',
#   'live',
#   'confront',
#   'attack',
#   'prevent',
#   'far',
#   'greater',
#   'number',
#   'death'],
#  ['ibm',
#   'say',
#   'supercomput',
#   'world',
#   'fastest',
#   'new',
#   'york',
#   'reuter',
#   'news',
#   'servic',
#   'septemb',
#   'ibm',
#   'said',
#   'yesterday',
#   'develop',
#   'world',
#   'fastest',
#   'comput',
#   'put',
#   'back',
#   'top',
#   'japanes',
#   'supercomput',
#   'claim',
#   'titl',
#   'two',
#   'year',
#   'ago'],
#  ['ibm',
#   'voic',
#   'servic',
#   'deal',
#   'lloyd',
#   'ap',
#   'ap',
#   'intern',
#   'busi',
#   'machin',
#   'corp',
#   'said',
#   'monday',
#   'provid',
#   'voic',
#   'data',
#   'servic',
#   'british',
#   'financialservic',
#   'compani',
#   'lloyd',
#   'tsb',
#   'group',
#   'plc',
#   'seven',
#   'year',
#   'deal',
#   'worth',
#   'million'],
#  ['serena',
#   'blame',
#   'headach',
#   'linz',
#   'upset',
#   'ap',
#   'ap',
#   'serena',
#   'william',
#   'blame',
#   'headach',
#   'poor',
#   'play',
#   'upset',
#   'loss',
#   'qualifi',
#   'alina',
#   'jidkova',
#   'second',
#   'round',
#   'generali',
#   'ladi',
#   'open'],
#  ['ftc',
#   'sue',
#   'alleg',
#   'spywar',
#   'distributor',
#   'compani',
#   'accus',
#   'infect',
#   'pc',
#   'sell',
#   'spywareblock',
#   'softwar'],
#  ['hurrican',
#   'ivan',
#   'threaten',
#   'barbado',
#   'eastern',
#   'caribbean',
#   'miami',
#   'reuter',
#   'eastern',
#   'caribbean',
#   'island',
#   'barbado',
#   'storm',
#   'alert',
#   'power',
#   'hurrican',
#   'ivan',
#   'race',
#   'across',
#   'atlant',
#   'ocean',
#   'toward',
#   'caribbean',
#   'sunday'],
#  ['korea',
#   'retreat',
#   'talk',
#   'seoul',
#   'north',
#   'korea',
#   'suggest',
#   'yesterday',
#   'would',
#   'particip',
#   'sixparti',
#   'negoti',
#   'nuclear',
#   'program',
#   'recent',
#   'revel',
#   'scientist',
#   'south',
#   'korea',
#   'illeg',
#   'experi',
#   'produc',
#   'fissil',
#   'materi',
#   'nuclear',
#   'weapon'],
#  ['microsoft',
#   'downplay',
#   'real',
#   'complaint',
#   'microsoft',
#   'corp',
#   'said',
#   'monday',
#   'complaint',
#   'file',
#   'south',
#   'korea',
#   'realnetwork',
#   'inc',
#   'alleg',
#   'media',
#   'player',
#   'softwar',
#   'breach',
#   'antitrust',
#   'law',
#   'quotwithout',
#   'merit',
#   'quot'],
#  ['pm',
#   'rumsfeld',
#   'lot',
#   'pak',
#   'build',
#   'trust',
#   'new',
#   'delhi',
#   'decemb',
#   'prime',
#   'minist',
#   'manmohan',
#   'singh',
#   'today',
#   'told',
#   'us',
#   'defenc',
#   'secretari',
#   'donald',
#   'rumsfeld',
#   'india',
#   'readi',
#   'take',
#   'forward',
#   'peac',
#   'process',
#   'pakistan',
#   'presid',
#   'musharraf',
#   'stick',
#   'commit',
#   'check',
#   'cross'],
#  ['stelio',
#   'enter',
#   'onlin',
#   'music',
#   'fray',
#   'easyjet',
#   'founder',
#   'team',
#   'uk',
#   'download',
#   'servic',
#   'wippit',
#   'enter',
#   'onlin',
#   'music',
#   'market'],
#  ['consum',
#   'price',
#   'calm',
#   'novemb',
#   'ap',
#   'ap',
#   'consum',
#   'price',
#   'calm',
#   'novemb',
#   'help',
#   'smaller',
#   'increas',
#   'energi',
#   'food',
#   'mean',
#   'feder',
#   'reserv',
#   'probabl',
#   'continu',
#   'rais',
#   'interest',
#   'rate',
#   'gradual',
#   'keep',
#   'inflat',
#   'control'],
#  ['four',
#   'us',
#   'soldier',
#   'face',
#   'hear',
#   'germani',
#   'iraq',
#   'prison',
#   'abus',
#   'berlin',
#   'four',
#   'us',
#   'soldier',
#   'accus',
#   'abus',
#   'prison',
#   'notori',
#   'jail',
#   'iraq',
#   'includ',
#   'suspect',
#   'ringlead',
#   'face',
#   'militari',
#   'hear',
#   'germani',
#   'monday',
#   'trial',
#   'court',
#   'martial'],
#  ['giuliani',
#   'said',
#   'apolog',
#   'bush',
#   'kerik',
#   'ap',
#   'ap',
#   'former',
#   'new',
#   'york',
#   'mayor',
#   'rudolph',
#   'giuliani',
#   'preplan',
#   'dinner',
#   'presid',
#   'bush',
#   'offer',
#   'apolog',
#   'abort',
#   'nomin',
#   'close',
#   'associ',
#   'bernard',
#   'kerik',
#   'homeland',
#   'secur',
#   'secretari',
#   'giuliani',
#   'spokeswoman',
#   'said'],
#  ['british',
#   'redeploy',
#   'iraq',
#   'meet',
#   'opposit',
#   'british',
#   'ministri',
#   'defens',
#   'confirm',
#   'sunday',
#   'us',
#   'sent',
#   'request',
#   'british',
#   'govern',
#   'redeploy',
#   'british',
#   'forc',
#   'station',
#   'iraq',
#   'us',
#   'troop',
#   'station',
#   'iraq',
#   'prepar',
#   'new',
#   'militari',
#   'action',
#   'fallujah'],
#  ['sale',
#   'sun',
#   'surg',
#   'ahead',
#   'connecticut',
#   'sun',
#   'game',
#   'last',
#   'saturday',
#   'drop',
#   'open',
#   'wnba',
#   'eastern',
#   'confer',
#   'semifin',
#   'seri',
#   'washington',
#   'mystic',
#   'sun',
#   'came',
#   'back',
#   'even',
#   'seri',
#   'monday',
#   'mystic',
#   'game'],
#  ['milit',
#   'kill',
#   'ampk',
#   'ahead',
#   'pm',
#   'visit',
#   'prime',
#   'minist',
#   'manmohan',
#   'singh',
#   'arriv',
#   'srinagar',
#   'tomorrow',
#   'first',
#   'leg',
#   'twoday',
#   'maiden',
#   'visit',
#   'jammu',
#   'kashmir',
#   'approach',
#   'would',
#   'look',
#   'big',
#   'pictur',
#   'rather',
#   'dole',
#   'packag',
#   'sourc',
#   'prime',
#   'minist'],
#  ['uk',
#   'troop',
#   'iraq',
#   'start',
#   'move',
#   'north',
#   'battl',
#   'group',
#   'british',
#   'troop',
#   'began',
#   'roll',
#   'southern',
#   'iraq',
#   'wednesday',
#   'usrequest',
#   'mission',
#   'deadlier',
#   'area',
#   'near',
#   'baghdad',
#   'major',
#   'polit',
#   'gambl',
#   'british',
#   'prime',
#   'minist',
#   'toni',
#   'blair'],
#  ['suprem',
#   'court',
#   'stay',
#   'dalmiya',
#   'elect',
#   'suprem',
#   'court',
#   'stay',
#   'elect',
#   'appoint',
#   'jagmohan',
#   'dalmiya',
#   'patroninchief',
#   'bcci',
#   'court',
#   'also',
#   'stay',
#   'appoint',
#   'justic',
#   'mohan',
#   'bcci',
#   'administr',
#   'restor'],
#  ['oklahoma',
#   'ralli',
#   'behind',
#   'white',
#   'quarterback',
#   'jason',
#   'white',
#   'last',
#   'year',
#   'heisman',
#   'winner',
#   'pass',
#   'five',
#   'touchdown',
#   'oklahoma',
#   'escap',
#   'texa'],
#  ['hamm',
#   'get',
#   'keep',
#   'gold',
#   'medal',
#   'us',
#   'gymnast',
#   'paul',
#   'hamm',
#   'keep',
#   'gold',
#   'medal',
#   'men',
#   'allaround',
#   'event',
#   'athen',
#   'olymp',
#   'sport',
#   'tribun',
#   'rule',
#   'thursday',
#   'lausann',
#   'switzerland'],
#  ['latin',
#   'america',
#   'alert',
#   'terror',
#   'monterrey',
#   'mexico',
#   'govern',
#   'throughout',
#   'mexico',
#   'central',
#   'america',
#   'alert',
#   'evid',
#   'grow',
#   'alqaida',
#   'member',
#   'travel',
#   'region',
#   'look',
#   'recruit',
#   'carri',
#   'attack',
#   'latin',
#   'america',
#   'potenti',
#   'last',
#   'frontier',
#   'intern',
#   'terror',
#   'territori',
#   'could',
#   'perfect',
#   'stage',
#   'ground',
#   'osama',
#   'bin',
#   'laden',
#   'milit',
#   'homegrown',
#   'rebel',
#   'group',
#   'drug',
#   'peopl',
#   'smuggler',
#   'corrupt',
#   'govern'],
#  ['flood',
#   'kill',
#   'least',
#   'haiti',
#   'bloat',
#   'corps',
#   'weep',
#   'rel',
#   'fill',
#   'morgu',
#   'haitian',
#   'face',
#   'yet',
#   'anoth',
#   'tragedi',
#   'year',
#   'mark',
#   'revolt',
#   'militari',
#   'intervent',
#   'deadli',
#   'flood'],
#  ['olymp',
#   'feder',
#   'crash',
#   'roddick',
#   'surviv',
#   'olymp',
#   'scare',
#   'athen',
#   'world',
#   'roger',
#   'feder',
#   'switzerland',
#   'crash',
#   'olymp',
#   'tenni',
#   'tournament',
#   'lost',
#   'unseed',
#   'toma',
#   'berdych',
#   'czech',
#   'republ'],
#  ['japan',
#   'leader',
#   'shuffl',
#   'cabinet',
#   'push',
#   'econom',
#   'reform',
#   'prime',
#   'minist',
#   'junichiro',
#   'koizumi',
#   'shift',
#   'econom',
#   'repairman',
#   'japan',
#   'next',
#   'gargantuan',
#   'task',
#   'privat',
#   'world',
#   'largest',
#   'bank'],
#  ['windi',
#   'clinch',
#   'champion',
#   'trophi',
#   'thriller',
#   'london',
#   'uk',
#   'sep',
#   'pn',
#   'unbeaten',
#   'ninth',
#   'wicket',
#   'partnership',
#   'run',
#   'ian',
#   'bradshaw',
#   'courtney',
#   'brown',
#   'led',
#   'west',
#   'indi',
#   'clinch',
#   'champion',
#   'trophi',
#   'cricket',
#   'tournament',
#   'defeat',
#   'host',
#   'england',
#   'two',
#   'wicket',
#   'final'],
#  ['selig',
#   'receiv',
#   'threeyear',
#   'extens',
#   'philadelphia',
#   'sport',
#   'network',
#   'owner',
#   'thursday',
#   'unanim',
#   'vote',
#   'extend',
#   'term',
#   'basebal',
#   'commission',
#   'bud',
#   'selig',
#   'three',
#   'year'],
#  ['scientist',
#   'work',
#   'fat',
#   'fight',
#   'food',
#   'addit',
#   'lincoln',
#   'neb',
#   'univers',
#   'nebraskalincoln',
#   'nutrit',
#   'scientist',
#   'tim',
#   'carr',
#   'work',
#   'food',
#   'addit',
#   'would',
#   'combat',
#   'cholesterol',
#   'combin',
#   'two',
#   'unexpect',
#   'sourc',
#   'soybean',
#   'beef',
#   'tallow'],
#  ['yen',
#   'cut',
#   'loss',
#   'oil',
#   'threat',
#   'persist',
#   'tokyo',
#   'reuter',
#   'yen',
#   'recoup',
#   'loss',
#   'dollar',
#   'euro',
#   'wednesday',
#   'trader',
#   'said',
#   'would',
#   'like',
#   'weaken',
#   'oil',
#   'price',
#   'keep',
#   'strike',
#   'record',
#   'high'],
#  ['william',
#   'could',
#   'elig',
#   'start',
#   'next',
#   'season',
#   'ricki',
#   'william',
#   'repres',
#   'appar',
#   'close',
#   'complet',
#   'agreement',
#   'nfl',
#   'could',
#   'make',
#   'retir',
#   'miami',
#   'dolphin',
#   'tailback',
#   'elig',
#   'play',
#   'outset',
#   'season'],
#  ['bean',
#   'pose',
#   'reelect',
#   'dilemma',
#   'crane',
#   'ap',
#   'ap',
#   'melissa',
#   'bean',
#   'hand',
#   'seat',
#   'cushion',
#   'spell',
#   'reason',
#   'democrat',
#   'think',
#   'beat',
#   'veteran',
#   'rep',
#   'phil',
#   'crane',
#   'nov',
#   'read',
#   'crane',
#   'origin',
#   'seat',
#   'warmer',
#   'mani',
#   'year',
#   'accomplish'],
#  ['aol',
#   'creat',
#   'brows',
#   'softwar',
#   'part',
#   'reincarn',
#   'america',
#   'onlin',
#   'inc',
#   'creat',
#   'softwar',
#   'brows',
#   'web',
#   'play',
#   'movi',
#   'song',
#   'question',
#   'stay',
#   'relev',
#   'increasingli',
#   'broadband',
#   'world'],
#  ['athlet',
#   'montgomeri',
#   'gain',
#   'dope',
#   'case',
#   'postpon',
#   'lausann',
#   'switzerland',
#   'dope',
#   'case',
#   'world',
#   'record',
#   'holder',
#   'tim',
#   'montgomeri',
#   'chryst',
#   'gain',
#   'postpon',
#   'court',
#   'arbitr',
#   'sport',
#   'ca',
#   'said'],
#  ['yahoo',
#   'buy',
#   'bloomba',
#   'plan',
#   'chennai',
#   'oper',
#   'internet',
#   'major',
#   'yahoo',
#   'inc',
#   'highskil',
#   'softwar',
#   'profession',
#   'team',
#   'chennai',
#   'acquir',
#   'usbas',
#   'stata',
#   'lab'],
#  ['rapper',
#   'collaps',
#   'die',
#   'rap',
#   'artist',
#   'odb',
#   'collaps',
#   'die',
#   'age',
#   'work',
#   'record',
#   'studio'],
#  ['button',
#   'defend',
#   'jenson',
#   'button',
#   'remain',
#   'silent',
#   'decis',
#   'switch',
#   'barhonda',
#   'bmw',
#   'william',
#   'next',
#   'year',
#   'clearli',
#   'unhappi',
#   'media',
#   'coverag',
#   'receiv',
#   'set',
#   'record',
#   'straight',
#   'indic'],
#  ['cell',
#   'phone',
#   'flight',
#   'consid',
#   'feder',
#   'commun',
#   'commiss',
#   'consid',
#   'loosen',
#   'ban',
#   'use',
#   'cell',
#   'phone',
#   'airplan'],
#  ['india',
#   'tribal',
#   'peopl',
#   'safe',
#   'tsunamioffici',
#   'reuter',
#   'reuter',
#   'india',
#   'dwindl',
#   'aboriginalpopul',
#   'remot',
#   'andaman',
#   'nicobar',
#   'island',
#   'safe',
#   'asmost',
#   'live',
#   'jungl',
#   'far',
#   'away',
#   'coast',
#   'hit',
#   'adevast',
#   'tsunami',
#   'coast',
#   'guard',
#   'offici',
#   'said',
#   'thursday'],
#  ['budget',
#   'fight',
#   'deal',
#   'setback',
#   'sharon',
#   'govern',
#   'prime',
#   'minist',
#   'ariel',
#   'sharon',
#   'thrown',
#   'crisi',
#   'last',
#   'night',
#   'israel',
#   'parliament',
#   'reject',
#   'propos',
#   'budget',
#   'sharon'],
#  ['cisco',
#   'boost',
#   'net',
#   'incom',
#   'revenu',
#   'cisco',
#   'system',
#   'inc',
#   'tuesday',
#   'report',
#   'signific',
#   'gain',
#   'earn',
#   'revenu',
#   'fiscal',
#   'first',
#   'quarter',
#   'met',
#   'analyst',
#   'expect'],
#  ['un',
#   'envoy',
#   'head',
#   'darfur',
#   'un',
#   'envoy',
#   'sudan',
#   'visit',
#   'darfur',
#   'tomorrow',
#   'check',
#   'govern',
#   'claim',
#   'peopl',
#   'displac',
#   'conflict',
#   'voluntarili',
#   'return',
#   'home',
#   'spokesman',
#   'said'],
#  ['offici',
#   'ibm',
#   'sell',
#   'pc',
#   'unit',
#   'chines',
#   'compani',
#   'ibm',
#   'ibm',
#   'said',
#   'tuesday',
#   'would',
#   'sell',
#   'pc',
#   'busi',
#   'lenovo',
#   'china',
#   'pc',
#   'maker',
#   'billion',
#   'deal',
#   'mark',
#   'end',
#   'era'],
#  ['philippin',
#   'flood',
#   'victim',
#   'lose',
#   'hope',
#   'storm',
#   'near',
#   'philippin',
#   'tide',
#   'mud',
#   'carv',
#   'random',
#   'trail',
#   'destruct',
#   'philippin',
#   'town',
#   'rob',
#   'alreadi',
#   'impoverish',
#   'resid',
#   'children',
#   'hous',
#   'hope'],
#  ['updat',
#   'sent',
#   'unit',
#   'held',
#   'drawn',
#   'derbi',
#   'manchest',
#   'unit',
#   'titl',
#   'ambit',
#   'took',
#   'anoth',
#   'blow',
#   'sunday',
#   'held',
#   'goalless',
#   'draw',
#   'home',
#   'derbi',
#   'rival',
#   'manchest',
#   'citi',
#   'alan',
#   'smith',
#   'sent'],
#  ['appl',
#   'imac',
#   'good',
#   'year',
#   'appl',
#   'sinc',
#   'begin',
#   'discuss',
#   'garageband',
#   'airport',
#   'express',
#   'latest',
#   'ipod'],
#  ['nasa',
#   'space',
#   'shuttl',
#   'fix',
#   'last',
#   'year',
#   'chunk',
#   'foam',
#   'damag',
#   'wing',
#   'columbia',
#   'lead',
#   'breakup',
#   'shuttl',
#   'high',
#   'texa',
#   'nasa',
#   'aim',
#   'three',
#   'shuttl',
#   'flight'],
#  ['india',
#   'celebr',
#   'taj',
#   'mahal',
#   'anniversari',
#   'india',
#   'celebr',
#   'devot',
#   'jubile',
#   'famou',
#   'mausoleum',
#   'taj',
#   'mahal',
#   'start',
#   'tomorrow',
#   'india',
#   'worldwid',
#   'known',
#   'histor',
#   'architectur',
#   'gem',
#   'snowwhit',
#   'taj',
#   'mahal'],
#  ['biolas',
#   'cut',
#   'outlook',
#   'share',
#   'tumbl',
#   'medic',
#   'technolog',
#   'compani',
#   'biolas',
#   'technolog',
#   'inc',
#   'bltio',
#   'quot',
#   'profil',
#   'research',
#   'thursday',
#   'cut',
#   'outlook',
#   'third',
#   'fourth',
#   'quarter',
#   'send',
#   'share',
#   'tumbl'],
#  ['new',
#   'chechen',
#   'leader',
#   'vow',
#   'peac',
#   'poll',
#   'critic',
#   'grozni',
#   'russia',
#   'reuter',
#   'chechnya',
#   'new',
#   'leader',
#   'vow',
#   'monday',
#   'rebuild',
#   'shatter',
#   'region',
#   'crush',
#   'extremist',
#   'win',
#   'elect',
#   'condemn',
#   'right',
#   'group',
#   'show',
#   'stagemanag',
#   'moscow'],
#  ['time',
#   'warner',
#   'pay',
#   'agre',
#   'justic',
#   'dept',
#   'deal',
#   'propos',
#   'pay',
#   'addit',
#   'end',
#   'sec',
#   'probe',
#   'harri',
#   'berkowitz',
#   'seek',
#   'remov',
#   'cloud',
#   'linger',
#   'time',
#   'warner',
#   'year',
#   'media',
#   'giant',
#   'said',
#   'yesterday'],
#  ['war',
#   'crime',
#   'suspect',
#   'surrend',
#   'serb',
#   'one',
#   'men',
#   'want',
#   'war',
#   'crime',
#   'commit',
#   'bosnia',
#   'war',
#   'surrend',
#   'serbian',
#   'author',
#   'ljubisa',
#   'beara',
#   'indict',
#   'two',
#   'year',
#   'ago',
#   'alleg',
#   'war',
#   'crime',
#   'commit',
#   'town'],
#  ['look',
#   'appeal',
#   'young',
#   'peopl',
#   'pc',
#   'go',
#   'loud',
#   'bold',
#   'plenti',
#   'would',
#   'happi',
#   'person',
#   'comput',
#   'sophi',
#   'foreman',
#   'austin',
#   'texa',
#   'enough',
#   'complaint',
#   'pc',
#   'plain'],
#  ['intuit',
#   'post',
#   'loss',
#   'revenu',
#   'pct',
#   'ap',
#   'ap',
#   'intuit',
#   'inc',
#   'post',
#   'narrow',
#   'net',
#   'loss',
#   'latest',
#   'quarter',
#   'increas',
#   'revenu',
#   'quickbook',
#   'account',
#   'softwar',
#   'help',
#   'boost',
#   'result'],
#  ['gartner',
#   'linux',
#   'piraci',
#   'claim',
#   'pant',
#   'claim',
#   'expert',
#   'gartner',
#   'group',
#   'linux',
#   'download',
#   'cover',
#   'piraci',
#   'dismiss',
#   'open',
#   'sourc',
#   'industri',
#   'associ',
#   'osia'],
#  ['sex',
#   'patch',
#   'cool',
#   'fda',
#   'ardor',
#   'question',
#   'effect',
#   'longterm',
#   'safeti',
#   'testosteron',
#   'patch',
#   'design',
#   'boost',
#   'woman',
#   'sex',
#   'drive',
#   'feder',
#   'regul',
#   'wonder',
#   'whether',
#   'approv',
#   'product'],
#  ['mood',
#   'mix',
#   'among',
#   'darfur',
#   'rebel',
#   'ahead',
#   'talk',
#   'reuter',
#   'reuter',
#   'sudanes',
#   'rebel',
#   'commanderin',
#   'camp',
#   'darfur',
#   'tell',
#   'troop',
#   'hope',
#   'peacebut',
#   'hour',
#   'march',
#   'away',
#   'young',
#   'men',
#   'say',
#   'areconvinc',
#   'sudan',
#   'want',
#   'drive',
#   'land'],
#  ['video',
#   'game',
#   'teach',
#   'handey',
#   'coordin',
#   'washington',
#   'reuter',
#   'video',
#   'game',
#   'often',
#   'malign',
#   'littl',
#   'redeem',
#   'valu',
#   'becom',
#   'way',
#   'firefight',
#   'soldier',
#   'currenc',
#   'trader',
#   'colleg',
#   'administr',
#   'hone',
#   'skill'],
#  ['poultri',
#   'produc',
#   'stock',
#   'fall',
#   'percent',
#   'new',
#   'york',
#   'reuter',
#   'poultri',
#   'produc',
#   'sanderson',
#   'farm',
#   'inc',
#   'href',
#   'said',
#   'tuesday',
#   'quarterli',
#   'profit',
#   'doubl',
#   'strong',
#   'demand',
#   'warn',
#   'lower',
#   'wholesal',
#   'price',
#   'higher',
#   'grain',
#   'cost',
#   'spark',
#   'percent',
#   'drop',
#   'share'],
#  ['softwar',
#   'bug',
#   'rais',
#   'spectr',
#   'death',
#   'flaw',
#   'softwar',
#   'code',
#   'use',
#   'numer',
#   'microsoft',
#   'applic',
#   'render',
#   'imag',
#   'mean',
#   'special',
#   'construct',
#   'imag',
#   'file',
#   'could',
#   'hijack',
#   'comput',
#   'spread',
#   'viru'],
#  ['harri',
#   'say',
#   'sorri',
#   'paparazzi',
#   'scuffl',
#   'london',
#   'princ',
#   'harri',
#   'make',
#   'public',
#   'apolog',
#   'scuffl',
#   'photograph',
#   'outsid',
#   'london',
#   'nightclub',
#   'spokesperson',
#   'said',
#   'saturday'],
#  ['exbbc',
#   'journalist',
#   'blast',
#   'govern',
#   'hutton',
#   'edinburgh',
#   'reuter',
#   'former',
#   'bbc',
#   'journalist',
#   'andrew',
#   'gilligan',
#   'harsh',
#   'word',
#   'toni',
#   'blair',
#   'govern',
#   'bbc',
#   'board',
#   'governor',
#   'saturday',
#   'first',
#   'public',
#   'appear',
#   'sinc',
#   'resign',
#   'wake',
#   'hutton',
#   'report'],
#  ['expm',
#   'madrid',
#   'blast',
#   'file',
#   'spain',
#   'prime',
#   'minist',
#   'accus',
#   'govern',
#   'succeed',
#   'order',
#   'destruct',
#   'comput',
#   'record',
#   'march',
#   'madrid',
#   'train',
#   'bomb',
#   'attempt',
#   'influenc',
#   'outcom',
#   'elect',
#   'held',
#   'three',
#   'day',
#   'later'],
#  ['uk',
#   'brown',
#   'want',
#   'reform',
#   'eu',
#   'british',
#   'chancellor',
#   'exchequ',
#   'gordon',
#   'brown',
#   'say',
#   'complain',
#   'european',
#   'union',
#   'week',
#   'alloc',
#   'govern',
#   'contract'],
#  ['opec',
#   'plan',
#   'discuss',
#   'rais',
#   'output',
#   'ceil',
#   'vienna',
#   'opec',
#   'oil',
#   'minist',
#   'meet',
#   'wednesday',
#   'vienna',
#   'consid',
#   'chang',
#   'group',
#   'formal',
#   'output',
#   'ceil',
#   'even',
#   'crude',
#   'price',
#   'remain',
#   'high',
#   'despit',
#   'cartel',
#   'effort',
#   'lower'],
#  ['afghan',
#   'elect',
#   'notebook',
#   'count',
#   'admit',
#   'fast',
#   'asleep',
#   'moment',
#   'came',
#   'although',
#   'moment',
#   'realli',
#   'moment',
#   'midafternoon',
#   'sunday',
#   'octob'],
#  ['race',
#   'driver',
#   'kill',
#   'crash',
#   'race',
#   'car',
#   'driver',
#   'tommi',
#   'baldwin',
#   'kill',
#   'crash',
#   'thompson',
#   'intern',
#   'speedway',
#   'featherlit',
#   'modifi',
#   'race'],
#  ['michoud',
#   'cheer',
#   'support',
#   'space',
#   'shuttl',
#   'nasa',
#   'decis',
#   'reconsid',
#   'use',
#   'space',
#   'shuttl',
#   'repair',
#   'orbit',
#   'hubbl',
#   'space',
#   'telescop',
#   'potenti',
#   'good',
#   'news',
#   'eastern',
#   'new',
#   'orlean',
#   'plant',
#   'make',
#   'extern',
#   'fuel',
#   'tank',
#   'shuttl',
#   'plant',
#   'spokesman',
#   'said',
#   'thursday'],
#  ['red',
#   'sox',
#   'player',
#   'file',
#   'free',
#   'agenc',
#   'world',
#   'champion',
#   'boston',
#   'red',
#   'sox',
#   'team',
#   'member',
#   'derek',
#   'low',
#   'second',
#   'left',
#   'pick',
#   'confetti',
#   'hair',
#   'jay',
#   'leno',
#   'mike',
#   'timlin',
#   'far',
#   'left',
#   'alan',
#   'embre',
#   'david',
#   'ortiz',
#   'dave',
#   'robert',
#   'far',
#   'right',
#   'look',
#   'visit',
#   'tonight',
#   'show',
#   'jay',
#   'leno'],
#  ['oldest',
#   'coach',
#   'nba',
#   'hubi',
#   'brown',
#   'retir',
#   'hubi',
#   'brown',
#   'oldest',
#   'coach',
#   'nba',
#   'age',
#   'retir',
#   'coach',
#   'memphi',
#   'grizzli',
#   'thursday',
#   'health',
#   'reason',
#   'accord',
#   'tnt',
#   'thursday',
#   'night',
#   'break',
#   'news'],
#  ['kmart',
#   'buy',
#   'sear',
#   'billion',
#   'deal',
#   'new',
#   'york',
#   'reuter',
#   'discount',
#   'retail',
#   'kmart',
#   'hold',
#   'corp',
#   'href',
#   'buy',
#   'depart',
#   'store',
#   'oper',
#   'sear',
#   'roebuck',
#   'co',
#   'href',
#   'billion',
#   'deal',
#   'unveil',
#   'wednesday',
#   'creat',
#   'thirdlargest',
#   'us',
#   'retail'],
#  ['exoa',
#   'head',
#   'arrest',
#   'scandalhit',
#   'former',
#   'head',
#   'organis',
#   'american',
#   'state',
#   'arrest',
#   'nativ',
#   'costa',
#   'rica'],
#  ['pont',
#   'confid',
#   'kasprowicz',
#   'london',
#   'australia',
#   'captain',
#   'ricki',
#   'pont',
#   'admit',
#   'form',
#   'michael',
#   'kasprowicz',
#   'left',
#   'world',
#   'champion',
#   'problem',
#   'solv',
#   'ahead',
#   'icc',
#   'champion',
#   'trophi',
#   'get',
#   'underway',
#   'england',
#   'friday'],
#  ['florida',
#   'st',
#   'nip',
#   'wake',
#   'forest',
#   'ap',
#   'ap',
#   'xavier',
#   'beitia',
#   'kick',
#   'field',
#   'goal',
#   'play',
#   'help',
#   'florida',
#   'state',
#   'pull',
#   'surprisingli',
#   'close',
#   'victori',
#   'wake',
#   'forest',
#   'saturday'],
#  ['studi',
#   'nicotin',
#   'addict',
#   'advanc',
#   'scientist',
#   'said',
#   'decad',
#   'nicotin',
#   'major',
#   'addict',
#   'compon',
#   'cigarett',
#   'exactli',
#   'chemic',
#   'depend',
#   'result',
#   'nicotin',
#   'interact'],
#  ['manassa',
#   'count',
#   'new',
#   'district',
#   'manassa',
#   'took',
#   'major',
#   'step',
#   'week',
#   'toward',
#   'expand',
#   'boost',
#   'downtown'],
#  ['china',
#   'shun',
#   'talk',
#   'taiwan',
#   'powel',
#   'call',
#   'dialogu',
#   'get',
#   'break',
#   'news',
#   'smart',
#   'mobil',
#   'phone',
#   'philippin',
#   'send',
#   'break',
#   'beij',
#   'china',
#   'wednesday',
#   'reject',
#   'call',
#   'us',
#   'secretari',
#   'state',
#   'colin',
#   'powel',
#   'engag',
#   'taiwan',
#   'dialogu'],
#  ['jackson',
#   'book',
#   'rip',
#   'kobe',
#   'come',
#   'former',
#   'coach',
#   'phil',
#   'jackson',
#   'quotth',
#   'last',
#   'season',
#   'team',
#   'search',
#   'soul',
#   'quot',
#   'diari',
#   'laker',
#   'season',
#   'end',
#   'nba',
#   'final',
#   'loss',
#   'piston'],
#  ['major',
#   'paedophil',
#   'trial',
#   'begin',
#   'portug',
#   'afp',
#   'afp',
#   'seven',
#   'peopl',
#   'includ',
#   'popular',
#   'tv',
#   'star',
#   'former',
#   'diplomat',
#   'went',
#   'trial',
#   'portug',
#   'highprofil',
#   'child',
#   'abus',
#   'case',
#   'involv',
#   'minor',
#   'network',
#   'staterun',
#   'children',
#   'home'],
#  ['firm',
#   'buy',
#   'rous',
#   'deal',
#   'boston',
#   'landmark',
#   'chang',
#   'hand',
#   'yesterday',
#   'rous',
#   'compani',
#   'develop',
#   'owner',
#   'faneuil',
#   'hall',
#   'marketplac',
#   'agre',
#   'purchas',
#   'gener',
#   'growth',
#   'properti',
#   'inc',
#   'chicago'],
#  ['europ',
#   'top',
#   'wood',
#   'mickelson',
#   'struggl',
#   'bloomfield',
#   'hill',
#   'michigan',
#   'reuter',
#   'heavyweight',
#   'unit',
#   'state',
#   'duo',
#   'tiger',
#   'wood',
#   'phil',
#   'mickelson',
#   'track',
#   'second',
#   'defeat',
#   'day',
#   'europ',
#   'maintain',
#   'stranglehold',
#   'ryder',
#   'cup',
#   'friday'],
#  ['glass',
#   'look',
#   'half',
#   'empti',
#   'jd',
#   'wetherspoon',
#   'pub',
#   'group',
#   'jd',
#   'wetherspoon',
#   'today',
#   'said',
#   'sale',
#   'slowdown',
#   'second',
#   'half',
#   'taken',
#   'fizz',
#   'annual',
#   'profit',
#   'citi',
#   'centr',
#   'pub',
#   'bar',
#   'oper',
#   'run',
#   'around',
#   'outlet',
#   'includ',
#   'stand'],
#  ['yahoo',
#   'buy',
#   'email',
#   'search',
#   'compani',
#   'yahoo',
#   'inc',
#   'one',
#   'largest',
#   'onlin',
#   'base',
#   'compani',
#   'said',
#   'bought',
#   'privat',
#   'held',
#   'email',
#   'search',
#   'firm',
#   'stata',
#   'lab',
#   'yahoo',
#   'move',
#   'compet',
#   'microsoft',
#   'googl',
#   'email',
#   'search',
#   'function'],
#  ['hilton',
#   'profit',
#   'soar',
#   'hotel',
#   'game',
#   'compani',
#   'hilton',
#   'reap',
#   'percent',
#   'rise',
#   'firsthalf',
#   'profit',
#   'beat',
#   'forecast',
#   'reiter',
#   'cautiou',
#   'outlook',
#   'recoveri',
#   'prospect',
#   'hotel',
#   'busi'],
#  ['glazer',
#   'eye',
#   'man',
#   'utd',
#   'bid',
#   'american',
#   'tycoon',
#   'malcolm',
#   'glazer',
#   'reportedli',
#   'pois',
#   'launch',
#   'takeov',
#   'bid',
#   'manchest',
#   'unit'],
#  ['sear',
#   'take',
#   'cyberspac',
#   'sear',
#   'roebuck',
#   'co',
#   'success',
#   'sold',
#   'tool',
#   'applianc',
#   'web',
#   'count',
#   'magic',
#   'bedspread',
#   'sweater',
#   'thank',
#   'part',
#   'expertis',
#   'gain',
#   'purchas',
#   'land',
#   'end'],
#  ['brokaw',
#   'jen',
#   'show',
#   'support',
#   'rather',
#   'new',
#   'york',
#   'acknowledg',
#   'mistak',
#   'cb',
#   'anchor',
#   'dan',
#   'rather',
#   'minut',
#   'report',
#   'question',
#   'presid',
#   'bush',
#   'servic',
#   'nation',
#   'guard',
#   'compet',
#   'news',
#   'anchor',
#   'tom',
#   'brokaw',
#   'peter',
#   'jen',
#   'offer',
#   'support',
#   'saturday',
#   'beleagu',
#   'newsman',
#   'brokaw',
#   'blast',
#   'call',
#   'attempt',
#   'demon',
#   'cb',
#   'rather',
#   'internet',
#   'complaint',
#   'report',
#   'first',
#   'surfac'],
#  ['china',
#   'plan',
#   'enact',
#   'law',
#   'secess',
#   'analyst',
#   'say',
#   'move',
#   'could',
#   'legal',
#   'bind',
#   'communist',
#   'parti',
#   'leadership',
#   'follow',
#   'longstand',
#   'threat',
#   'attack',
#   'taiwan',
#   'island',
#   'formal',
#   'declar',
#   'independ'],
#  ['ejunk',
#   'recycl',
#   'still',
#   'infanc',
#   'ap',
#   'ap',
#   'offic',
#   'depot',
#   'inc',
#   'store',
#   'ran',
#   'electron',
#   'recycl',
#   'drive',
#   'last',
#   'summer',
#   'accept',
#   'everyth',
#   'cell',
#   'phone',
#   'televis',
#   'store',
#   'overwhelm',
#   'amount',
#   'etrash',
#   'receiv'],
#  ['exenron',
#   'ceo',
#   'seek',
#   'separ',
#   'trial',
#   'houston',
#   'reuter',
#   'lawyer',
#   'former',
#   'enron',
#   'corp',
#   'href',
#   'chief',
#   'execut',
#   'jeffrey',
#   'skill',
#   'friday',
#   'ask',
#   'feder',
#   'court',
#   'separ',
#   'trial',
#   'former',
#   'boss',
#   'ken',
#   'lay',
#   'charg',
#   'link',
#   'downfal',
#   'energi',
#   'compani'],
#  ['warn',
#   'human',
#   'death',
#   'bird',
#   'flu',
#   'latest',
#   'victim',
#   'world',
#   'health',
#   'organ',
#   'offici',
#   'warn',
#   'likelihood',
#   'human',
#   'death',
#   'bird',
#   'flu',
#   'viru',
#   'death',
#   'teenag',
#   'boy',
#   'thailand',
#   'week'],
#  ['moratorium',
#   'web',
#   'tax',
#   'advanc',
#   'congress',
#   'yesterday',
#   'clear',
#   'way',
#   'keep',
#   'access',
#   'internet',
#   'larg',
#   'free',
#   'tax',
#   'next',
#   'three',
#   'year',
#   'break',
#   'yearlong',
#   'deadlock'],
#  ['hub',
#   'school',
#   'make',
#   'grade',
#   'scienc',
#   'grant',
#   'record',
#   'million',
#   'grant',
#   'announc',
#   'today',
#   'revolution',
#   'scienc',
#   'teach',
#   'throughout',
#   'boston',
#   'public',
#   'school',
#   'offici',
#   'said'],
#  ['alcatel',
#   'bolster',
#   'us',
#   'presenc',
#   'reuter',
#   'reuter',
#   'alcatel',
#   'expand',
#   'itsfoothold',
#   'key',
#   'north',
#   'american',
#   'market',
#   'acquisitionof',
#   'mobil',
#   'softwar',
#   'provid',
#   'confer',
#   'technologybusi',
#   'million'],
#  ['us',
#   'approv',
#   'kidney',
#   'dialysi',
#   'drug',
#   'offer',
#   'time',
#   'relief',
#   'regulatori',
#   'approv',
#   'also',
#   'boost',
#   'embattl',
#   'drug',
#   'sector',
#   'fear',
#   'follow',
#   'seri',
#   'safeti',
#   'crise',
#   'us',
#   'food',
#   'drug',
#   'administr',
#   'would',
#   'get',
#   'tougher',
#   'new',
#   'drug'],
#  ['putin',
#   'tactic',
#   'unlik',
#   'stem',
#   'terror',
#   'ap',
#   'ap',
#   'presid',
#   'vladimir',
#   'putin',
#   'say',
#   'fight',
#   'terror',
#   'consolid',
#   'secur',
#   'agenc',
#   'tighten',
#   'polit',
#   'control',
#   'countri',
#   'tough',
#   'tactic',
#   'risk',
#   'alien',
#   'public',
#   'support',
#   'need',
#   'alli',
#   'abroad',
#   'seem',
#   'ignor',
#   'plea',
#   'crack',
#   'chechen',
#   'separatist'],
#  ['battl',
#   'brew',
#   'california',
#   'emiss',
#   'rule',
#   'automak',
#   'suv',
#   'owner',
#   'feder',
#   'govern',
#   'may',
#   'balk',
#   'state',
#   'latest',
#   'effort',
#   'curb',
#   'air',
#   'pollut',
#   'daniel',
#   'wood',
#   'staff',
#   'writer',
#   'christian',
#   'scienc',
#   'monitor'],
#  ['explos',
#   'target',
#   'bangladesh',
#   'opposit',
#   'ralli',
#   'bangladesh',
#   'seri',
#   'explos',
#   'opposit',
#   'parti',
#   'ralli',
#   'former',
#   'prime',
#   'minist',
#   'speak',
#   'kill',
#   'least',
#   'peopl',
#   'wound',
#   'dozen',
#   'other'],
#  ['us',
#   'ad',
#   'job',
#   'septemb',
#   'fewer',
#   'expect',
#   'unemploy',
#   'rate',
#   'remain',
#   'unchang',
#   'percent',
#   'figur',
#   'expect',
#   'sharpen',
#   'presidenti',
#   'debat',
#   'domest',
#   'polici',
#   'set',
#   'tonight'],
#  ['us',
#   'goal',
#   'sight',
#   'win',
#   'panama',
#   'unit',
#   'state',
#   'region',
#   'final',
#   'qualifi',
#   'world',
#   'cup',
#   'american',
#   'lead',
#   'group',
#   'point',
#   'two',
#   'win',
#   'two',
#   'tie',
#   'beat',
#   'panamanian',
#   'tonight',
#   'rfk',
#   'stadium',
#   'us',
#   'squad',
#   'secur',
#   'spot',
#   'final',
#   'six',
#   'concacaf'],
#  ['tenman',
#   'psg',
#   'clinch',
#   'seventh',
#   'straight',
#   'win',
#   'marseil',
#   'tenman',
#   'pari',
#   'st',
#   'germain',
#   'clinch',
#   'seventh',
#   'consecut',
#   'victori',
#   'archriv',
#   'olympiqu',
#   'marseil',
#   'triumph',
#   'ligu',
#   'sunday',
#   'thank',
#   'secondhalf',
#   'winner',
#   'substitut',
#   'edouard',
#   'ciss'],
#  ['uk',
#   'soldier',
#   'killer',
#   'may',
#   'european',
#   'suicid',
#   'bomber',
#   'kill',
#   'three',
#   'black',
#   'watch',
#   'soldier',
#   'white',
#   'suggest',
#   'british',
#   'troop',
#   'european',
#   'terrorist'],
#  ['european',
#   'evacu',
#   'coast',
#   'european',
#   'nation',
#   'led',
#   'franc',
#   'evacu',
#   'nation',
#   'ivori',
#   'coast',
#   'thursday',
#   'explos',
#   'antifrench',
#   'violenc',
#   'made',
#   'even',
#   'longtim',
#   'resid',
#   'rush',
#   'pack',
#   'bag'],
#  ['get',
#   'list',
#   'netscap',
#   'open',
#   'directori',
#   'project',
#   'get',
#   'list',
#   'netscap',
#   'open',
#   'directori',
#   'projectwhen',
#   'decid',
#   'major',
#   'search',
#   'engin',
#   'directori',
#   'want',
#   'websit',
#   'list',
#   'overlook',
#   'one',
#   'import',
#   'one',
#   'dmoz',
#   'short',
#   'form',
#   'directori',
#   'mozilla',
#   'dmoz',
#   'anoth',
#   'name',
#   'open'],
#  ['sun',
#   'microsoft',
#   'cite',
#   'progress',
#   'perfect',
#   'microsoft',
#   'sun',
#   'microsystem',
#   'say',
#   'warm',
#   'take',
#   'time',
#   'deliv',
#   'grand',
#   'promis',
#   'platform',
#   'interoper',
#   'announc',
#   'last',
#   'spring'],
#  ['iran',
#   'say',
#   'halt',
#   'nuclear',
#   'technolog',
#   'drive',
#   'iran',
#   'sunday',
#   'reject',
#   'european',
#   'demand',
#   'halt',
#   'pursuit',
#   'nuclear',
#   'technolog',
#   'reiter',
#   'readi',
#   'provid',
#   'assur',
#   'would',
#   'use',
#   'technolog',
#   'build',
#   'atom',
#   'weapon'],
#  ['isp',
#   'file',
#   'suit',
#   'spammer',
#   'washingtonpostcom',
#   'washingtonpostcom',
#   'four',
#   'nation',
#   'largest',
#   'onlin',
#   'provid',
#   'yesterday',
#   'announc',
#   'new',
#   'round',
#   'lawsuit',
#   'aim',
#   'email',
#   'spammer',
#   'includ',
#   'first',
#   'major',
#   'case',
#   'involv',
#   'spam',
#   'sent',
#   'via',
#   'instant',
#   'messag',
#   'servic'],
#  ['darfur',
#   'rebel',
#   'say',
#   'power',
#   'deal',
#   'first',
#   'disarm',
#   'later',
#   'abuja',
#   'nigeria',
#   'reuter',
#   'rebel',
#   'sudan',
#   'darfur',
#   'region',
#   'thursday',
#   'reject',
#   'call',
#   'disarm',
#   'confin',
#   'fighter',
#   'base',
#   'polit',
#   'solut',
#   'conflict'],
#  ['michigan',
#   'escap',
#   'san',
#   'diego',
#   'state',
#   'braylon',
#   'edward',
#   'caught',
#   'eight',
#   'pass',
#   'yard',
#   'two',
#   'touchdown',
#   'includ',
#   'gamewinn',
#   'third',
#   'quarter',
#   'michigan'],
#  ['prospect',
#   'juror',
#   'grill',
#   'prospect',
#   'juror',
#   'kobe',
#   'bryant',
#   'sexual',
#   'assault',
#   'case',
#   'ask',
#   'feel',
#   'racial',
#   'prejudic',
#   'interraci',
#   'relationship',
#   'marit',
#   'infidel',
#   'justic',
#   'rich',
#   'famou'],
#  ['charter',
#   'lose',
#   'anoth',
#   'top',
#   'exec',
#   'charter',
#   'commun',
#   'chtrnasdaq',
#   'news',
#   'research',
#   'lost',
#   'second',
#   'top',
#   'execut',
#   'month',
#   'friday',
#   'resign',
#   'oper',
#   'chief',
#   'maggi',
#   'bellvil'],
#  ['bryan',
#   'brother',
#   'win',
#   'master',
#   'cup',
#   'open',
#   'ap',
#   'ap',
#   'secondseed',
#   'bob',
#   'mike',
#   'bryan',
#   'unit',
#   'state',
#   'defeat',
#   'gaston',
#   'etli',
#   'martin',
#   'rodriguez',
#   'saturday',
#   'openinground',
#   'doubl',
#   'match',
#   'atp',
#   'master',
#   'cup'],
#  ['sun',
#   'releas',
#   'solari',
#   'free',
#   'novemb',
#   'web',
#   'host',
#   'industri',
#   'review',
#   'effort',
#   'win',
#   'back',
#   'lost',
#   'market',
#   'share',
#   'sun',
#   'microsystem',
#   'suncom',
#   'releas',
#   'solari',
#   'latest',
#   'version',
#   'compani',
#   'unixbas',
#   'oper',
#   'system',
#   'softwar',
#   'free',
#   'monday'],
#  ['washingtonbound',
#   'expo',
#   'hire',
#   'ticket',
#   'agenc',
#   'expo',
#   'clear',
#   'anoth',
#   'logist',
#   'hurdl',
#   'move',
#   'washington',
#   'friday',
#   'announc',
#   'agreement',
#   'ticketmast',
#   'handl',
#   'ticket',
#   'sale'],
#  ['dale',
#   'mcfeatter',
#   'massacr',
#   'iraq',
#   'sh',
#   'bush',
#   'administr',
#   'strategi',
#   'exit',
#   'iraq',
#   'depend',
#   'heavili',
#   'perhap',
#   'even',
#   'sole',
#   'train',
#   'enough',
#   'iraqi',
#   'soldier',
#   'polic',
#   'secur',
#   'countri',
#   'handov',
#   'elect',
#   'iraqi',
#   'govern'],
#  ['deutsch',
#   'bank',
#   'sell',
#   'scudder',
#   'busi',
#   'legg',
#   'mason',
#   'new',
#   'york',
#   'dow',
#   'jonesap',
#   'deutsch',
#   'bank',
#   'ag',
#   'germani',
#   'plan',
#   'sell',
#   'new',
#   'york',
#   'philadelphia',
#   'cincinnati',
#   'chicago',
#   'offic',
#   'scudder',
#   'privat',
#   'invest',
#   'counsel',
#   'legg',
#   'mason',
#   'inc'],
#  ['id',
#   'biomed',
#   'shot',
#   'arm',
#   'id',
#   'biomed',
#   'nasdaq',
#   'idb',
#   'recent',
#   'show',
#   'import',
#   'right',
#   'place',
#   'right',
#   'time',
#   'especi',
#   'vaccin',
#   'busi'],
#  ['bush',
#   'defend',
#   'war',
#   'despit',
#   'arm',
#   'report',
#   'us',
#   'presid',
#   'georg',
#   'bush',
#   'thursday',
#   'defend',
#   'decis',
#   'go',
#   'war',
#   'quotuniqu',
#   'threat',
#   'quot',
#   'iraq',
#   'despit',
#   'offici',
#   'us',
#   'report',
#   'baghdad',
#   'weapon',
#   'mass',
#   'destruct',
#   'shiit',
#   'militia',
#   'pledg',
#   'disarm'],
#  ['readi',
#   'mix',
#   'fortun',
#   'rmc',
#   'group',
#   'found',
#   'danish',
#   'engin',
#   'kjeld',
#   'ammentorp',
#   'made',
#   'trade',
#   'loss',
#   'first',
#   'year',
#   'readi',
#   'mix',
#   'concret',
#   'australia',
#   'revers',
#   'uk',
#   'rival',
#   'began',
#   'expand'],
#  ['suprem',
#   'court',
#   'hear',
#   'file',
#   'share',
#   'case',
#   'us',
#   'suprem',
#   'court',
#   'agre',
#   'friday',
#   'consid',
#   'case',
#   'like',
#   'signific',
#   'impact',
#   'music',
#   'video',
#   'electron',
#   'industri'],
#  ['weak',
#   'employ',
#   'report',
#   'cast',
#   'doubt',
#   'us',
#   'econom',
#   'strength',
#   'washington',
#   'afp',
#   'weakerthananticip',
#   'report',
#   'us',
#   'labor',
#   'market',
#   'show',
#   'job',
#   'ad',
#   'novemb',
#   'cast',
#   'fresh',
#   'doubt',
#   'pace',
#   'growth',
#   'world',
#   'largest',
#   'economi'],
#  ['lose',
#   'pace',
#   'like',
#   'runner',
#   'slow',
#   'finish',
#   'line',
#   'us',
#   'economi',
#   'may',
#   'lose',
#   'momentum',
#   'approach',
#   'novemb',
#   'elect'],
#  ['iran',
#   'vow',
#   'freez',
#   'uranium',
#   'enrich',
#   'iran',
#   'promis',
#   'meet',
#   'monday',
#   'deadlin',
#   'suspend',
#   'uranium',
#   'enrich',
#   'process',
#   'could',
#   'use',
#   'make',
#   'nuclear',
#   'weapon',
#   'freez',
#   'could',
#   'spare',
#   'un',
#   'secur',
#   'council',
#   'sanction'],
#  ['soni',
#   'group',
#   'agre',
#   'principl',
#   'buy',
#   'mgm',
#   'philadelphia',
#   'reuter',
#   'group',
#   'head',
#   'soni',
#   'corp',
#   'href',
#   'agre',
#   'principl',
#   'buy',
#   'hollywood',
#   'film',
#   'studio',
#   'metrogoldwynmay',
#   'href',
#   'nearli',
#   'billion',
#   'monday',
#   'sourc',
#   'close',
#   'deal',
#   'said'],
#  ['microsoft',
#   'delay',
#   'auto',
#   'updat',
#   'enterpris',
#   'although',
#   'monday',
#   'day',
#   'microsoft',
#   'began',
#   'push',
#   'window',
#   'xp',
#   'servic',
#   'pack',
#   'enterpris',
#   'chang',
#   'mind',
#   'last',
#   'minut',
#   'delay',
#   'automat',
#   'updat',
#   'week'],
#  ['suprem',
#   'court',
#   'hear',
#   'appeal',
#   'convict',
#   'killerrapist',
#   'larri',
#   'fisher',
#   'canadian',
#   'press',
#   'canadian',
#   'press',
#   'ottawa',
#   'cp',
#   'man',
#   'convict',
#   'brutal',
#   'murder',
#   'rape',
#   'kept',
#   'david',
#   'milgaard',
#   'wrong',
#   'imprison',
#   'year',
#   'abl',
#   'appeal',
#   'case',
#   'suprem',
#   'court',
#   'canada'],
#  ['voeller',
#   'set',
#   'coach',
#   'roma',
#   'former',
#   'germani',
#   'coach',
#   'rudi',
#   'voeller',
#   'reveal',
#   'close',
#   'take',
#   'roma',
#   'coach',
#   'follow',
#   'resign',
#   'cesar',
#   'prandelli'],
#  ['sept',
#   'quick',
#   'take',
#   'week',
#   'indianapoli',
#   'green',
#   'bay',
#   'class',
#   'nfl',
#   'quarterback',
#   'squar',
#   'one',
#   'class',
#   'nfl',
#   'pass',
#   'defens',
#   'predict',
#   'result',
#   'highli',
#   'entertain',
#   'shootout',
#   'saw',
#   'peyton',
#   'man'],
#  ['egyptian',
#   'petit',
#   'seek',
#   'term',
#   'limit',
#   'ap',
#   'ap',
#   'politician',
#   'intellectu',
#   'vow',
#   'saturday',
#   'push',
#   'constitut',
#   'amend',
#   'stop',
#   'egyptian',
#   'presid',
#   'hosni',
#   'mubarak',
#   'serv',
#   'anoth',
#   'term',
#   'offic'],
#  ['mass',
#   'biotech',
#   'boost',
#   'statur',
#   'massachusett',
#   'biotechnolog',
#   'council',
#   'recent',
#   'track',
#   'record',
#   'beacon',
#   'hill',
#   'envi',
#   'industri',
#   'lobbi',
#   'issu',
#   'block',
#   'drug',
#   'pricecontrol',
#   'effort',
#   'state',
#   'fund',
#   'job',
#   'train',
#   'council',
#   'success',
#   'persuad',
#   'democratcontrol',
#   'legislatur',
#   'republican',
#   'governor',
#   'mitt',
#   'romney',
#   'vote',
#   'way'],
#  ['faster',
#   'checkclear',
#   'benefit',
#   'us',
#   'new',
#   'law',
#   'take',
#   'effect',
#   'today',
#   'sure',
#   'posit',
#   'impact',
#   'nation',
#   'payment',
#   'system',
#   'also',
#   'like',
#   'impact',
#   'pull',
#   'checkbook',
#   'time',
#   'pay',
#   'bill'],
#  ['live',
#   'india',
#   'australia',
#   'australia',
#   'took',
#   'complet',
#   'control',
#   'first',
#   'test',
#   'day',
#   'three',
#   'bangalor',
#   'build',
#   'lead',
#   'india',
#   'india',
#   'bowl',
#   'ad',
#   'last',
#   'three',
#   'wicket',
#   'parthiv',
#   'patel',
#   'make',
#   'patient'],
#  ['judg',
#   'rule',
#   'close',
#   'home',
#   'quotig',
#   'verifi',
#   'colombian',
#   'judg',
#   'oscar',
#   'buitrago',
#   'rey',
#   'one',
#   'three',
#   'offici',
#   'suspend',
#   'fig',
#   'world',
#   'gymnast',
#   'bodi',
#   'august',
#   'live',
#   'work',
#   'ohio',
#   'sever',
#   'year',
#   'quot',
#   'magazin',
#   'websit',
#   'said',
#   'sunday'],
#  ['dell',
#   'recal',
#   'million',
#   'notebook',
#   'ac',
#   'adapt',
#   'dell',
#   'friday',
#   'voluntarili',
#   'recal',
#   'million',
#   'ac',
#   'adapt',
#   'notebook',
#   'receiv',
#   'seven',
#   'report',
#   'adapt',
#   'overh',
#   'pose',
#   'risk',
#   'fire',
#   'electr',
#   'shock',
#   'user'],
#  ['jet',
#   'fire',
#   'round',
#   'school',
#   'us',
#   'militari',
#   'investig',
#   'thursday',
#   'nation',
#   'guard',
#   'fighter',
#   'jet',
#   'fire',
#   'round',
#   'new',
#   'jersey',
#   'school',
#   'round',
#   'fire',
#   'nighttim',
#   'train'],
#  ['philli',
#   'plan',
#   'becom',
#   'one',
#   'big',
#   'hot',
#   'spot',
#   'pc',
#   'world',
#   'pc',
#   'world',
#   'citi',
#   'build',
#   'world',
#   'largest',
#   'mesh',
#   'wifi',
#   'network',
#   'spread',
#   'internet',
#   'access'],
#  ['desktop',
#   'search',
#   'get',
#   'seriou',
#   'launch',
#   'microsoft',
#   'test',
#   'version',
#   'throw',
#   'gauntlet',
#   'googl',
#   'yahoo',
#   'ask',
#   'jeev',
#   'gear',
#   'battl',
#   'brew'],
#  ['carter',
#   'place',
#   'injur',
#   'list',
#   'toronto',
#   'sport',
#   'network',
#   'toronto',
#   'raptor',
#   'allstar',
#   'swingman',
#   'vinc',
#   'carter',
#   'place',
#   'injur',
#   'list',
#   'friday',
#   'test',
#   'reveal',
#   'mild',
#   'strain',
#   'left',
#   'achil',
#   'tendon'],
#  ['world',
#   'poll',
#   'presid',
#   'start',
#   'wartorn',
#   'afghanistan',
#   'world',
#   'news',
#   'kabul',
#   'vote',
#   'began',
#   'afghanistan',
#   'saturday',
#   'first',
#   'direct',
#   'presidenti',
#   'elect',
#   'countri',
#   'histori'],
#  ['darfur',
#   'peac',
#   'talk',
#   'overshadow',
#   'fight',
#   'reuter',
#   'reuter',
#   'peac',
#   'talk',
#   'sudan',
#   'wartorn',
#   'darfurregion',
#   'got',
#   'way',
#   'monday',
#   'nigeria',
#   'capit',
#   'overshadowedbi',
#   'fight',
#   'rebel',
#   'govern',
#   'forc',
#   'vastdesert',
#   'area'],
#  ['jpmorgan',
#   'dimon',
#   'three',
#   'month',
#   'job',
#   'reshuffl',
#   'leadership',
#   'jami',
#   'dimon',
#   'wait',
#   'less',
#   'three',
#   'month',
#   'becom',
#   'presid',
#   'jpmorgan',
#   'chase',
#   'amp',
#   'co',
#   'instal',
#   'financ',
#   'chief',
#   'banker',
#   'work',
#   'decad'],
#  ['schalk',
#   'face',
#   'media',
#   'frenzi',
#   'london',
#   'longawait',
#   'clash',
#   'barbarian',
#   'black',
#   'cardiff',
#   'saturday',
#   'given',
#   'huge',
#   'shot',
#   'arm',
#   'news',
#   'springbok',
#   'given',
#   'world',
#   'best',
#   'rugbi',
#   'player',
#   'flanker',
#   'schalk',
#   'burger',
#   'permiss',
#   'play'],
#  ['foreign',
#   'retail',
#   'enclosur',
#   'land',
#   'competit',
#   'china',
#   'report',
#   'anoth',
#   'quotchampion',
#   'supermarket',
#   'quot',
#   'french',
#   'retail',
#   'carrefour',
#   'open',
#   'soon',
#   'guangm',
#   'villag',
#   'haidian',
#   'district',
#   'beij'],
#  ['indian',
#   'mound',
#   'mystifi',
#   'excav',
#   'vast',
#   'manmad',
#   'mound',
#   'nearli',
#   'remain',
#   'ancient',
#   'citi',
#   'call',
#   'cahokia',
#   'built',
#   'along',
#   'bank',
#   'mississippi',
#   'heyday',
#   'around',
#   'ad',
#   'citi',
#   'bustl',
#   'metropoli',
#   'michel',
#   'delio',
#   'report',
#   'collinsvil',
#   'illinoi'],
#  ['us',
#   'advanc',
#   'falluja',
#   'new',
#   'fight',
#   'erupt',
#   'northern',
#   'iraq',
#   'insurg',
#   'open',
#   'new',
#   'front',
#   'usl',
#   'forc',
#   'today',
#   'mosul',
#   'enorm',
#   'car',
#   'bomb',
#   'baghdad',
#   'kill',
#   'least',
#   'peopl'],
#  ['cleveland',
#   'cruis',
#   'easi',
#   'victori',
#   'carmelo',
#   'anthoni',
#   'search',
#   'silver',
#   'line',
#   'thursday',
#   'could',
#   'use',
#   'one',
#   'late',
#   'start',
#   'nugget',
#   'loss',
#   'cleveland',
#   'cavali',
#   'forc',
#   'denver',
#   'televis',
#   'viewer',
#   'choos',
#   'game',
#   'late',
#   'local'],
#  ['ca',
#   'cut',
#   'percent',
#   'workforc',
#   'comput',
#   'associ',
#   'intern',
#   'inc',
#   'ca',
#   'plan',
#   'cut',
#   'posit',
#   'worldwid',
#   'percent',
#   'workforc',
#   'hope',
#   'shave',
#   'million',
#   'annual',
#   'oper',
#   'cost'],
#  ['bigley',
#   'grant',
#   'irish',
#   'passport',
#   'irish',
#   'govern',
#   'given',
#   'kenneth',
#   'bigley',
#   'kidnap',
#   'iraq',
#   'irish',
#   'passport',
#   'bid',
#   'stress',
#   'nonbritish',
#   'root',
#   'issu',
#   'follow',
#   'appeal',
#   'famili',
#   'dual',
#   'citizenship',
#   'mean'],
#  ['renteria',
#   'sign',
#   'topshelf',
#   'deal',
#   'red',
#   'sox',
#   'gener',
#   'manag',
#   'theo',
#   'epstein',
#   'acknowledg',
#   'edgar',
#   'renteria',
#   'luxuri',
#   'red',
#   'sox',
#   'necess',
#   'there',
#   'noth',
#   'wrong',
#   'get',
#   'key',
#   'bmw',
#   'that',
#   'fourtim',
#   'allstar',
#   'twotim',
#   'gold',
#   'glover',
#   'eye',
#   'red',
#   'sox'],
#  ['gop',
#   'convent',
#   'close',
#   'milder',
#   'protest',
#   'ap',
#   'ap',
#   'week',
#   'ralli',
#   'march',
#   'nearli',
#   'arrest',
#   'left',
#   'antibush',
#   'protest',
#   'drain',
#   'citi',
#   'refut',
#   'alleg',
#   'demonstr',
#   'held',
#   'long',
#   'polic',
#   'custodi'],
#  ['polish',
#   'woman',
#   'hostag',
#   'back',
#   'home',
#   'freed',
#   'iraq',
#   'afp',
#   'afp',
#   'polish',
#   'woman',
#   'hostag',
#   'abduct',
#   'iraq',
#   'three',
#   'week',
#   'ago',
#   'back',
#   'home',
#   'releas',
#   'captor',
#   'said',
#   'treat',
#   'well'],
#  ['american',
#   'earli',
#   'riser',
#   'get',
#   'rude',
#   'awaken',
#   'bloomfield',
#   'township',
#   'mich',
#   'whatev',
#   'magic',
#   'found',
#   'morn',
#   'dew',
#   'yesterday',
#   'lost',
#   'afternoon',
#   'shadow',
#   'oakland',
#   'hill',
#   'countri',
#   'club',
#   'herald',
#   'us',
#   'ryder',
#   'cup',
#   'team',
#   'find',
#   'need',
#   'miracl',
#   'finish',
#   'even',
#   'grander',
#   'one',
#   'script'],
#  ['moral',
#   'clariti',
#   'blur',
#   'darfur',
#   'crisi',
#   'talk',
#   'sudan',
# ...
#   'chip',
#   'spawn',
#   'devic',
#   'wireless',
#   'broadband',
#   'endus',
#   'cost',
#   'less',
#   'wont',
#   'requir',
#   'visit',
#   'servic',
#   'provid',
#   'compani',
#   'execut',
#   'said',
#   'tuesday'],
#  ['sec',
#   'said',
#   'examin',
#   'stock',
#   'price',
#   'big',
#   'broker',
#   'dozen',
#   'brokerag',
#   'firm',
#   'suspect',
#   'fail',
#   'secur',
#   'best',
#   'avail',
#   'price',
#   'stock',
#   'trade',
#   'custom'],
#  ['crack',
#   'rock',
#   'point',
#   'martian',
#   'water',
#   'crack',
#   'rock',
#   'call',
#   'escher',
#   'help',
#   'nasa',
#   'scientist',
#   'reconstruct',
#   'histori',
#   'water',
#   'mar',
#   'say',
#   'crater',
#   'current',
#   'explor',
#   'opportun',
#   'rover',
#   'may',
#   'shape',
#   'second'],
#  ['australia',
#   'amppasx',
#   'declin',
#   'pace',
#   'cole',
#   'woolworth',
#   'australia',
#   'amppasx',
#   'index',
#   'fell',
#   'record',
#   'cole',
#   'myer',
#   'ltd',
#   'drop',
#   'second',
#   'day',
#   'concern',
#   'secondhalf',
#   'earn',
#   'announc',
#   'yesterday',
#   'justifi',
#   'share',
#   'price'],
#  ['florida',
#   'welcom',
#   'urban',
#   'meyer',
#   'avail',
#   'raw',
#   'script',
#   'video',
#   'stori',
#   'present',
#   'pleas',
#   'note',
#   'script',
#   'come',
#   'directli',
#   'tv',
#   'newsroom',
#   'system',
#   'edit',
#   'web',
#   'read'],
#  ['cazenov',
#   'agre',
#   'jp',
#   'morgan',
#   'merger',
#   'cazenov',
#   'invest',
#   'bank',
#   'unit',
#   'advis',
#   'nearli',
#   'half',
#   'britain',
#   'lead',
#   'compani',
#   'merg',
#   'rival',
#   'oper',
#   'run',
#   'jp',
#   'morgan',
#   'end',
#   'year',
#   'independ'],
#  ['miller',
#   'win',
#   'world',
#   'cup',
#   'downhil',
#   'race',
#   'bode',
#   'miller',
#   'unit',
#   'state',
#   'blast',
#   'cours',
#   'way',
#   'win',
#   'men',
#   'world',
#   'cup',
#   'downhil',
#   'ski',
#   'race',
#   'lake',
#   'louis',
#   'alberta',
#   'canada',
#   'saturday',
#   'nov'],
#  ['dossier',
#   'bob',
#   'bell',
#   'review',
#   'season',
#   'renault',
#   'team',
#   'chassi',
#   'technic',
#   'director',
#   'review',
#   'hardfought',
#   'season',
#   'saw',
#   'team',
#   'meet',
#   'object',
#   'prepar',
#   'futur'],
#  ['mussina',
#   'matsui',
#   'lead',
#   'yanke',
#   'past',
#   'red',
#   'sox',
#   'reuter',
#   'reuter',
#   'mike',
#   'mussina',
#   'retir',
#   'first',
#   'face',
#   'hideki',
#   'matsui',
#   'drove',
#   'five',
#   'run'],
#  ['web',
#   'server',
#   'takedown',
#   'call',
#   'speech',
#   'threat',
#   'ap',
#   'ap',
#   'devin',
#   'theriotorr',
#   'member',
#   'feisti',
#   'group',
#   'reporteractivist',
#   'call',
#   'indymedia',
#   'surpris',
#   'two',
#   'fbi',
#   'agent',
#   'show',
#   'seattl',
#   'law',
#   'offic',
#   'say',
#   'visit',
#   'courtesi',
#   'call',
#   'behalf',
#   'swiss',
#   'author'],
#  ['muslim',
#   'could',
#   'prove',
#   'crucial',
#   'elect',
#   'ap',
#   'ap',
#   'muslim',
#   'arabamerican',
#   'taken',
#   'custodi',
#   'sept',
#   'attack',
#   'usl',
#   'war',
#   'rage',
#   'iraq',
#   'mani',
#   'muslim',
#   'oppos',
#   'georg',
#   'bush',
#   'novemb',
#   'presidenti',
#   'elect',
#   'vote',
#   'john',
#   'kerri',
#   'slamdunk',
#   'either'],
#  ['schill',
#   'deliv',
#   'bush',
#   'team',
#   'exec',
#   'shill',
#   'kerri',
#   'curt',
#   'schill',
#   'suppos',
#   'pitch',
#   'year',
#   'endors',
#   'presid',
#   'bush',
#   'autom',
#   'phone',
#   'call',
#   'made',
#   'three',
#   'battleground',
#   'state',
#   'elect',
#   'day'],
#  ['brazil',
#   'rule',
#   'parti',
#   'forc',
#   'runoff',
#   'sao',
#   'paulo',
#   'brazil',
#   'rule',
#   'worker',
#   'parti',
#   'pt',
#   'held',
#   'onto',
#   'mayoralti',
#   'least',
#   'three',
#   'major',
#   'citi',
#   'sunday',
#   'municip',
#   'vote',
#   'face',
#   'tough',
#   'run'],
#  ['appl',
#   'song',
#   'sold',
#   'via',
#   'itun',
#   'appl',
#   'celebr',
#   'yesterday',
#   'announc',
#   'sold',
#   'million',
#   'song',
#   'via',
#   'itun',
#   'music',
#   'store',
#   'despit',
#   'report',
#   'overal',
#   'traffic',
#   'onlin',
#   'music',
#   'store',
#   'drop',
#   'appl'],
#  ['verita',
#   'softwar',
#   'buy',
#   'kvault',
#   'email',
#   'archiv',
#   'new',
#   'york',
#   'verita',
#   'softwar',
#   'largest',
#   'independ',
#   'us',
#   'storag',
#   'softwar',
#   'provid',
#   'buy',
#   'email',
#   'backup',
#   'compani',
#   'kvault',
#   'softwar',
#   'million',
#   'cash',
#   'verita',
#   'said',
#   'tuesday'],
#  ['pillpop',
#   'nation',
#   'american',
#   'use',
#   'prescript',
#   'drug',
#   'pharmaceut',
#   'compani',
#   'cant',
#   'take',
#   'huge',
#   'comfort'],
#  ['us',
#   'birdi',
#   'assault',
#   'seiz',
#   'ub',
#   'cup',
#   'lead',
#   'unit',
#   'state',
#   'team',
#   'abl',
#   'stop',
#   'juggernaut',
#   'partnership',
#   'colin',
#   'montgomeri',
#   'bernhard',
#   'langer',
#   'littl',
#   'els',
#   'slow',
#   'recordset'],
#  ['next',
#   'space',
#   'station',
#   'crew',
#   'launch',
#   'expedit',
#   'latest',
#   'crew',
#   'take',
#   'resid',
#   'intern',
#   'space',
#   'station',
#   'set',
#   'launch',
#   'kazakhstan'],
#  ['gate',
#   'microsoft',
#   'tackl',
#   'spywar',
#   'problem',
#   'mountain',
#   'view',
#   'califmicrosoft',
#   'chairman',
#   'bill',
#   'gate',
#   'say',
#   'never',
#   'comput',
#   'viru',
#   'adwar',
#   'malwar',
#   'tick',
#   'enough',
#   'microsoft',
#   'plan',
#   'someth'],
#  ['offici',
#   'blame',
#   'exil',
#   'us',
#   'tone',
#   'light',
#   'dapper',
#   'comedian',
#   'word',
#   'sober',
#   'outlin',
#   'vision',
#   'regim',
#   'chang',
#   'leftist',
#   'venezuela'],
#  ['hurrican',
#   'jeann',
#   'head',
#   'toward',
#   'florida',
#   'hurrican',
#   'jeann',
#   'kill',
#   'peopl',
#   'haiti',
#   'head',
#   'toward',
#   'northern',
#   'bahama',
#   'florida',
#   'haiti',
#   'around',
#   'peopl',
#   'still',
#   'miss',
#   'un',
#   'said',
#   'number'],
#  ['shame',
#   'fail',
#   'australian',
#   'team',
#   'former',
#   'australia',
#   'fast',
#   'bowler',
#   'merv',
#   'hugh',
#   'believ',
#   'absenc',
#   'sachin',
#   'tendulkar',
#   'first',
#   'two',
#   'test',
#   'sourav',
#   'ganuli',
#   'next',
#   'two',
#   'main',
#   'reason',
#   'india',
#   'poor',
#   'show',
#   'ongo',
#   'seri',
#   'australia'],
#  ['vinc',
#   'carter',
#   'trade',
#   'net',
#   'indianapoli',
#   'ind',
#   'sport',
#   'network',
#   'toronto',
#   'raptor',
#   'trade',
#   'allstar',
#   'swingman',
#   'vinc',
#   'carter',
#   'new',
#   'jersey',
#   'net',
#   'exchang',
#   'center',
#   'alonzo',
#   'mourn',
#   'forward',
#   'eric',
#   'william',
#   'centerforward',
#   'aaron',
#   'william',
#   'two',
#   'condit',
#   'firstround',
#   'draft',
#   'pick',
#   'trade',
#   'cannot',
#   'announc',
#   'nba',
#   'approv',
#   'salarycap',
#   'purpos'],
#  ['feder',
#   'crush',
#   'hewitt',
#   'set',
#   'new',
#   'record',
#   'fullstretch',
#   'roger',
#   'feder',
#   'switzerland',
#   'return',
#   'shot',
#   'first',
#   'set',
#   'lleyton',
#   'hewitt',
#   'tenni',
#   'master',
#   'cup',
#   'final',
#   'match',
#   'sunday'],
#  ['fed',
#   'stick',
#   'pace',
#   'feder',
#   'reserv',
#   'offici',
#   'agre',
#   'meet',
#   'septemb',
#   'probabl',
#   'would',
#   'keep',
#   'rais',
#   'benchmark',
#   'interest',
#   'rate',
#   'come',
#   'quarter',
#   'likelihood',
#   'continu',
#   'solid',
#   'econom',
#   'growth'],
#  ['jeann',
#   'forc',
#   'mass',
#   'evacu',
#   'florida',
#   'hurrican',
#   'jeann',
#   'forc',
#   'evacu',
#   'resid',
#   'saturday',
#   'bore',
#   'florida',
#   'wind',
#   'near',
#   'kph',
#   'threaten',
#   'strengthen',
#   'major',
#   'storm'],
#  ['nortel',
#   'win',
#   'indian',
#   'wireless',
#   'contract',
#   'nortel',
#   'score',
#   'first',
#   'major',
#   'wireless',
#   'deal',
#   'indian',
#   'servic',
#   'provid'],
#  ['tool',
#   'cybercrimin',
#   'websit',
#   'offer',
#   'surfer',
#   'chanc',
#   'download',
#   'free',
#   'quotphish',
#   'kit',
#   'quot',
#   'contain',
#   'graphic',
#   'web',
#   'code',
#   'text',
#   'requir',
#   'construct',
#   'kind',
#   'bogu',
#   'site',
#   'use',
#   'internet',
#   'phish',
#   'scam'],
#  ['oecd',
#   'report',
#   'boost',
#   'turkey',
#   'eu',
#   'case',
#   'ap',
#   'ap',
#   'turkish',
#   'prime',
#   'minist',
#   'recep',
#   'tayyip',
#   'erdogan',
#   'made',
#   'upbeat',
#   'econom',
#   'report',
#   'countri',
#   'press',
#   'case',
#   'membership',
#   'european',
#   'union'],
#  ['britsh',
#   'press',
#   'see',
#   'good',
#   'result',
#   'french',
#   'socialist',
#   'vote',
#   'london',
#   'dec',
#   'afp',
#   'vote',
#   'french',
#   'socialist',
#   'back',
#   'eu',
#   'constitut',
#   'bode',
#   'well',
#   'ratif',
#   'even',
#   'though',
#   'outcom',
#   'referendum',
#   'still',
#   'uncertain',
#   'major',
#   'british',
#   'newspap',
#   'said',
#   'friday'],
#  ['polish',
#   'cop',
#   'bust',
#   'comput',
#   'piraci',
#   'gang',
#   'warsaw',
#   'reuter',
#   'polish',
#   'polic',
#   'broken',
#   'gang',
#   'hacker',
#   'sold',
#   'pirat',
#   'music',
#   'film',
#   'use',
#   'academ',
#   'comput',
#   'system',
#   'around',
#   'world',
#   'store',
#   'ware',
#   'polic',
#   'spokeswoman',
#   'said',
#   'tuesday'],
#  ['tenni',
#   'roddick',
#   'hewitt',
#   'moya',
#   'feder',
#   'miss',
#   'madrid',
#   'madrid',
#   'master',
#   'tournament',
#   'danger',
#   'dub',
#   'masterless',
#   'seri',
#   'three',
#   'world',
#   'excit',
#   'player',
#   'join',
#   'event',
#   'grow',
#   'absente',
#   'list'],
#  ['australia',
#   'nation',
#   'food',
#   'flag',
#   'per',
#   'cent',
#   'profit',
#   'growth',
#   'australian',
#   'milk',
#   'produc',
#   'nation',
#   'food',
#   'ltd',
#   'said',
#   'friday',
#   'expect',
#   'fiscal',
#   'net',
#   'profit',
#   'grow',
#   'per',
#   'cent',
#   'spur',
#   'mainli',
#   'raft',
#   'new',
#   'product',
#   'lift',
#   'market',
#   'share'],
#  ['nordstrom',
#   'post',
#   'increas',
#   'nordstrom',
#   'inc',
#   'beat',
#   'cautiou',
#   'forecast',
#   'post',
#   'percent',
#   'increas',
#   'thirdquart',
#   'earn',
#   'reap',
#   'benefit',
#   'streamlin',
#   'inventori',
#   'system',
#   'focus',
#   'improv',
#   'merchandis'],
#  ['tech',
#   'group',
#   'launch',
#   'antispywar',
#   'campaign',
#   'ted',
#   'bridi',
#   'washington',
#   'ap',
#   'promin',
#   'internet',
#   'safeti',
#   'organ',
#   'lead',
#   'computermak',
#   'dell',
#   'inc',
#   'dell',
#   'launch',
#   'campaign',
#   'friday',
#   'help',
#   'consum',
#   'fend',
#   'spywar',
#   'softwar',
#   'caus',
#   'sluggish',
#   'comput',
#   'perform',
#   'popup',
#   'ad',
#   'secretli',
#   'monitor',
#   'activ',
#   'internet',
#   'user'],
#  ['england',
#   'lose',
#   'hill',
#   'six',
#   'nation',
#   'richard',
#   'hill',
#   'exploratori',
#   'oper',
#   'left',
#   'knee',
#   'last',
#   'night',
#   'amid',
#   'fear',
#   'may',
#   'miss',
#   'england',
#   'friendli',
#   'intern',
#   'next',
#   'month',
#   'also',
#   'start',
#   'six',
#   'nation',
#   'championship'],
#  ['bridg',
#   'hand',
#   'england',
#   'chanc',
#   'chelsea',
#   'defend',
#   'wayn',
#   'bridg',
#   'tonight',
#   'hand',
#   'chanc',
#   'stake',
#   'claim',
#   'longterm',
#   'solut',
#   'england',
#   'leftsid',
#   'midfield',
#   'conundrum'],
#  ['black',
#   'aid',
#   'attack',
#   'holling',
#   'report',
#   'david',
#   'radler',
#   'former',
#   'chief',
#   'oper',
#   'offic',
#   'holling',
#   'intern',
#   'righthand',
#   'man',
#   'lord',
#   'black',
#   'savag',
#   'special',
#   'report',
#   'claim',
#   'publish',
#   'compani'],
#  ['arafat',
#   'condit',
#   'improv',
#   'hospit',
#   'bed',
#   'yasser',
#   'arafat',
#   'swiftli',
#   'condemn',
#   'suicid',
#   'bomb',
#   'tel',
#   'aviv',
#   'monday',
#   'sign',
#   'ail',
#   'palestinian',
#   'leader',
#   'want',
#   'convey',
#   'impress',
#   'still',
#   'charg',
#   'despit',
#   'deterior',
#   'health'],
#  ['potenti',
#   'teflon',
#   'settlement',
#   'dupont',
#   'co',
#   'agre',
#   'settlement',
#   'potenti',
#   'worth',
#   'million',
#   'thursday',
#   'resolv',
#   'alleg',
#   'chemic',
#   'giant',
#   'contamin',
#   'drink',
#   'water',
#   'west',
#   'virginia'],
#  ['klein',
#   'derid',
#   'meanspirit',
#   'comment',
#   'handicap',
#   'canadian',
#   'press',
#   'canadian',
#   'press',
#   'calgari',
#   'cp',
#   'premier',
#   'ralph',
#   'klein',
#   'blast',
#   'thursday',
#   'meanspirit',
#   'disrespect',
#   'say',
#   'two',
#   'women',
#   'heckl',
#   'payment',
#   'disabl',
#   'didnt',
#   'look',
#   'handicap'],
#  ['chief',
#   'trim',
#   'roster',
#   'ap',
#   'ap',
#   'kansa',
#   'citi',
#   'chief',
#   'termin',
#   'contract',
#   'kicker',
#   'morten',
#   'andersen',
#   'put',
#   'middl',
#   'lineback',
#   'mike',
#   'maslowski',
#   'injur',
#   'reserv',
#   'sunday'],
#  ['fda',
#   'panel',
#   'urg',
#   'studi',
#   'stroke',
#   'med',
#   'us',
#   'advisori',
#   'panel',
#   'friday',
#   'recommend',
#   'approv',
#   'astrazeneca',
#   'new',
#   'stroke',
#   'prevent',
#   'medic',
#   'exanta',
#   'cite',
#   'concern',
#   'drug',
#   'effect',
#   'liver'],
#  ['louisvil',
#   'rout',
#   'chaminad',
#   'hawaii',
#   'taquan',
#   'dean',
#   'score',
#   'point',
#   'cardin',
#   'bounc',
#   'back',
#   'openinground',
#   'loss',
#   'beat',
#   'chaminad',
#   'yesterday',
#   'consol',
#   'bracket',
#   'maui',
#   'invit',
#   'lahaina',
#   'hawaii'],
#  ['flaw',
#   'offic',
#   'do',
#   'attack',
#   'potenti',
#   'secur',
#   'compani',
#   'warn',
#   'thursday',
#   'flaw',
#   'microsoft',
#   'offic',
#   'could',
#   'allow',
#   'denialofservic',
#   'attack',
#   'execut',
#   'system',
#   'run',
#   'somewhat',
#   'older',
#   'version',
#   'popular',
#   'product',
#   'suit'],
#  ['japan',
#   'open',
#   'smile',
#   'hewitt',
#   'sharapova',
#   'top',
#   'seed',
#   'lleyton',
#   'hewitt',
#   'maria',
#   'sharapova',
#   'best',
#   'second',
#   'round',
#   'could',
#   'win',
#   'three',
#   'set',
#   'japan',
#   'open'],
#  ['man',
#   'utd',
#   'boss',
#   'ferguson',
#   'fresh',
#   'dig',
#   'arsen',
#   'manchest',
#   'unit',
#   'boss',
#   'sir',
#   'alex',
#   'ferguson',
#   'turn',
#   'heat',
#   'arsen',
#   'state',
#   'regard',
#   'major',
#   'titl',
#   'rival'],
#  ['hacker',
#   'hit',
#   'california',
#   'univers',
#   'comput',
#   'comput',
#   'hacker',
#   'access',
#   'name',
#   'social',
#   'secur',
#   'number',
#   'million',
#   'californian',
#   'break',
#   'comput',
#   'system',
#   'univers',
#   'california',
#   'berkeley',
#   'august'],
#  ['mystic',
#   'blown',
#   'washington',
#   'mystic',
#   'shoot',
#   'percent',
#   'field',
#   'lose',
#   'indiana',
#   'saturday',
#   'night'],
#  ['virginia',
#   'blow',
#   'templ',
#   'ap',
#   'ap',
#   'wali',
#   'lundi',
#   'ran',
#   'yard',
#   'three',
#   'touchdown',
#   'alvin',
#   'pearman',
#   'return',
#   'punt',
#   'yard',
#   'score',
#   'lead',
#   'virginia',
#   'win',
#   'templ',
#   'saturday'],
#  ['yank',
#   'clinch',
#   'east',
#   'berni',
#   'blast',
#   'yanke',
#   'chanc',
#   'throw',
#   'parti',
#   'home',
#   'thursday',
#   'night',
#   'kind',
#   'champagn',
#   'flow',
#   'everyth',
#   'glass'],
#  ['stock',
#   'mutual',
#   'fund',
#   'perform',
#   'well',
#   'ap',
#   'ap',
#   'wall',
#   'street',
#   'fourthquart',
#   'ralli',
#   'gave',
#   'stock',
#   'mutual',
#   'fund',
#   'solid',
#   'perform',
#   'smallcap',
#   'equiti',
#   'fund',
#   'real',
#   'estat',
#   'fund',
#   'score',
#   'biggest',
#   'return',
#   'largecap',
#   'growth',
#   'equiti',
#   'technologyfocus',
#   'fund',
#   'slimmest',
#   'gain'],
#  ['nba',
#   'ratifi',
#   'refere',
#   'fiveyear',
#   'contract',
#   'nba',
#   'refere',
#   'enter',
#   'fiveyear',
#   'collect',
#   'bargain',
#   'agreement',
#   'leagu',
#   'remov',
#   'possibl',
#   'replac',
#   'offici',
#   'work',
#   'upcom',
#   'season'],
#  ['isra',
#   'alter',
#   'barrier',
#   'rout',
#   'israel',
#   'say',
#   'move',
#   'plan',
#   'stretch',
#   'controversi',
#   'barrier',
#   'west',
#   'bank',
#   'closer',
#   'israel'],
#  ['french',
#   'citizen',
#   'flee',
#   'ivori',
#   'coast',
#   'violenc',
#   'reuter',
#   'reuter',
#   'hundr',
#   'french',
#   'citizen',
#   'fled',
#   'theirform',
#   'coloni',
#   'ivori',
#   'coast',
#   'wednesday',
#   'day',
#   'ofantifrench',
#   'riot',
#   'loot',
#   'countri',
#   'seen',
#   'modelfor',
#   'africa',
#   'postindepend',
#   'prosper'],
#  ['discont',
#   'china',
#   'boil',
#   'public',
#   'protest',
#   'local',
#   'govern',
#   'announc',
#   'go',
#   'confisc',
#   'home',
#   'busi',
#   'make',
#   'room',
#   'new',
#   'develop',
#   'resid',
#   'villag',
#   'southeastern',
#   'china',
#   'fought',
#   'back'],
#  ['gate',
#   'frighten',
#   'big',
#   'bad',
#   'linux',
#   'grand',
#   'nabob',
#   'world',
#   'softwar',
#   'giant',
#   'microsoft',
#   'bill',
#   'gate',
#   'told',
#   'technologist',
#   'afraid',
#   'linux',
#   'speak',
#   'shindig',
#   'comput',
#   'histori',
#   'museum',
#   'gate',
#   'said',
#   'seen'],
#  ['dollar',
#   'slip',
#   'weaker',
#   'produc',
#   'price',
#   'chicago',
#   'reuter',
#   'dollar',
#   'eas',
#   'friday',
#   'august',
#   'declin',
#   'us',
#   'produc',
#   'price',
#   'undermin',
#   'forecast',
#   'dollarboost',
#   'feder',
#   'reserv',
#   'interest',
#   'rate',
#   'hike',
#   'beyond',
#   'septemb'],
#  ['isra',
#   'helicopt',
#   'fire',
#   'missil',
#   'gaza',
#   'wit',
#   'reuter',
#   'reuter',
#   'isra',
#   'helicopt',
#   'fire',
#   'missil',
#   'intoa',
#   'town',
#   'southern',
#   'gaza',
#   'strip',
#   'late',
#   'wednesday',
#   'witnessessaid',
#   'hour',
#   'palestinian',
#   'suicid',
#   'bomber',
#   'blew',
#   'upin',
#   'jerusalem',
#   'kill',
#   'two',
#   'isra',
#   'border',
#   'policemen'],
#  ...]

# %% [markdown]
# Since the overall size of corpus is relatively small (53202 unique words) and dataset was previously cleaned from stopwords, parameters such as size = 100 (the number of transformed vector’s dimensions), window = 5 (the maximum number of surrounding words to analyze), min_count = 1 (minimum count of words to proceed) and sg =1 (Skip-gram architecture) were selected for text transformation.

# %%
#Load the Word2vec model
#model_w2v = Word2Vec.load("word2vec.model")
#model_w2v.init_sims(replace = True)

# %%
w_model_sg = Word2Vec(sent, size = 100, window = 5, min_count = 1, sg = 1)
w_model_sg.init_sims(replace = True)
w_model_sg.wv.vectors.shape
# Out:
# (53202, 100)

# %%
#saving model
#w_model_sg.save("word2vec.model")

# %%
#saving weights
filename = 'embedding_sg_word2vec.txt'
w_model_sg.wv.save_word2vec_format(filename, binary=False)

# %% [markdown]
# Each word in the vocabulary transformed to the 100-dimensinal vector

# %%
ww = dict(zip(w_model_sg.wv.index2word, w_model_sg.wv.vectors))
ww
# Out:
# {'new': array([ 0.00654503,  0.14620057,  0.12140904, -0.03922348,  0.02716835,
#          0.10644053,  0.17231777, -0.05495744, -0.03099191, -0.1365046 ,
#          0.10521759,  0.07703044,  0.01120177, -0.01273528,  0.16865562,
#          0.0822508 , -0.10616173,  0.01160257, -0.08177923, -0.03481948,
#         -0.21113126, -0.05476615, -0.07396526,  0.10378452,  0.01892306,
#         -0.19928946, -0.2118883 ,  0.08088666,  0.04160492, -0.11273932,
#         -0.0763417 ,  0.05515302, -0.16042872,  0.11365878, -0.01895962,
#         -0.0337267 ,  0.08884577, -0.03825793,  0.05408671, -0.09573387,
#          0.14002916,  0.1054254 ,  0.09356842, -0.10556114,  0.10589712,
#         -0.13105911,  0.03505216,  0.0325547 ,  0.13839719, -0.07252531,
#          0.11692549,  0.10830921,  0.12844303, -0.2140178 ,  0.03025259,
#         -0.07544559, -0.01171061, -0.05116756, -0.16096231, -0.14898191,
#          0.04726227, -0.15922788,  0.01312063, -0.01710202,  0.14913343,
#          0.04058523, -0.00626275, -0.00517502, -0.01299731, -0.13260035,
#          0.02539989, -0.07230916, -0.02089886, -0.04868237,  0.05850764,
#         -0.1045184 ,  0.0334208 ,  0.00936334,  0.00036571,  0.0949443 ,
#         -0.04563091, -0.02809838, -0.0246969 ,  0.09196829, -0.13694188,
#          0.0359091 , -0.07197638,  0.03075374,  0.01511426,  0.23634374,
#          0.08956203, -0.17920347,  0.22937228,  0.01781571, -0.06402287,
#         -0.03816286,  0.03332962, -0.18938383,  0.04623007,  0.00774287],
#        dtype=float32),
#  'said': array([-0.08582123,  0.0666263 ,  0.18675749,  0.10116273, -0.13663612,
#          0.1283161 ,  0.15292096,  0.04162828, -0.15007415, -0.2711632 ,
#          0.07286298, -0.02767305, -0.10542615,  0.03428666,  0.01864257,
#          0.05356264,  0.12382986, -0.03713644, -0.01316293,  0.01024596,
#          0.07040653,  0.07394444, -0.08373272,  0.05827411, -0.06865085,
#         -0.16939497, -0.01741073,  0.01508175, -0.01246971,  0.1158021 ,
#         -0.15400673,  0.21855001, -0.03463275,  0.05378473, -0.04022311,
#          0.04306754,  0.12838031,  0.08919092,  0.10263035, -0.03298821,
#          0.15930219,  0.17245321,  0.006687  , -0.03943901,  0.16868329,
#          0.03135751, -0.01963996,  0.06246632,  0.06123308, -0.11972311,
#          0.11842258,  0.20579374, -0.03514767, -0.08364531, -0.14246307,
#          0.02343209,  0.01401909, -0.04796572,  0.11398102, -0.04435076,
#         -0.11215985, -0.02128573,  0.13074945, -0.15342097, -0.01406964,
#          0.1098891 ,  0.08841938,  0.07698643, -0.13143322, -0.00839783,
#          0.00513296,  0.01533376, -0.09284456, -0.10431654, -0.17611207,
#         -0.02213252, -0.07500359, -0.02761436, -0.14018838,  0.05549948,
#         -0.06275436, -0.123303  ,  0.04947521,  0.01906227,  0.0023424 ,
#          0.13161094,  0.20837262,  0.0053684 , -0.12408592, -0.05637984,
#         -0.01363148, -0.08171936,  0.01444526, -0.06078828,  0.09939615,
#          0.02309171, -0.22124316,  0.03690275, -0.00243519, -0.05578858],
#        dtype=float32),
#  'us': array([-0.0645223 ,  0.283122  ,  0.09419077, -0.02309478,  0.06073872,
#          0.04917824,  0.01417381,  0.03142755, -0.08259973, -0.14375485,
#          0.19721165,  0.00949239, -0.02644471, -0.17648068,  0.12945479,
#          0.06811889,  0.02637323,  0.01310423, -0.09726616, -0.04053082,
#         -0.09381618, -0.08841915, -0.08431944, -0.15471911, -0.13377452,
#          0.00581817, -0.0254764 ,  0.19074385, -0.13501889,  0.13004383,
#         -0.00628315,  0.18726583, -0.06988049, -0.00865939,  0.00865264,
#          0.02262051, -0.03424574, -0.12279888, -0.03335932, -0.01788331,
#          0.10184159,  0.1206112 ,  0.0946453 , -0.06654964,  0.04510984,
#         -0.19375065, -0.02832781,  0.11765715,  0.12484554, -0.07166136,
#          0.03647028,  0.13877194, -0.02859761, -0.11589647, -0.14345855,
#          0.01200444, -0.06320093, -0.07087929, -0.07259363, -0.0038051 ,
#          0.07934499,  0.10590927,  0.1274199 , -0.10261867,  0.05258372,
#          0.01312377,  0.12438504, -0.03321191, -0.0977247 ,  0.06159675,
#         -0.21891676, -0.04398441, -0.14804003,  0.03886431, -0.14541659,
#         -0.04975309,  0.13977087, -0.06116403, -0.05558884,  0.0258079 ,
#          0.15942645,  0.01842942,  0.11288481,  0.09758887,  0.16131496,
#          0.06700423,  0.00052264, -0.00942092,  0.09678029,  0.06742118,
#         -0.11855969, -0.13864565, -0.0088504 , -0.11413196,  0.08136042,
#         -0.06143606, -0.16753434,  0.03665827, -0.04753518, -0.07754265],
#        dtype=float32),
#  'reuters': array([-0.02206706,  0.08765916,  0.14557032,  0.00273029,  0.10592604,
#          0.06876496,  0.01431738, -0.12878752, -0.04321653, -0.1877382 ,
#          0.12519905, -0.04812439,  0.0820023 , -0.00322226,  0.08556063,
#         -0.1494365 , -0.01357529, -0.19153917, -0.12201031, -0.04347678,
#         -0.08178739, -0.04397063, -0.01959995,  0.06825221,  0.03738356,
#          0.04862867, -0.03596879, -0.007261  ,  0.05221223,  0.07836517,
#         -0.08166581,  0.11643478, -0.00567465,  0.09216097,  0.15250725,
#          0.14210387, -0.09911125,  0.08793309,  0.06701222, -0.0798638 ,
#          0.25570542,  0.19927247,  0.13847801, -0.15295747, -0.10405112,
#         -0.0730389 , -0.12386315, -0.00266775,  0.2772487 , -0.20407258,
#          0.09054782,  0.13388075, -0.04985203, -0.17006692,  0.05982732,
#         -0.19629519, -0.07388216,  0.01267787,  0.00230616, -0.1523806 ,
#          0.00535162, -0.04741223,  0.05623214,  0.02165437,  0.02249543,
#          0.01970361,  0.04000032, -0.17572425,  0.06498928,  0.04248349,
#         -0.0469332 , -0.03655988, -0.08475153, -0.02238752,  0.15811042,
#         -0.14051817, -0.02325199,  0.07149333, -0.03675146,  0.13620253,
#          0.06927083,  0.05517855,  0.19945808,  0.06083123,  0.03609314,
#          0.11971011,  0.07964838, -0.03576062, -0.02456807,  0.03402452,
#         -0.09201724,  0.03505599,  0.05127762, -0.11455577, -0.04376752,
#         -0.04345104,  0.0195007 ,  0.04639968, -0.0063497 , -0.05749051],
#        dtype=float32),
#  'ap': array([ 1.05540175e-02, -6.83152303e-02,  9.25748199e-02, -5.59906587e-02,
#         -1.13227563e-02, -8.26809704e-02, -6.03496432e-02, -8.32926929e-02,
#          1.09679066e-02, -1.23928070e-01,  1.99248679e-02,  1.80313177e-02,
#          1.64121211e-01,  3.05363983e-02, -3.15066823e-03,  5.07809520e-02,
#         -1.36218905e-01, -9.18965936e-02,  4.76562008e-02,  3.68443578e-02,
#         -4.71218582e-03, -9.74592566e-02,  3.87069024e-02, -1.23489715e-01,
#         -1.67669758e-04, -1.42314583e-01, -4.11773771e-02, -2.31651925e-02,
#         -2.88809324e-03,  5.59748560e-02, -2.01438423e-02,  1.31166905e-01,
#          3.35059837e-02, -3.82622108e-02,  2.26102859e-01,  8.62594172e-02,
#         -4.29111235e-02, -8.72978196e-02,  5.46973050e-02,  5.02464436e-02,
#          1.51254460e-01,  1.57419860e-01,  1.10977031e-01, -9.06144232e-02,
#         -4.14078496e-02, -1.13549069e-01, -6.91423789e-02,  9.52895954e-02,
#          6.22049049e-02, -1.68208525e-01,  5.66646121e-02,  8.37216154e-02,
#         -1.12378582e-01, -9.41060334e-02,  3.64310965e-02, -4.53536573e-04,
#          3.19171622e-02,  9.53815356e-02, -9.63347629e-02, -1.95824467e-02,
#          1.92804337e-01, -2.16374561e-01,  1.50717124e-01,  5.83760068e-02,
#          1.34446383e-01, -4.73219566e-02,  1.65051818e-01, -7.64648244e-02,
#         -3.96854803e-02, -8.51916373e-02, -1.69776589e-01,  2.14395180e-01,
#          1.23139387e-02, -1.08301491e-01,  1.69066742e-01,  4.52962657e-03,
#          4.74816002e-02, -1.66970678e-02, -7.00807944e-02,  1.54114097e-01,
#          6.51364326e-02,  4.77187298e-02, -8.17559436e-02, -2.52311826e-02,
#          3.82892936e-02,  3.12562704e-01,  2.39744764e-02, -9.55517292e-02,
#         -1.53556332e-01,  3.08643524e-02, -1.06889452e-03, -1.37822270e-01,
#          6.28918931e-02, -1.77181065e-01, -3.79750766e-02, -1.60488054e-01,
#         -8.82445201e-02,  3.96186411e-02,  4.42384407e-02,  5.00258282e-02],
#        dtype=float32),
#  'first': array([ 0.08488857,  0.15993933,  0.00544855,  0.11410671,  0.02036773,
#         -0.03992935,  0.09656399, -0.02140765, -0.02206662, -0.03918775,
#          0.12812038, -0.11339946, -0.00297694,  0.0459207 , -0.09957895,
#         -0.13134865, -0.08492541, -0.01038206,  0.14212196, -0.20185807,
#          0.0690605 ,  0.00815234, -0.17713296,  0.09446359, -0.05752657,
#         -0.18258254, -0.09304514,  0.06148962,  0.1176034 , -0.07272395,
#         -0.05061294, -0.05295458, -0.08738753,  0.1140237 ,  0.02169724,
#          0.01656307, -0.01883547, -0.09964121,  0.12269039,  0.02970702,
#          0.22103831,  0.04620311,  0.01943096, -0.13513151,  0.18942353,
#         -0.16528766, -0.01826069,  0.1395048 , -0.00893125, -0.0200838 ,
#          0.07877161,  0.07051013,  0.00424528, -0.22642277, -0.09688176,
#         -0.10124809, -0.06137997,  0.03331573,  0.01933954, -0.17187041,
#          0.10690746, -0.00592061, -0.0015697 , -0.110947  , -0.18484846,
#         -0.06184521, -0.09381205, -0.01760953,  0.04883257, -0.14408392,
#         -0.13236347, -0.03663517,  0.13895579, -0.03253945,  0.02436246,
#         -0.12024774,  0.07126781, -0.10665707, -0.21483141,  0.11480239,
#          0.05704424, -0.01127338, -0.02601987,  0.10798705, -0.071014  ,
#         -0.0802394 ,  0.05755917,  0.05623216, -0.12333996,  0.0715096 ,
#         -0.08277687, -0.04007585,  0.16395316, -0.02241707,  0.06545276,
#         -0.0354928 , -0.12936835,  0.09599304,  0.08941361,  0.15423504],
#        dtype=float32),
#  'two': array([ 0.04900061,  0.15667106,  0.09740362, -0.09341364, -0.07489301,
#          0.06710865,  0.18400483, -0.15716958, -0.10584604, -0.05459438,
#         -0.01643666, -0.05774979,  0.0456801 , -0.11642668,  0.06264875,
#         -0.04011438, -0.0081766 , -0.04374657,  0.01076892,  0.09305263,
#          0.02401917, -0.16134325, -0.13804853, -0.10949083,  0.01533487,
#         -0.04292987, -0.16707121, -0.03664829,  0.10162061, -0.02642689,
#         -0.13440678,  0.18576394, -0.15767686,  0.01485478,  0.05970797,
#         -0.13397378, -0.17090598,  0.03677438, -0.09265382,  0.14134821,
#          0.02563238,  0.18263811, -0.13581462,  0.04451819, -0.0676594 ,
#          0.00090801, -0.13745071,  0.19780682,  0.02655713, -0.12456834,
#         -0.07220277,  0.03704096, -0.14739165, -0.15062755, -0.16068397,
#         -0.10314929, -0.02816905, -0.03303785,  0.07178134, -0.01472073,
#          0.22064433,  0.00568858,  0.01492093, -0.08135631,  0.04513898,
#          0.16661046,  0.06079398, -0.02360353, -0.01590816, -0.0745526 ,
#         -0.04493704,  0.02400413,  0.04691247,  0.0346488 , -0.01492956,
#         -0.10687132,  0.17546308, -0.16447395,  0.01098527,  0.01176495,
#         -0.15938833, -0.1416817 ,  0.01462129,  0.03883056, -0.03749928,
#          0.10305428,  0.19462736,  0.05838039, -0.11462449,  0.1201804 ,
#         -0.06055972,  0.04387116,  0.06803669, -0.06264956, -0.08287306,
#          0.0274146 , -0.03004405, -0.06980649, -0.11829845,  0.0968174 ],
#        dtype=float32),
#  'world': array([-0.13637674,  0.11529111, -0.00679943, -0.03701428,  0.11418645,
#         -0.02571872, -0.07187446, -0.16269334,  0.15031733, -0.03641307,
#         -0.1573058 ,  0.10353201,  0.09192508,  0.03769891,  0.08631277,
#          0.15855105,  0.07383535, -0.01099049,  0.00928548, -0.04128028,
#          0.09516859,  0.05065632,  0.04108907,  0.13760534,  0.18912198,
#         -0.00118636,  0.10844418,  0.20941669,  0.02590485,  0.00945641,
#         -0.13760072,  0.13526243, -0.10288845,  0.00244785,  0.07200094,
#         -0.06379679,  0.02873597, -0.1191897 , -0.03078173, -0.04174923,
#         -0.04439168,  0.2558519 , -0.01416429,  0.02008718,  0.03744991,
#         -0.20563403,  0.05822275,  0.02744965,  0.03602673, -0.26124042,
#          0.14489923,  0.0530859 , -0.01619638, -0.08012088,  0.00067802,
#         -0.02733715, -0.18194522,  0.01659602,  0.08618473, -0.09037974,
#          0.04831679,  0.05372351, -0.06684777, -0.01849214, -0.05469139,
#          0.15914048, -0.03697468, -0.036459  ,  0.16429843, -0.070282  ,
#          0.03299262, -0.0091125 ,  0.07588022,  0.14631636, -0.01959877,
#          0.02443002,  0.02255616,  0.0439024 , -0.15123606,  0.20117712,
#          0.01296229, -0.05522366,  0.14296536,  0.07535408,  0.05088884,
#         -0.02225495,  0.21011752, -0.00598058, -0.05463869,  0.07974339,
#          0.06313965, -0.21367459,  0.05109785,  0.06297809,  0.08194944,
#          0.04389204, -0.10637905,  0.04541716,  0.10005899,  0.07106224],
#        dtype=float32),
#  'thursday': array([-0.05207378,  0.16446066,  0.10368737, -0.16741559, -0.05831822,
#          0.06691097,  0.2668908 , -0.0052112 , -0.143266  , -0.11563127,
#         -0.0051259 ,  0.12352113,  0.02812117,  0.041163  ,  0.12863277,
#         -0.05011572,  0.01617782, -0.02825617,  0.04895889, -0.11576829,
#         -0.05708917, -0.08510699,  0.0141639 ,  0.12887456, -0.05740651,
#          0.03775581, -0.09300398, -0.05551273, -0.05623861,  0.04265631,
#         -0.13334796,  0.22301629, -0.09529432,  0.04627509,  0.06120999,
#          0.08166236,  0.04627476, -0.05991906,  0.07024639, -0.10698573,
#          0.09546082,  0.07819195,  0.10226323, -0.10477788,  0.18357976,
#         -0.00496111, -0.05541933,  0.27984968, -0.03407259, -0.21407792,
#          0.0507438 ,  0.24448788,  0.00757282, -0.19303758, -0.03474861,
#          0.05169668, -0.07268488, -0.08187515, -0.01388744,  0.03067265,
#         -0.03447928, -0.00394669,  0.03029622, -0.17443986,  0.06243943,
#          0.08626873, -0.0151929 , -0.02960648,  0.03503098, -0.0198523 ,
#         -0.11065249,  0.00032132,  0.10370969, -0.02032047, -0.11839873,
#         -0.01931069,  0.01022419, -0.07919949,  0.09804344,  0.15090603,
#         -0.1721218 , -0.00171538,  0.11754152,  0.11745912, -0.01155532,
#          0.12576866,  0.19108047,  0.00060911, -0.0051849 , -0.0104149 ,
#         -0.07788589,  0.02971274, -0.00284848, -0.04413744,  0.02208496,
#         -0.10534766, -0.05994904,  0.14323008,  0.10793816, -0.0038299 ],
#        dtype=float32),
#  'oil': array([-0.09006727,  0.08729316,  0.20266184,  0.02623275, -0.18217377,
#          0.03406344, -0.0016016 , -0.09436386, -0.01903158, -0.14411983,
#          0.15324198,  0.0383439 , -0.09880663, -0.11094984,  0.16716939,
#          0.10755825,  0.06539969, -0.02489729,  0.02753435, -0.09109996,
#          0.1335673 , -0.1261603 ,  0.05198756,  0.02065034,  0.00661753,
#          0.08805527,  0.18326344, -0.0014888 , -0.03141351,  0.13966268,
#         -0.10479946,  0.23704624, -0.07184432,  0.090017  ,  0.06010302,
#          0.05062966, -0.1125086 ,  0.03724741,  0.05471203, -0.01916489,
#          0.1683703 ,  0.0021722 , -0.05618304, -0.14971256, -0.07433797,
#          0.00481458,  0.08810364,  0.05084677,  0.15787533, -0.10356721,
#          0.08005191,  0.11673287,  0.08215822, -0.22634344, -0.10126457,
#          0.071064  , -0.09764601,  0.04586506, -0.1785024 ,  0.01918267,
#         -0.00585899, -0.03053707,  0.07173774, -0.08468143, -0.07974608,
#         -0.02012008,  0.08911473,  0.01037417,  0.22574729, -0.19230755,
#          0.00867223, -0.07881064, -0.00048089, -0.01953804,  0.07814225,
#         -0.08982711, -0.03535835, -0.05518723,  0.02223856,  0.10331689,
#          0.12815315, -0.02157908,  0.04032693,  0.11200347, -0.06506335,
#         -0.09851719, -0.03326332,  0.06117642, -0.02627489,  0.06330942,
#         -0.13354269, -0.10806315, -0.08637831, -0.14342281,  0.19681086,
#          0.08700359,  0.06879282, -0.11142743, -0.06509267, -0.00719363],
#        dtype=float32),
#  'monday': array([ 0.06391853,  0.18277767,  0.10093377, -0.16145132, -0.16496119,
#          0.08679076,  0.15566063, -0.00112726, -0.16686895, -0.17544414,
#         -0.02030595,  0.12946269,  0.09210198,  0.10955001,  0.09643219,
#          0.03347847,  0.04480628,  0.03606533,  0.0523673 , -0.08911528,
#         -0.09387884, -0.08770331, -0.04319067,  0.16063748, -0.12251575,
#          0.01186641,  0.02866844, -0.08454156, -0.07785261,  0.01839051,
#         -0.2089683 ,  0.23459102, -0.16015962,  0.04620575,  0.0656926 ,
#          0.04203953, -0.02501279, -0.04192308,  0.0436364 , -0.07174034,
#          0.04022972,  0.06640851,  0.07005136, -0.14098558,  0.19456841,
#         -0.03825691, -0.00644613,  0.27788743, -0.01857263, -0.0835941 ,
#          0.03395971,  0.22206531, -0.01272714, -0.24280198,  0.02760466,
#          0.01024334, -0.06514386, -0.04722606,  0.01322263, -0.08712828,
#         -0.08885437, -0.01929686, -0.01475918, -0.080496  ,  0.06372511,
#         -0.04342245, -0.11847269, -0.08852009, -0.02120486, -0.11734207,
#         -0.07115744, -0.05503701,  0.01971788, -0.02859428, -0.13139337,
#          0.02684421, -0.05424044,  0.0280072 ,  0.04312492,  0.169992  ,
#         -0.13137183, -0.02030694,  0.04738541,  0.07631157, -0.06574112,
#          0.06324071,  0.17958638,  0.03481368, -0.00154031, -0.02475099,
#         -0.08275523,  0.00397703, -0.00197465, -0.01824396,  0.03622182,
#         -0.18508424, -0.01985858,  0.12565704,  0.06107621,  0.04329749],
#        dtype=float32),
#  'wednesday': array([ 0.00430963,  0.11467818,  0.07562979, -0.17219277, -0.11031692,
#          0.02620254,  0.18815014, -0.04229247, -0.10832561, -0.13584457,
#          0.04799534,  0.03709584,  0.01509963,  0.09264705,  0.05289597,
#         -0.03255659,  0.08869428,  0.03219734, -0.00077481, -0.13820228,
#         -0.00962835, -0.06187771, -0.03993681,  0.14923981, -0.1252596 ,
#          0.07279918, -0.10193489, -0.10722955, -0.05338895,  0.02987532,
#         -0.06932387,  0.2536358 , -0.14747861, -0.02208825,  0.07455434,
#          0.12304298,  0.0037477 , -0.0519981 ,  0.09840316, -0.08897467,
#          0.14298148,  0.02017983,  0.08488266, -0.19677925,  0.15063639,
#         -0.03435678,  0.07878485,  0.20707929, -0.0292366 , -0.122731  ,
#          0.08541479,  0.21747929,  0.00574588, -0.27234071,  0.00144212,
#          0.07094122, -0.14830875, -0.08729614, -0.03460209, -0.0418823 ,
#         -0.02317475,  0.07404432, -0.02020753, -0.03621259, -0.04301984,
#          0.06968815, -0.02705695, -0.08475741, -0.03249492,  0.00702484,
#         -0.16819417,  0.02618197,  0.08715833,  0.00788923, -0.08113877,
#          0.00172363,  0.016277  , -0.03696816,  0.0385542 ,  0.19728187,
#         -0.16947722, -0.10375097,  0.07174298,  0.03254738,  0.01040847,
#          0.09345565,  0.17233211,  0.03745924, -0.04270319, -0.02210806,
#         -0.0558288 ,  0.03484063,  0.04306842, -0.039362  , -0.01299417,
#         -0.12079602, -0.04538921,  0.2693883 ,  0.06476063, -0.00489297],
#        dtype=float32),
#  'tuesday': array([-3.09115127e-02,  1.50271878e-01,  1.24364041e-01, -1.30570933e-01,
#         -1.61707893e-01,  1.04098447e-01,  1.83217943e-01, -1.87771872e-03,
#         -1.60579100e-01, -1.63694784e-01, -6.94189407e-03,  9.89687517e-02,
#          1.99366994e-02,  5.19513041e-02,  9.54743624e-02, -1.61189940e-02,
#          1.41068012e-03,  5.54420501e-02,  9.50630382e-03, -1.44925773e-01,
#         -1.71975289e-02, -7.50275999e-02, -3.41612510e-02,  1.81891784e-01,
#         -1.20682217e-01, -6.49860501e-03, -5.78206256e-02, -3.78541388e-02,
#         -1.02410428e-01,  6.91126846e-03, -1.30593300e-01,  1.79218411e-01,
#         -1.17064007e-01,  2.16123983e-02,  1.16887949e-02,  2.11500991e-02,
#          2.14568619e-02, -5.15118651e-02,  9.90189463e-02, -9.46371853e-02,
#          8.19874778e-02,  7.09125027e-02,  9.43910033e-02, -4.51940000e-02,
#          1.76908582e-01,  2.57233847e-02, -1.17211342e-02,  2.81567454e-01,
#         -5.92543185e-03, -1.39823526e-01,  3.78551483e-02,  2.63505131e-01,
#         -1.06199365e-02, -2.28608549e-01,  2.81549953e-02, -1.18156355e-02,
#         -6.56451285e-02, -7.58068264e-02,  3.60269495e-03, -6.84761778e-02,
#         -3.39468233e-02,  3.86138447e-02, -5.01449853e-02, -6.15367293e-02,
#          3.81850824e-03,  2.27431025e-04, -1.92674156e-02, -1.11637622e-01,
#         -1.54699413e-02, -7.96519369e-02, -1.77727088e-01, -4.99322079e-02,
#          5.67343980e-02, -8.98274686e-03, -1.12543516e-01, -1.06905606e-02,
#          1.83554310e-02, -9.88175720e-03, -2.47239098e-02,  1.85402036e-01,
#         -1.79761589e-01, -8.21199119e-02,  9.84492600e-02,  6.94160983e-02,
#         -4.59736995e-02,  7.70317540e-02,  2.17258811e-01,  1.07738458e-01,
#          4.29673195e-02,  2.33932044e-02, -1.18538134e-01,  6.52606711e-02,
#          9.61731002e-03, -8.21738970e-03,  7.85939246e-02, -1.29772440e-01,
#         -7.40274563e-02,  1.84061155e-01,  8.63727480e-02,  2.73006279e-02],
#        dtype=float32),
#  'company': array([-0.18524021,  0.13118427,  0.11194333, -0.01871857, -0.1848052 ,
#          0.03876999,  0.01260625, -0.06791537, -0.07362092, -0.00068632,
#         -0.00807583,  0.00279578,  0.01602904, -0.03103141,  0.05644991,
#         -0.05866093,  0.01177427, -0.02572553,  0.02473903, -0.06087285,
#          0.06443699,  0.08872259, -0.08762632,  0.07614909, -0.02492871,
#         -0.0202661 , -0.13557947, -0.07484266, -0.03530427, -0.0272727 ,
#         -0.18617901, -0.05476357,  0.02457697, -0.08074383, -0.00758954,
#         -0.02339405,  0.10976768,  0.23978111,  0.09358943,  0.03508027,
#          0.1930588 ,  0.20927481, -0.0057807 , -0.07168125,  0.26168612,
#          0.02880351,  0.05267097, -0.09096424, -0.14210325, -0.10030092,
#         -0.09798583,  0.11952071, -0.16081935, -0.28195536, -0.15399197,
#         -0.12232496, -0.04919322, -0.03522282,  0.01424768,  0.01050636,
#         -0.00862086, -0.11013293,  0.00543205, -0.13601854,  0.194631  ,
#          0.1742714 ,  0.03795216,  0.139107  ,  0.00820252, -0.04118157,
#         -0.06986836,  0.0360132 ,  0.02062496, -0.0785372 , -0.0360734 ,
#          0.04434208,  0.02764435, -0.11556984, -0.09801269, -0.05838619,
#          0.13729206,  0.00089722,  0.02310158,  0.13680369, -0.0998092 ,
#          0.04700643,  0.1181128 ,  0.06288286,  0.06014413,  0.132488  ,
#         -0.01337525, -0.15928772, -0.1362354 , -0.06364276,  0.08503354,
#         -0.10928635,  0.00171237, -0.07891295,  0.00626652,  0.05349237],
#        dtype=float32),
#  'one': array([ 6.80917175e-03,  1.91462547e-01,  5.33099137e-02, -4.62097414e-02,
#         -7.05017075e-02,  3.27899493e-02,  1.56452417e-01, -1.70064449e-01,
#         -1.56410351e-01,  1.04380906e-01, -2.25846261e-01, -9.93054360e-02,
#          8.36143941e-02, -1.68417916e-01, -2.82567497e-02,  5.47608882e-02,
#         -8.42377369e-04,  1.65322181e-02, -1.01322997e-02,  9.05292109e-03,
#         -2.16790270e-02, -8.73541608e-02, -2.50999063e-01,  7.25712720e-03,
#          6.20839931e-02, -1.00915320e-01, -1.63579836e-01,  5.47453798e-02,
#         -1.19759943e-02, -4.73076068e-02, -1.61820799e-02,  7.44870305e-02,
#         -2.20343005e-02,  5.36628366e-02,  1.85018837e-01,  6.28366247e-02,
#         -1.27156839e-01, -6.30237386e-02, -3.19531485e-02,  1.91761181e-02,
#          3.95771489e-02,  9.64537859e-02, -1.17992505e-01, -3.04770228e-02,
#          1.58169121e-01, -5.58834784e-02,  1.96170770e-02,  1.08666003e-01,
#         -3.19206193e-02, -2.41601825e-01, -9.21433344e-02, -7.08975419e-02,
#         -1.97238214e-02, -1.81976870e-01,  1.16437912e-01, -2.55254637e-02,
#         -5.21736145e-02,  1.22539237e-01,  2.46948190e-02, -2.25167889e-02,
#          5.24842739e-02,  5.61676659e-02,  7.39050880e-02, -1.32683396e-01,
#          5.42039312e-02, -4.38304432e-02,  8.04001689e-02,  5.23091368e-02,
#         -1.46338996e-02,  5.99318836e-03,  4.39402498e-02, -3.50105390e-02,
#          5.83333671e-02, -4.44233827e-02,  1.39936507e-02, -2.07263846e-02,
#          2.43271023e-01, -1.13055827e-02, -7.93451816e-02,  1.46120489e-01,
#          4.31603156e-02,  3.67004499e-02, -2.12591626e-02,  2.28014246e-01,
#          1.38871193e-01,  2.55303075e-05,  1.79624647e-01, -9.47894752e-02,
#         -1.50418013e-01, -3.11113391e-02, -2.48917583e-02, -9.29582675e-05,
#          5.83116040e-02,  2.54066866e-02,  2.03782633e-01,  1.22171298e-01,
#         -8.62083212e-02, -9.84428003e-02,  8.51954371e-02, -8.12961385e-02],
#        dtype=float32),
#  'friday': array([-3.11973542e-02,  1.10996924e-01,  1.05816968e-01, -2.48584270e-01,
#         -1.06454201e-01,  4.17036563e-02,  1.85550645e-01, -3.10999230e-02,
#         -1.43452421e-01, -2.01763764e-01,  9.89813581e-02,  3.52359973e-02,
#          2.98909508e-02,  3.02179959e-02,  1.27284616e-01,  5.32358745e-03,
#          4.82814666e-03,  7.60134310e-03,  2.31893361e-03, -8.16810951e-02,
#         -1.47347271e-01, -2.75219381e-02, -2.30591688e-02,  7.56719783e-02,
#         -2.75125299e-02,  6.82440102e-02, -4.33341973e-03, -7.03610629e-02,
#         -7.18147904e-02,  1.13198841e-02, -1.26328871e-01,  2.29122207e-01,
#         -9.90983322e-02, -3.70803662e-02,  1.16603091e-01,  1.80417299e-02,
#          6.93639815e-02, -4.71218042e-02,  1.47185177e-01, -1.88291946e-03,
#          6.96406439e-02,  8.26032311e-02,  6.30968511e-02, -6.52357563e-02,
#          2.06630185e-01,  2.64379233e-02, -7.97440857e-03,  2.03545257e-01,
#          1.69417728e-02, -1.87790155e-01,  2.74570901e-02,  2.38194808e-01,
#          4.49309237e-02, -2.07186446e-01, -5.58523508e-03,  5.87955266e-02,
#         -1.45144030e-01, -1.32542744e-01, -1.63077768e-02, -3.85362580e-02,
#         -6.78649247e-02,  2.07211170e-02,  1.00079961e-02, -1.70873746e-01,
#          9.46660247e-03,  2.27428973e-02, -7.51180425e-02, -3.11169140e-02,
#         -1.48245820e-03, -9.08256024e-02, -1.20618053e-01, -1.42473891e-01,
#          7.84814805e-02, -3.48437652e-02, -9.32723433e-02,  1.75774214e-04,
#          1.20591326e-02, -5.32454252e-03,  5.13063706e-02,  8.29340294e-02,
#         -1.21428162e-01, -1.60219986e-02,  1.45377412e-01,  1.34481378e-02,
#         -1.46795968e-02,  1.50574446e-01,  2.42911011e-01,  1.74054541e-02,
#         -7.55139142e-02, -1.47217559e-02, -7.00751767e-02, -4.63544801e-02,
#         -8.76641460e-03, -5.88970110e-02,  3.54396999e-02, -1.42536983e-01,
#         -8.19285959e-03,  2.09507167e-01,  5.82309403e-02,  2.07134578e-02],
#        dtype=float32),
#  'last': array([ 0.1310569 ,  0.09155098,  0.18891628,  0.01272887, -0.03014077,
#          0.12848343,  0.1435064 , -0.19726975, -0.13518019,  0.12975597,
#          0.20208514, -0.03656139,  0.16663943,  0.04959926,  0.06459991,
#          0.13195454,  0.13238238,  0.02920999,  0.06870335, -0.1489554 ,
#         -0.07045616, -0.0446898 , -0.10975533, -0.07435125, -0.0759362 ,
#         -0.16717832, -0.02142411, -0.00608686, -0.07830577,  0.00655726,
#          0.10340666,  0.11370245,  0.00133997,  0.04129343,  0.00513146,
#          0.09181096,  0.07758737, -0.03451937,  0.00479323, -0.01578259,
#          0.18006763,  0.14334267,  0.04182778, -0.04602316,  0.20544472,
#         -0.03005512, -0.10496294,  0.16586354,  0.01943817, -0.17788373,
#         -0.02840705,  0.20030174, -0.02524987, -0.17072369,  0.06095527,
#          0.1299494 , -0.08021075, -0.09095404,  0.05776517,  0.0255555 ,
#         -0.02006407,  0.05035017, -0.17183495,  0.02924631,  0.01967234,
#          0.19383305, -0.0027924 , -0.10419188,  0.00594334, -0.0556591 ,
#         -0.06246758,  0.01059282,  0.1394063 ,  0.04505822, -0.04235024,
#          0.16310562,  0.0655803 ,  0.00834463, -0.0449733 ,  0.09840776,
#          0.09246743,  0.03476329,  0.04356744,  0.23050393,  0.04034036,
#         -0.0496852 ,  0.08288771, -0.02238671, -0.09886272, -0.01024427,
#         -0.02310086, -0.08128054,  0.11006852, -0.03359791, -0.13725953,
#         -0.1000038 , -0.06305028,  0.04681164,  0.00135435,  0.06184678],
#        dtype=float32),
#  'inc': array([-0.06781135,  0.06644272,  0.05308949,  0.27428514, -0.01074981,
#          0.1102183 , -0.03668773, -0.20299634, -0.06094988, -0.05202658,
#          0.0912755 , -0.01363035, -0.0299125 , -0.00046634,  0.17909788,
#         -0.03909906, -0.02237607, -0.07469424, -0.12374362,  0.08584669,
#          0.09219911,  0.1074355 , -0.0689407 ,  0.19499286, -0.06222569,
#         -0.12370009, -0.06056351, -0.02535514, -0.1723136 , -0.01176252,
#         -0.2843799 ,  0.03263092, -0.05392293, -0.03175305,  0.01705108,
#          0.09055684,  0.00369269, -0.03613907,  0.02601009,  0.02446577,
#         -0.03688338,  0.10130477,  0.00653416, -0.16525099,  0.19456899,
#         -0.09787257, -0.03437726,  0.16964708, -0.07799406, -0.02696193,
#          0.11837227,  0.18611766, -0.04139809, -0.21892466, -0.03719946,
#         -0.0994317 ,  0.06757073, -0.02922178,  0.02913849, -0.16373445,
#         -0.07652274,  0.00574645, -0.04835376, -0.01791412,  0.09547725,
#          0.02429007,  0.04126675,  0.1276225 ,  0.04640429,  0.03039348,
#         -0.18252546,  0.07435533, -0.04357193, -0.07896542, -0.02015011,
#          0.1564647 , -0.0181556 , -0.13505769,  0.10777442, -0.04807749,
#          0.04978514,  0.01913404,  0.10338391,  0.12461357, -0.15759847,
#          0.06482843,  0.08013365, -0.08847858,  0.08532178,  0.0381389 ,
#          0.11883618, -0.04215803, -0.04061867, -0.08848453,  0.07065349,
#         -0.08487838,  0.06595347, -0.10964369, -0.14845793, -0.0163532 ],
#        dtype=float32),
#  'yesterday': array([ 5.08414581e-02,  1.34829015e-01,  1.33243918e-01, -1.62504658e-01,
#         -1.33980826e-01, -1.63991600e-02,  1.18222348e-01, -1.34337142e-01,
#         -1.32177979e-01, -6.78753480e-02, -1.21319955e-02,  1.07460544e-01,
#          2.11116602e-03, -2.00271476e-02,  1.62677336e-02, -4.52251034e-03,
#          1.64604560e-02, -5.02981653e-04,  1.99459363e-02, -1.12900518e-01,
#          2.71901470e-02, -1.81038100e-02, -5.27187400e-02,  8.80066603e-02,
#         -1.71917528e-01,  3.20880860e-02, -5.87864071e-02, -2.31530797e-02,
#         -5.36835119e-02,  1.31180845e-02, -1.02941677e-01,  2.56151855e-01,
#          3.27505916e-03,  2.02243202e-04,  4.51498218e-02,  6.34852331e-03,
#         -7.89917186e-02, -1.03407754e-02,  5.96499704e-02,  1.00084143e-02,
#          7.21630976e-02,  3.88020128e-02,  7.06201941e-02, -2.18149498e-02,
#          1.83506727e-01, -1.09446853e-01, -5.44440374e-02,  3.44729602e-01,
#         -9.20971781e-02, -2.37008497e-01, -8.96035135e-02,  2.57791489e-01,
#         -3.78631689e-02, -2.04579726e-01,  1.12409525e-01,  6.37894720e-02,
#         -1.53864339e-01, -2.03087479e-01, -2.52858829e-02, -6.55264556e-02,
#         -2.43227445e-02, -7.07140192e-03,  7.60822892e-02, -1.60844713e-01,
#          3.22217867e-02, -6.57573715e-02, -4.31191362e-02, -8.60490575e-02,
#         -7.26849809e-02, -4.53957655e-02, -8.03240910e-02, -4.44555320e-02,
#          8.17404091e-02, -6.44585714e-02, -2.25259867e-02,  1.64716858e-02,
#         -3.25049721e-02,  2.37773452e-02,  1.17165251e-02,  1.64157450e-02,
#         -1.47471726e-01, -4.08966057e-02,  9.73769836e-03,  4.30227257e-02,
#         -3.82052250e-02,  1.25368712e-02,  1.45117849e-01,  2.05766479e-03,
#          4.87682177e-03,  4.16273735e-02, -6.52534440e-02, -4.74872738e-02,
#         -6.24580644e-02, -1.15827151e-01,  1.41560659e-01, -8.67824256e-02,
#          3.22194472e-02,  2.56412864e-01,  6.58279806e-02,  4.62961011e-02],
#        dtype=float32),
#  'year': array([ 0.00422158,  0.08372145, -0.03154688,  0.02317322,  0.08655442,
#         -0.02653388,  0.28413224, -0.11686954, -0.00081486, -0.13096805,
#          0.06033574, -0.02573077,  0.16910857,  0.06347567, -0.09934614,
#          0.0658596 , -0.14196181, -0.06638289,  0.08877409, -0.00492555,
#          0.00484397,  0.03041825, -0.23859489,  0.04243736,  0.01179204,
#         -0.01233293,  0.0109887 ,  0.14071943,  0.03669191, -0.02116457,
#         -0.2808377 ,  0.16706425, -0.05670519, -0.00913314,  0.01599854,
#         -0.18438827,  0.10320898, -0.07566958, -0.12043883, -0.03180883,
#          0.22297207,  0.17928201, -0.11528543, -0.21988276,  0.13800341,
#          0.03991061,  0.13236138,  0.1695209 ,  0.05272149, -0.17822304,
#          0.01331501,  0.08049492, -0.16340287, -0.13001202,  0.01727309,
#          0.01799087, -0.03141827,  0.07743518,  0.0051616 , -0.04650113,
#         -0.02548698,  0.08898851,  0.02783389, -0.0989242 , -0.13152786,
#         -0.03174842,  0.00425395,  0.02184211,  0.05657248,  0.07493427,
#         -0.08823948, -0.0222286 ,  0.08056618,  0.04294951,  0.05909188,
#          0.00628798, -0.01318014, -0.0772076 ,  0.04632859,  0.02731807,
#         -0.08169935, -0.0593906 , -0.02238082,  0.14610605, -0.08788176,
#         -0.0485257 ,  0.09995546, -0.03201467,  0.05968654,  0.11883131,
#          0.05824155, -0.06254505, -0.17160515, -0.0898765 ,  0.08925535,
#         -0.02818862, -0.15189224,  0.00625154,  0.03332165, -0.02518829],
#        dtype=float32),
#  'york': array([ 0.013888  ,  0.21142544,  0.1357645 , -0.0474177 , -0.00355037,
#          0.01151927,  0.12601571, -0.02214332, -0.09745118, -0.1844702 ,
#          0.06728446, -0.02178909,  0.02472411, -0.16952062,  0.13149792,
#          0.10139774, -0.08088873, -0.04195819, -0.00764804, -0.02382033,
#         -0.13124111, -0.09060477, -0.14515424,  0.07383594,  0.1199657 ,
#         -0.23117904, -0.04392562,  0.10147906,  0.07176677,  0.13457917,
#         -0.15052198,  0.13718331, -0.15519209,  0.08065937,  0.06270937,
#          0.0014469 ,  0.04235182, -0.05433858,  0.02123947, -0.17923068,
#          0.16067638,  0.02498653,  0.11114126, -0.24502183,  0.00766884,
#         -0.06116121, -0.05538974, -0.00025975,  0.04944986, -0.04930431,
#          0.03802886,  0.09739993,  0.08024336, -0.10709716,  0.07143057,
#         -0.02245636, -0.12216732, -0.10498923, -0.14892043, -0.15552896,
#          0.02970394, -0.02119038, -0.0070156 , -0.05558722,  0.21974105,
#          0.10331941, -0.07127444, -0.11181191,  0.06984732,  0.05077782,
#         -0.07951736,  0.04314246, -0.09786772, -0.03526632, -0.04867735,
#          0.02397634, -0.09899898,  0.03701957, -0.00915943,  0.02351718,
#          0.11724953, -0.00091585,  0.06981407,  0.14923987, -0.18678638,
#          0.10266677, -0.00122797, -0.02006083, -0.00731969,  0.18932655,
#          0.09672119, -0.1186192 ,  0.10509911, -0.07442167, -0.01262086,
#         -0.00883529,  0.13213554, -0.08422194, -0.03519873,  0.08184347],
#        dtype=float32),
#  'iraq': array([-0.00510424,  0.04294345,  0.17944504,  0.08264375,  0.03623786,
#         -0.10534328, -0.12538339,  0.09112607,  0.05242787, -0.17229378,
#          0.24251287,  0.0083467 ,  0.0139753 , -0.00750987,  0.11264093,
#          0.22133248, -0.05629917,  0.0639931 , -0.01677603,  0.07953232,
#         -0.00655929, -0.16165465, -0.08792833, -0.01211768, -0.14682318,
#          0.00286614, -0.04959067, -0.06092471,  0.01533499,  0.16919683,
#         -0.01819433,  0.22040631,  0.16691577, -0.04614846,  0.11809691,
#         -0.11041717,  0.12526765,  0.01349655, -0.0272402 , -0.15151834,
#          0.17206788,  0.06889918, -0.04222801, -0.04901309,  0.03509127,
#         -0.05596915,  0.01701332,  0.09942891, -0.02141177, -0.12707329,
#         -0.03936698,  0.18205234, -0.03520638, -0.14156173, -0.05325199,
#          0.01242785,  0.07170051,  0.00997832, -0.03937404, -0.01087833,
#          0.06530752,  0.19707501,  0.10772721, -0.12537633, -0.02379483,
#          0.060716  ,  0.07174811, -0.17548329,  0.00949846, -0.08090302,
#          0.04286619,  0.03385665,  0.0805033 ,  0.01745147, -0.112243  ,
#          0.02341506,  0.1002142 , -0.13997027, -0.07920003, -0.13426213,
#         -0.03914458, -0.11261772,  0.0957936 ,  0.10442562,  0.14336781,
#         -0.07315835,  0.20857282,  0.04898434,  0.00343381, -0.06169996,
#         -0.06373423, -0.13836029, -0.02353121, -0.03052838,  0.17860028,
#          0.02569669, -0.07900203, -0.1086592 , -0.02951553, -0.06727328],
#        dtype=float32),
#  'million': array([-1.29337445e-01,  7.88459033e-02,  9.76657644e-02, -2.49598958e-02,
#         -7.78172489e-06,  4.89059463e-02,  1.16837971e-01, -1.39519721e-01,
#         -9.08571780e-02, -6.56789541e-02, -1.08803585e-01,  5.31910136e-02,
#          2.06786707e-01,  2.70553771e-02,  1.27365459e-02, -1.22371919e-01,
#         -1.93756863e-01,  5.51609397e-02, -1.98026877e-02, -4.85058501e-02,
#          1.50663435e-01,  1.26454398e-01, -1.18121557e-01,  5.88067733e-02,
#          4.29740129e-03,  6.71133474e-02,  4.10346128e-02,  8.05057213e-02,
#         -2.28425190e-02,  6.34356737e-02,  5.97204594e-03, -8.53610858e-02,
#         -1.33239537e-01,  7.86428079e-02, -4.61618463e-03,  9.67794806e-02,
#          2.11038306e-01,  2.43545044e-02, -1.28340619e-02,  3.86993922e-02,
#          3.60378101e-02, -4.49573435e-03, -1.25962332e-01, -9.15653631e-02,
#          7.89298713e-02,  4.07382473e-02,  3.83723080e-02, -1.24598905e-01,
#          1.20765381e-01, -6.61508292e-02, -6.00963607e-02,  2.04705045e-01,
#         -1.93982292e-02, -2.43909344e-01, -9.96510461e-02,  1.33229000e-02,
#         -1.90726742e-01, -9.79865864e-02, -6.76174089e-02, -1.03733934e-01,
#         -1.62125602e-01, -8.89032707e-02,  5.78148253e-02, -1.30144089e-01,
#          1.13161512e-01, -6.66612089e-02,  1.64445579e-01, -8.36505815e-02,
#          1.18115386e-02, -7.97460601e-02, -9.54943523e-02, -5.42717986e-02,
#         -1.11811139e-01,  4.97404784e-02,  1.48261592e-01, -3.36254090e-02,
#          1.52001247e-01, -1.83869913e-01, -1.36228681e-01, -2.47769542e-02,
#         -5.57197891e-02, -4.01231088e-02,  3.87267657e-02,  1.13528460e-01,
#         -3.83500010e-02,  1.92711093e-02,  5.62863760e-02, -4.07709973e-03,
#          9.48546380e-02,  3.07615008e-02,  5.20986766e-02, -1.34056643e-01,
#         -6.17648009e-03, -2.98728421e-03,  1.63218364e-01, -1.11195609e-01,
#         -1.86521173e-01,  1.26749948e-01, -3.49028371e-02, -1.04004495e-01],
#        dtype=float32),
#  'microsoft': array([-0.09394723,  0.05939112,  0.10113586,  0.07570821,  0.03591201,
#         -0.05501366,  0.22749856,  0.05457627,  0.01120799,  0.03488869,
#          0.07776693, -0.12476382, -0.03133501, -0.14888212,  0.18764326,
#         -0.06439129,  0.07966503, -0.05655599, -0.18539357,  0.07482218,
#          0.03997158, -0.04917116,  0.03116877, -0.00443793, -0.09710985,
#         -0.16006988, -0.11393283, -0.16857527, -0.0821389 , -0.02475045,
#         -0.08386018,  0.04948064, -0.00869872,  0.18558036,  0.0252082 ,
#         -0.02176468,  0.02571218, -0.08069617,  0.07641466, -0.11534902,
#         -0.12890156,  0.15571961, -0.05844913, -0.12838684,  0.09314351,
#         -0.01550769,  0.09369159, -0.11069991,  0.04360092,  0.00752766,
#          0.11183801,  0.1514036 , -0.04485542, -0.15143172,  0.07018944,
#         -0.03711251, -0.09400365,  0.06781076, -0.14427385,  0.02938892,
#          0.00131896, -0.01582567, -0.16413797, -0.02411729, -0.07730318,
#          0.06068828,  0.15110889,  0.0382838 ,  0.0330091 , -0.16584593,
#         -0.08251487,  0.12472222, -0.00899912, -0.02788991, -0.04145902,
#         -0.02313798,  0.05573874, -0.17598851, -0.0983758 , -0.04565873,
#          0.08391763,  0.0741059 , -0.02338099,  0.15586703,  0.10529596,
#         -0.012286  ,  0.05616701, -0.09991699, -0.00127855,  0.13738452,
#         -0.15092659, -0.24032462, -0.2082866 , -0.15781422,  0.08223661,
#         -0.075576  ,  0.08906249,  0.00299902,  0.10253869,  0.03051673],
#        dtype=float32),
#  'president': array([ 0.09595491,  0.1333091 ,  0.05672335,  0.07931024,  0.22675087,
#          0.08459466,  0.08366805,  0.07578991, -0.11383349, -0.05998338,
#          0.00336389,  0.12516287,  0.00672967,  0.08172742,  0.05982364,
#          0.00629021,  0.07491209, -0.13387854, -0.0396269 ,  0.00091188,
#          0.02321647, -0.09426312,  0.19001478,  0.00548773,  0.01451017,
#         -0.13165198,  0.04459285, -0.03590291,  0.1840432 , -0.14367366,
#         -0.00298262,  0.05584407, -0.09939484,  0.10400349,  0.00026664,
#          0.11092798,  0.05732268,  0.06662373,  0.14628436, -0.070086  ,
#          0.13714953,  0.20704925, -0.04851807, -0.04693263,  0.00079211,
#         -0.01228395,  0.0146857 ,  0.12017905,  0.11097597, -0.01147946,
#         -0.11445704,  0.17066088, -0.03884403, -0.1655471 , -0.07837303,
#          0.0017893 , -0.06134234,  0.05102795,  0.06062457,  0.15062073,
#          0.04073382,  0.12337142,  0.07097071,  0.04386056,  0.04099057,
#         -0.16813208, -0.14770778, -0.09363169,  0.07128788,  0.00111218,
#         -0.0164908 ,  0.0186739 , -0.01071966, -0.00980531, -0.11475083,
#          0.02513461,  0.00902988,  0.12491532, -0.17528266, -0.01772563,
#          0.00493953, -0.22083132, -0.03711184,  0.15417744, -0.15591814,
#         -0.02032677,  0.17771268, -0.05098714, -0.13027628, -0.09289484,
#         -0.08190101, -0.04153091, -0.11372174, -0.08703514,  0.16768132,
#         -0.16532317, -0.11386338, -0.11607727, -0.05429149, -0.08315598],
#        dtype=float32),
#  'says': array([ 0.02782645,  0.16241364,  0.08502832, -0.00614393, -0.07431793,
#         -0.09351024,  0.18759786, -0.0640364 , -0.12430936, -0.18093567,
#          0.1922016 ,  0.18634768, -0.0127181 , -0.0862143 , -0.08193376,
#          0.12474252,  0.1375691 , -0.02603982,  0.06415308, -0.02579195,
#          0.02181226,  0.05853524, -0.12740105, -0.03341844, -0.03717791,
#         -0.14795357, -0.09530284,  0.0860865 ,  0.01581765,  0.03602134,
#          0.01279933,  0.18288322,  0.05915795, -0.01559354,  0.04554655,
#          0.05104563,  0.14705521,  0.08506928,  0.06805922, -0.07863542,
#          0.08495983,  0.17175679,  0.06815968, -0.06609011,  0.06508736,
#          0.03845714, -0.1082429 , -0.0080215 ,  0.18278414, -0.09462123,
#          0.23443232,  0.14633504, -0.08056705, -0.17594275, -0.01576375,
#          0.06017637,  0.06762571, -0.01789775,  0.06517952, -0.06761499,
#         -0.01970147,  0.07679633,  0.18416849, -0.04272648, -0.02093829,
#         -0.04585101,  0.15073721,  0.10289348, -0.05275106,  0.07958965,
#          0.0775406 , -0.03522517, -0.17720115, -0.06403469,  0.01385778,
#          0.10939216, -0.14508626, -0.02317197, -0.14643842,  0.00632509,
#         -0.06033642, -0.030081  ,  0.0492684 , -0.04005799,  0.04603908,
#          0.13171603,  0.18347757, -0.07293069, -0.11497988, -0.02847067,
#          0.02973664, -0.08017014,  0.04044733, -0.10801105,  0.21905164,
#          0.02710623, -0.0805293 , -0.10988889,  0.02527307, -0.04548237],
#        dtype=float32),
#  'game': array([ 0.1863222 ,  0.12516978,  0.20325485,  0.02473424, -0.1348867 ,
#          0.11473215,  0.08293367, -0.03214467,  0.03732508,  0.02111015,
#          0.06973255, -0.08910827,  0.02299329,  0.12293591, -0.05343107,
#         -0.07175583,  0.06437477, -0.16892047, -0.07356865,  0.06697454,
#         -0.1081439 , -0.11702416, -0.08318202,  0.04634359,  0.1033786 ,
#         -0.09506292,  0.05438023,  0.03319053, -0.02799274, -0.04973181,
#         -0.14644773,  0.15199453,  0.03277633, -0.0350939 , -0.03793899,
#         -0.11746752,  0.16519874, -0.16356075,  0.03889033, -0.13214229,
#          0.04991153,  0.07800937, -0.09021499, -0.13526177, -0.02254657,
#          0.14566895, -0.13254079,  0.10761655, -0.20662467, -0.12800834,
#         -0.00337888, -0.07404721,  0.08521931, -0.10864324, -0.11760846,
#          0.04848699, -0.13056226, -0.07269292, -0.07074995,  0.01182595,
#          0.05706256, -0.00561466,  0.0218532 , -0.03002036, -0.12670074,
#          0.0990426 ,  0.13997361, -0.00358924, -0.07429277, -0.25208068,
#         -0.11232183,  0.0418205 ,  0.02792647, -0.07769682,  0.10183672,
#          0.1614853 , -0.09880645, -0.05028741,  0.02761948,  0.10893399,
#          0.15647575,  0.02623123,  0.14452206,  0.14816661, -0.02692736,
#         -0.02399197,  0.1629708 , -0.15686819, -0.03807107,  0.04710029,
#         -0.04073567, -0.08745126,  0.15283343,  0.01415024, -0.01178529,
#         -0.03612915,  0.01859746,  0.03612348, -0.00959352, -0.12576379],
#        dtype=float32),
#  'corp': array([-0.13345431,  0.11405197,  0.19585092,  0.11540031, -0.0754564 ,
#          0.04802569,  0.0367283 ,  0.01375496,  0.00203357,  0.02107787,
#          0.1009798 , -0.05606719,  0.00501823,  0.06807151,  0.01234015,
#         -0.06896515,  0.01062509,  0.10270707, -0.20170166,  0.0846257 ,
#          0.00521337,  0.01927874, -0.01713046,  0.01575849, -0.12264241,
#         -0.11153851, -0.03187282, -0.14500992,  0.08514845, -0.04085986,
#         -0.25982192,  0.06509364, -0.04535428, -0.02677286,  0.00233091,
#          0.13542996,  0.07695026, -0.05188397, -0.0449814 , -0.07836353,
#         -0.03322272,  0.11443117, -0.10751704, -0.17688805,  0.11692068,
#         -0.08179796,  0.1331353 ,  0.06997517, -0.08510798, -0.04044028,
#          0.06207906,  0.3389675 , -0.20450291, -0.20177151, -0.05265832,
#         -0.14153332,  0.0039092 ,  0.02736384, -0.12162063, -0.17888758,
#         -0.02055888, -0.00199353, -0.03411992, -0.05191192,  0.06244729,
#          0.17404611,  0.1599324 ,  0.04986227, -0.02886678,  0.0091583 ,
#         -0.12460586,  0.0748178 ,  0.09297276,  0.02910743, -0.01853588,
#          0.05695455,  0.1077376 ,  0.0567649 , -0.02712723,  0.03384446,
#          0.07406011,  0.04092365,  0.17101969,  0.01222176, -0.05550336,
#         -0.03683661,  0.09270816, -0.05188946,  0.04124574,  0.09875619,
#          0.02337858, -0.1036613 ,  0.00498717, -0.122706  ,  0.10906628,
#         -0.09680691,  0.16109069, -0.10542262, -0.07619347, -0.06246481],
#        dtype=float32),
#  'united': array([-0.03290882,  0.2340226 ,  0.02919183,  0.07606185, -0.07601763,
#         -0.0167853 , -0.04002729, -0.128633  , -0.01432078,  0.02754124,
#         -0.00062374,  0.08781179, -0.07690958, -0.04954204,  0.00185261,
#         -0.02611844, -0.0116001 ,  0.00556308, -0.05407042, -0.0193454 ,
#         -0.06682826, -0.1466609 , -0.12630853,  0.12227671, -0.0490713 ,
#          0.00377678,  0.14715739,  0.1017476 , -0.14297168, -0.04096165,
#         -0.06768392,  0.16159168, -0.0681696 , -0.09099   , -0.02364465,
#         -0.00761242, -0.00522517, -0.05543472, -0.04237428,  0.03086483,
#          0.140188  ,  0.18864298,  0.04822024, -0.11102057,  0.03145286,
#         -0.15334475,  0.02707601,  0.07594327,  0.19030893, -0.11721539,
#          0.10327895,  0.0922038 ,  0.00172587, -0.18888497,  0.03571357,
#          0.07718899, -0.17871301,  0.19662268, -0.03108668, -0.06276892,
#         -0.00696617,  0.07074775,  0.02370089, -0.10929886,  0.02318795,
#         -0.01143345,  0.15437539,  0.12209402, -0.149646  , -0.0879636 ,
#         -0.04940756,  0.10904883,  0.2002672 ,  0.04240557, -0.10594991,
#          0.01776344, -0.07662743, -0.07246538, -0.11966448, -0.137103  ,
#         -0.07100986,  0.06213956,  0.06530073, -0.0478521 ,  0.18785757,
#          0.01229452, -0.01232764, -0.09191637, -0.13510825,  0.0632917 ,
#         -0.21690355, -0.18845236,  0.02805469, -0.076376  ,  0.02680453,
#         -0.21189028, -0.03920434,  0.00097466, -0.10070027, -0.11314737],
#        dtype=float32),
#  'week': array([ 0.01873241,  0.09528954,  0.1397916 , -0.13810752, -0.01415497,
#          0.05896213,  0.2751518 , -0.11692125, -0.11748572, -0.0038976 ,
#          0.21578018, -0.05567266,  0.03579794,  0.03546692,  0.13353647,
#          0.05197302, -0.06729936,  0.00609374,  0.05740354, -0.03057395,
#         -0.09790654,  0.0072509 , -0.01139164, -0.02357737, -0.034119  ,
#          0.0626407 , -0.12174183,  0.00252864, -0.01869334,  0.0066641 ,
#         -0.07369126,  0.27413508, -0.14401375,  0.08449268, -0.0662355 ,
#         -0.0206127 ,  0.02368339,  0.02388999, -0.01913812,  0.0345313 ,
#          0.23009059,  0.30181915,  0.02690956, -0.0957379 ,  0.1016748 ,
#         -0.03375921,  0.12747045,  0.13867114,  0.02072879, -0.1950227 ,
#         -0.04700546,  0.1279824 , -0.08081365, -0.21343783,  0.02474014,
#          0.07004195, -0.03695115,  0.04370047,  0.03136984, -0.10856486,
#         -0.0395332 ,  0.12488308, -0.21787186, -0.01905409,  0.05828934,
#          0.018416  ,  0.0346008 , -0.01684856,  0.01365743, -0.01979417,
#         -0.06539296, -0.05170636,  0.05749338, -0.02850417, -0.00161733,
#          0.19245575,  0.04251544, -0.01689992, -0.02372262,  0.07938553,
#         -0.07222853, -0.04103429,  0.00757275,  0.18237153,  0.05116829,
#          0.03448826,  0.13231482, -0.06521124, -0.03168013,  0.12542483,
#         -0.05116845,  0.01146988,  0.09676944, -0.0051927 , -0.00190712,
#         -0.08299596, -0.11653762, -0.0056419 ,  0.1595965 , -0.12992278],
#        dtype=float32),
#  'government': array([-0.0880691 ,  0.14420399,  0.18888214,  0.00208316, -0.02094231,
#         -0.12472942, -0.01174208,  0.06945288, -0.15960006, -0.22674938,
#          0.23357598,  0.01055792, -0.0810729 ,  0.05474752,  0.16992556,
#          0.10506671, -0.03476951, -0.12166686,  0.00151431, -0.02399633,
#          0.05475308,  0.0650222 ,  0.06114866,  0.02805289, -0.01006677,
#          0.02454414, -0.08294281, -0.0019712 ,  0.03686734,  0.08770283,
#         -0.02232035,  0.08636152,  0.01400253, -0.22078884,  0.04344038,
# ...
#          3.29817943e-02,  4.64226566e-02, -1.00846648e-01,  1.08184852e-02,
#         -2.06222124e-02, -6.34978488e-02, -9.41124409e-02,  2.80470215e-03,
#          1.89379275e-01, -1.58215404e-01, -3.68058197e-02, -6.00268133e-03,
#          1.21160485e-01, -1.32921815e-01, -7.74307176e-02,  1.49894995e-03,
#         -2.64227688e-02, -7.88493454e-02,  5.38673736e-02, -6.62981570e-02,
#          4.80004400e-02,  1.74576733e-02,  1.30130202e-01,  1.71784356e-01,
#          9.16318968e-03,  6.82019815e-02,  1.25685737e-01, -2.33359993e-01,
#         -4.81349342e-02, -1.88754931e-01,  8.13167095e-02,  7.60386661e-02,
#          1.42358199e-01, -9.23895836e-02, -6.69347644e-02,  2.48708010e-01,
#          4.35010195e-02, -1.28152400e-01,  7.64451642e-03,  1.69664934e-01,
#         -2.20122352e-01,  6.27484769e-02,  7.62984622e-03,  1.15240216e-01,
#          1.47245720e-01, -5.60374418e-03, -6.93577304e-02, -4.75273952e-02,
#          1.04099140e-02, -5.33392541e-02,  2.62348093e-02, -1.43083230e-01,
#         -1.20182276e-01, -1.06381729e-01,  7.72241354e-02, -9.09610279e-03,
#         -1.21522592e-02, -6.61781505e-02, -5.94577104e-05, -3.45823541e-02,
#         -2.77265847e-01, -7.96650052e-02,  4.00970085e-03,  2.98937038e-03,
#         -5.46524767e-03, -7.87876770e-02,  4.36382294e-02, -8.99393484e-03,
#         -9.38974228e-03, -7.02071115e-02,  1.99154541e-01,  6.75211623e-02,
#          6.36408627e-02, -5.18186465e-02, -3.90163902e-03, -9.30082723e-02,
#          7.77110532e-02,  1.12333307e-02,  2.16601148e-01,  4.67367992e-02,
#         -1.47395387e-01,  8.41155276e-03, -1.44693244e-03,  7.46404976e-02],
#        dtype=float32),
#  'needs': array([ 6.45518452e-02,  1.07118927e-01,  9.63807404e-02,  1.99343842e-02,
#         -1.07927650e-01, -1.07151724e-01,  6.56861141e-02, -2.26201892e-01,
#          1.39366211e-02, -9.10304710e-02, -8.87663513e-02,  9.92815420e-02,
#          1.20114930e-01,  3.72427814e-02,  7.27400333e-02,  7.76101127e-02,
#          3.78291719e-02,  4.16535102e-02, -2.90900841e-02, -6.74129054e-02,
#         -1.64230406e-01,  1.86988562e-02, -1.32937118e-01, -1.55963257e-01,
#          3.21993022e-03, -1.59748852e-01, -5.62232211e-02,  8.39331895e-02,
#         -2.84235179e-02, -3.34508568e-02, -2.89088264e-02,  1.29739583e-01,
#         -4.33587097e-02, -4.30633686e-02, -2.51488704e-02, -3.38912047e-02,
#         -9.62161347e-02,  8.74311477e-02,  8.16534013e-02, -1.19388446e-01,
#          2.19776765e-01,  1.60286054e-01, -7.06874952e-02, -1.10444605e-01,
#          4.85203415e-02, -1.31630018e-01, -1.32335667e-02,  6.84819371e-02,
#          1.29772812e-01, -6.47471026e-02,  4.55430672e-02,  1.55896425e-01,
#         -9.84701328e-03, -2.92018622e-01, -6.66150898e-02,  5.02849370e-02,
#         -1.59534708e-01,  2.90782992e-02, -1.57143638e-01, -1.49406686e-01,
#          5.72751127e-02,  1.40052542e-01,  6.27974467e-03, -6.56393245e-02,
#         -9.30642262e-02, -1.92218479e-02,  1.33312136e-01,  1.64021894e-01,
#         -2.85006203e-02,  5.10067260e-03, -1.05830051e-01, -4.00572121e-02,
#         -1.79780573e-02,  3.08614206e-02, -3.33254710e-02, -4.35649678e-02,
#         -9.13902670e-02, -6.76519647e-02, -2.34382331e-01, -2.18560267e-02,
#         -7.37611670e-03,  1.10020757e-01, -5.59555565e-06,  1.64294273e-01,
#         -7.84035325e-02,  1.04518175e-01,  1.38779759e-01, -7.30252191e-02,
#         -4.77070808e-02,  7.62230083e-02,  1.54359236e-01, -9.90309119e-02,
#         -3.90648618e-02, -1.47341313e-02,  6.45709708e-02, -1.19026974e-01,
#         -8.08512494e-02, -1.39113784e-01, -2.61677578e-02,  3.10958121e-02],
#        dtype=float32),
#  'continues': array([-0.05635448,  0.173187  ,  0.17810646, -0.04450068, -0.06456336,
#         -0.04756999,  0.10888167, -0.14578414,  0.03468881, -0.0669248 ,
#          0.1261907 ,  0.05962313,  0.14343677, -0.12177449,  0.00369848,
#          0.04545796, -0.01671525, -0.01599442,  0.01282171, -0.08656734,
#          0.07727958,  0.00444513, -0.13543732, -0.10782792,  0.04071895,
#         -0.22672135, -0.01739999,  0.04475069, -0.06200939,  0.01154906,
#         -0.05603523,  0.24547562,  0.02660189,  0.11197119, -0.04609469,
#         -0.14724897, -0.05835009, -0.07191207, -0.0035958 , -0.02736031,
#          0.18562599,  0.27348495,  0.01922329, -0.10421769, -0.05373923,
#         -0.02232265, -0.0336911 ,  0.05322719,  0.08418453, -0.18776487,
#          0.09327985,  0.0488816 ,  0.01192182, -0.22738762, -0.00124595,
#         -0.01172168, -0.1862698 ,  0.00877549, -0.06629794, -0.05563911,
#         -0.01273909,  0.03997201,  0.22178431,  0.04282838, -0.18024851,
#         -0.01509656,  0.04849194,  0.03105296,  0.00085035, -0.09150516,
#         -0.0637527 , -0.19590044, -0.05005004,  0.13790573, -0.10254861,
#         -0.04473396,  0.14229499, -0.12182597, -0.01400623,  0.0874052 ,
#         -0.08612742,  0.1906541 , -0.00375053,  0.15105905,  0.01516187,
#         -0.00695247,  0.08224241, -0.08727748, -0.00554373,  0.07862236,
#          0.02506729, -0.11934421, -0.01036327, -0.06241319,  0.04173573,
#          0.06724827,  0.00861225, -0.08908797,  0.02307117, -0.06622735],
#        dtype=float32),
#  'role': array([ 0.05292049,  0.22494867,  0.0536166 , -0.04987383,  0.01978286,
#         -0.1101822 ,  0.09737855, -0.12108155, -0.04474716, -0.04526728,
#          0.00174648,  0.05364887,  0.03100808, -0.11044433,  0.02469568,
#          0.03231212,  0.12131242, -0.06387273,  0.01580048,  0.00165469,
#         -0.10684358, -0.09853409, -0.15301415, -0.14846593, -0.00939724,
#         -0.18208872, -0.07637534,  0.05951487,  0.005356  , -0.02981481,
#          0.06080628,  0.06901482, -0.07366835,  0.03128977, -0.03466059,
#         -0.10799594, -0.13971284,  0.12541193,  0.09289536,  0.08104146,
#          0.140056  ,  0.16018288, -0.07792477, -0.20189597, -0.01702614,
#         -0.10878696, -0.08581016,  0.12394353,  0.05805921, -0.22727256,
#         -0.05034976,  0.23584285, -0.1233106 , -0.3309344 , -0.04194078,
#          0.12442049, -0.1155185 ,  0.03716214, -0.00397312, -0.04795793,
#          0.05530415,  0.12747036,  0.09002215, -0.05891398, -0.13760294,
#         -0.07575276,  0.02690053,  0.00134336, -0.15078731, -0.06852055,
#         -0.12325279,  0.04273253, -0.00066409, -0.04434272, -0.01177307,
#         -0.08823381, -0.09399924, -0.10331552, -0.11342468,  0.02666352,
#         -0.04563535, -0.02031064, -0.04627967,  0.09129176,  0.05346939,
#          0.06024186,  0.17940712, -0.08307009, -0.04802216,  0.03932953,
#         -0.01680668, -0.17793615,  0.03928463,  0.02008362,  0.05502405,
#         -0.02917926, -0.16237079, -0.01264471,  0.05769719,  0.0509957 ],
#        dtype=float32),
#  'howard': array([ 0.02018062,  0.01122956,  0.04570626,  0.06844795,  0.07579882,
#         -0.1292488 ,  0.0671079 , -0.16171724, -0.05786844, -0.13419704,
#          0.19291718,  0.03033234, -0.03309485, -0.04323232, -0.00383707,
#         -0.07111094, -0.04824201, -0.0154969 , -0.1579755 ,  0.04709663,
#          0.1512259 , -0.1329985 , -0.10349339,  0.08663645,  0.0193964 ,
#         -0.23893371, -0.07527476, -0.01215095, -0.00842988, -0.05852035,
#         -0.05308855,  0.19589865,  0.13801983, -0.10972588, -0.11544835,
#          0.03282993, -0.02122355, -0.1027939 ,  0.12641653, -0.04391705,
#          0.03503942,  0.09741589,  0.01951   , -0.18082066, -0.02320653,
#         -0.02498395, -0.03698957, -0.05691046,  0.1019943 , -0.1757774 ,
#         -0.13813785,  0.21384515, -0.00964578, -0.20718104,  0.03290627,
#          0.15633765, -0.13810922,  0.01112991, -0.12258476,  0.10916908,
#          0.03697849, -0.07931197,  0.04876909, -0.11723427,  0.15446275,
#         -0.00449168, -0.15622169, -0.16417548, -0.00405464, -0.08410464,
#         -0.00958898, -0.02541238, -0.11759003, -0.06640045, -0.08763236,
#         -0.00382844, -0.0264608 , -0.01596237, -0.0679305 ,  0.05396467,
#          0.03916378,  0.02614734,  0.00747439,  0.00972327, -0.20517616,
#         -0.13281451,  0.16645873,  0.01663093,  0.00095025,  0.0046916 ,
#         -0.00417528, -0.06431146, -0.02377034, -0.02196071, -0.05290955,
#         -0.11409435, -0.21435729, -0.14436701,  0.10773097, -0.00091208],
#        dtype=float32),
#  'homes': array([-0.10143337,  0.16982603,  0.11285394, -0.03750876, -0.03296463,
#          0.05009991,  0.13353345, -0.18549706, -0.11109646, -0.07793862,
#          0.01889657, -0.0331419 ,  0.2130154 ,  0.07903324,  0.06215358,
#         -0.1139608 , -0.01189647, -0.09637585, -0.06302317,  0.0467193 ,
#          0.14188185, -0.09258017,  0.01877725,  0.03748689,  0.12453969,
#         -0.06174954,  0.0174367 , -0.05414668, -0.03158607,  0.07710553,
#         -0.08695513,  0.29605496,  0.01382872,  0.07435413, -0.01646906,
#          0.08597067,  0.07010455,  0.16833183,  0.03488728, -0.05031275,
#          0.25115484,  0.17374776, -0.0133325 , -0.11820859,  0.07212928,
#          0.05108274, -0.01076555,  0.05937065,  0.05862694, -0.11892027,
#          0.05873254,  0.0436891 ,  0.07513177, -0.19371212,  0.02931505,
#         -0.00839362, -0.11702648, -0.1804828 , -0.03199666, -0.14302656,
#         -0.01093954,  0.09589156,  0.16888413, -0.05619989, -0.026819  ,
#         -0.00569011,  0.01385208,  0.04947783, -0.18708225,  0.02986859,
#          0.10270867,  0.03850568, -0.02771881,  0.10467292,  0.02417136,
#         -0.06898057,  0.19103631, -0.1751654 ,  0.05895602,  0.06344447,
#         -0.05122497,  0.13680941, -0.03677731,  0.01955533,  0.07702123,
#         -0.03781218,  0.02504497,  0.10948364,  0.15574008, -0.07974495,
#         -0.01728626, -0.0670994 , -0.17284177, -0.01585287,  0.03813795,
#         -0.02402277, -0.03305405, -0.11568149, -0.13367522, -0.02698836],
#        dtype=float32),
#  'medical': array([-3.63281593e-02,  1.83189854e-01,  1.76766351e-01, -3.44618894e-02,
#         -4.37313803e-02,  3.32763642e-02, -2.34412402e-02, -6.19869195e-02,
#         -3.33536528e-02, -1.81218646e-02, -1.32100461e-02, -6.35278597e-02,
#         -7.39530921e-02,  1.19890176e-01,  6.55830130e-02,  2.72578094e-02,
#          1.26933530e-01, -3.77266260e-04, -9.91902277e-02, -3.41371372e-02,
#         -5.98088466e-02,  3.04803234e-02,  5.71750402e-02,  1.10391423e-01,
#          1.32716909e-01,  4.04686071e-02, -8.76571238e-02, -3.37134525e-02,
#         -7.19882175e-02,  5.22205718e-02, -2.41670124e-02,  2.30873749e-01,
#          6.29615271e-03, -2.86290180e-02, -3.16045247e-02,  4.14678790e-02,
#          1.02505580e-01,  5.56775630e-02,  1.56391263e-02, -1.43781111e-01,
#          1.73435286e-01,  8.46078321e-02, -1.77932352e-01, -1.00232348e-01,
#          1.47342071e-01, -1.73787966e-01, -1.33331358e-01,  7.51786530e-02,
#         -1.13274507e-01, -2.00696439e-01, -1.82223003e-02,  2.46875599e-01,
#          1.21596821e-01, -1.62254721e-01, -5.67793660e-02, -2.24584807e-02,
#          6.25422131e-03,  5.73129654e-02, -1.36769088e-02, -1.16920367e-01,
#          3.47673073e-02,  1.08234167e-01,  1.40920177e-01, -1.87759906e-01,
#          3.32453214e-02, -3.65594625e-02, -7.15009198e-02,  7.38057345e-02,
#         -1.02815665e-01, -5.10701798e-02, -9.89295542e-02,  1.95053384e-01,
#         -1.09934427e-01,  2.18528546e-02, -1.01174355e-01,  7.26815388e-02,
#          4.05221209e-02, -1.14769809e-01, -1.90602869e-01,  1.95820600e-01,
#         -4.76015881e-02,  7.10901171e-02, -1.55448390e-03, -7.44067058e-02,
#         -8.28622133e-02,  2.08036289e-01,  9.17416587e-02, -4.34513483e-03,
#         -6.94558024e-02,  3.64984833e-02, -1.78464334e-02,  1.13183698e-04,
#          1.13913222e-04,  1.44154802e-01, -1.65466145e-02, -3.22501585e-02,
#         -3.13291810e-02, -1.55252069e-01,  3.28223929e-02, -5.65814301e-02],
#        dtype=float32),
#  'create': array([-0.0679531 ,  0.14271136,  0.23867412,  0.13568339, -0.01760535,
#         -0.07915131,  0.04491145, -0.0968978 ,  0.01154971, -0.11144914,
#         -0.07278454,  0.10016718, -0.02006402, -0.04893947,  0.11827088,
#         -0.01510832,  0.04304246,  0.07581738, -0.02657515,  0.0892691 ,
#          0.09016932, -0.01681451, -0.07498175,  0.00168183,  0.08543599,
#         -0.04903365, -0.13400418,  0.01294774, -0.09310386, -0.03058328,
#         -0.20074072,  0.14209718,  0.01844493,  0.07818478,  0.09553044,
#          0.08494363,  0.01646122,  0.14141431, -0.04390256,  0.03726329,
#          0.14072601,  0.24222565, -0.14165764, -0.04331878,  0.13871774,
#         -0.16068147,  0.04923319,  0.02320113, -0.16132258, -0.10120253,
#          0.05273367,  0.09165071, -0.01712012, -0.17817289, -0.13823238,
#         -0.04393858, -0.1307873 , -0.08631372, -0.00612732, -0.09973974,
#         -0.0383622 ,  0.01166318, -0.00634843,  0.01366072,  0.00788328,
#         -0.0550738 ,  0.03849068,  0.04662052, -0.05035571, -0.16229896,
#         -0.03969486,  0.01448792, -0.157735  ,  0.02239602, -0.14324817,
#         -0.10808263,  0.1031955 , -0.12290258, -0.06246118,  0.19738638,
#         -0.098481  ,  0.06817451, -0.0079299 ,  0.18728065, -0.01047544,
#          0.08342671,  0.19457163, -0.03607362, -0.05076924,  0.11918576,
#          0.19254239, -0.10441873,  0.00347974, -0.04498315,  0.14872368,
#         -0.03933674, -0.09974226, -0.07966172, -0.10251062, -0.01456558],
#        dtype=float32),
#  'losing': array([ 0.09387701,  0.06174846,  0.1612483 , -0.03901927, -0.0035755 ,
#         -0.01457765,  0.05728606, -0.14039344, -0.06764821,  0.06310314,
#          0.04297427,  0.00455429,  0.11879359,  0.06491593,  0.04633099,
#          0.01610302, -0.03772845, -0.00943903,  0.10087326, -0.01527414,
#         -0.08001591, -0.09012897, -0.15661794, -0.05017859, -0.03453204,
#         -0.19769049,  0.02396923,  0.13709176,  0.02295498,  0.03429625,
#         -0.11750216,  0.19176282, -0.09601912,  0.09239511,  0.0255444 ,
#         -0.19825846,  0.06849591, -0.08624131,  0.00233465, -0.04467274,
#          0.10106127,  0.16137941, -0.0201803 , -0.2219228 ,  0.12399478,
#         -0.09399992,  0.03060668,  0.12247513,  0.09666739, -0.11986051,
#          0.02377413,  0.04249464,  0.05769799, -0.2054987 , -0.00513245,
#          0.01129993, -0.21902646,  0.123024  , -0.18499078, -0.0787506 ,
#          0.13735215,  0.02064855,  0.00489635, -0.00844468, -0.07574709,
#          0.11554009,  0.06960292, -0.11213014,  0.03560303, -0.10419826,
#         -0.13061595, -0.11330312,  0.11838052,  0.04009958, -0.03122571,
#          0.00703596, -0.02969072, -0.06879571, -0.0150949 ,  0.09915233,
#          0.0119806 ,  0.12644355,  0.10744411,  0.1097137 , -0.04934743,
#          0.11489245,  0.17695718, -0.09496137, -0.12342404,  0.04905998,
#          0.00983177, -0.14679445,  0.06099621, -0.20874722,  0.1620662 ,
#         -0.07627766, -0.1279083 ,  0.0499418 , -0.05817659,  0.00197619],
#        dtype=float32),
#  'italy': array([-0.05756338,  0.23904216,  0.07426196,  0.04376148, -0.11659604,
#         -0.10236079, -0.03145458, -0.06501967,  0.0749355 ,  0.05301855,
#          0.09703357, -0.11701484,  0.09109787,  0.00036188,  0.03468002,
#          0.02722445, -0.09999042,  0.0024713 , -0.02484942,  0.06679922,
#          0.03963522, -0.15127958, -0.04106812,  0.04279694,  0.11004403,
#          0.06328974,  0.03468018,  0.10478369,  0.04672762,  0.04999658,
#         -0.09262224,  0.12522931,  0.00874584,  0.00922694,  0.06224699,
#         -0.09332725, -0.02655677,  0.03289095,  0.03779596, -0.02827911,
#          0.0263737 ,  0.10767819,  0.13413125, -0.14536488,  0.03247924,
#         -0.31945553, -0.06020092,  0.11301653,  0.11380504, -0.12255821,
#          0.0822076 ,  0.15138821, -0.02875365, -0.15793836,  0.06692147,
#          0.12504557, -0.16370788,  0.09608913,  0.08066044,  0.06151216,
#         -0.00624928, -0.0343485 ,  0.16218396, -0.13646992,  0.03557483,
#          0.02845649,  0.06646198, -0.13615403, -0.02798505, -0.0660018 ,
#          0.07497125,  0.01453267,  0.06362364,  0.17593783, -0.21955784,
#         -0.09498533, -0.0275809 , -0.15527664, -0.03173073,  0.10242313,
#         -0.07223062, -0.17617142,  0.07101639,  0.02121125,  0.04336417,
#         -0.02784848,  0.20329127,  0.05484472,  0.06727033, -0.01098453,
#         -0.06727601, -0.16397357,  0.00504222, -0.15020534,  0.16022952,
#          0.05091257, -0.152567  ,  0.10217573, -0.01670194, -0.05310566],
#        dtype=float32),
#  ...}

# %% [markdown]
# Expressions below demonstrate the 100-dimensional representation of the‘computer’ word and the most relevant context words estimated with cosine similarity.

# %%
    w_model_sg.wv['computer']
# Out:
# array([ 0.06388441, -0.08133382, -0.13676958,  0.10582004,  0.06654062,
#        -0.04945404,  0.07931393,  0.08044662, -0.19894224, -0.04958534,
#         0.08718207, -0.20376472, -0.02995504, -0.11479849, -0.09902271,
#         0.08149272, -0.02656364, -0.00617725, -0.01187406, -0.13356061,
#         0.05705734, -0.0504782 ,  0.21819203,  0.14567892,  0.11150423,
#         0.22995125, -0.13097145, -0.04231865, -0.05635202,  0.01697813,
#         0.09151268,  0.08142684,  0.09050979, -0.07395874,  0.02765094,
#        -0.10545062, -0.07931811,  0.00223664, -0.00463745, -0.06310347,
#         0.019389  ,  0.17977041,  0.17574738,  0.04723195,  0.0760856 ,
#        -0.00848501,  0.12051502,  0.15135323, -0.02821335, -0.07651005,
#        -0.05400637, -0.06249378, -0.03090185, -0.1311977 ,  0.13637047,
#        -0.01506626, -0.06128463,  0.07527307,  0.03063625, -0.02353359,
#        -0.135863  ,  0.11806294,  0.00530435, -0.06856249,  0.13208763,
#         0.02626646, -0.05626931, -0.24905108, -0.03653201, -0.05046824,
#        -0.01047773, -0.00566028,  0.03844219, -0.16854328, -0.18983673,
#        -0.00351789, -0.03189205, -0.00683244, -0.07032195, -0.11395986,
#         0.15294251, -0.10210698,  0.05696347,  0.02076365, -0.00205236,
#        -0.05633365,  0.00996392,  0.03992171,  0.09938776,  0.10060339,
#         0.06184255,  0.03764948,  0.06169024, -0.07659867,  0.02831339,
#        -0.15962256, -0.02482823, -0.03540504, -0.31427738,  0.04544675],
#       dtype=float32)

# %%
w_model_sg.wv.most_similar('computer')
# Out:
# [('computers', 0.7709169387817383),
#  ('powerbook', 0.7192236185073853),
#  ('hacker', 0.7096250057220459),
#  ('personal', 0.7085227966308594),
#  ('ibook', 0.6991468667984009),
#  ('macintosh', 0.6917257308959961),
#  ('aapl', 0.6909997463226318),
#  ('pc', 0.6901720762252808),
#  ('cupertino', 0.6838955879211426),
#  ('accessed', 0.6793504953384399)]

# %% [markdown]
# Furthermore, it is possible to calculate a similarity between two words

# %%
w_model_sg.wv.similarity('ibm', 'computer')
# Out:
# 0.6137135

# %% [markdown]
# The expression below excludes an irrelevant word from the list of three

# %%
w_model_sg.wv.doesnt_match(['computer', 'paris', 'berlin'])
# Out:
# 'computer'

# %% [markdown]
# # Training ML algorithms

# %% [markdown]
# One common approach to performing classification with ML algorithms is to calculate the average feature vector for each list of words in the training dataset.

# %% [markdown]
# Word averaging has been performed with defined by https://gist.github.com/susanli2016/dae5c9ff3cea5744822384881fc619dd#file-word_averaging
# function, which iterates through each row of the input text, extracts 100-dimensional vectorial representation and then calculates mean value by each column (axis=0)

# %%
def word_averaging(wv, words):
    all_words, mean = set(), []
    
    for word in words:
        if isinstance(word, np.ndarray):
            mean.append(word)
        elif word in wv.vocab:
            mean.append(wv.vectors_norm[wv.vocab[word].index])
            all_words.add(wv.vocab[word].index)

    if not mean:
        logging.warning("cannot compute similarity with no input %s", words)
        return np.zeros(wv.vector_size,)

    mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
    return mean

def  word_averaging_list(wv, text_list):
    return np.vstack([word_averaging(wv, post) for post in text_list ])

# %%
X_train_word_average_sg = word_averaging_list(w_model_sg.wv, np.array(sent))
X_train_word_average_sg.shape
# Out:
# (40000, 100)

# %% [markdown]
# After applying defined averaging function, transformed dataset with dimensions (40000,100) is ready to be processed through Linear SVM, Logistic Regression and Random Forest ML algorithms. Naïve Bayes has been excluded due to negative values in the training dataset

# %%
params = [{ 'clf': [LinearSVC(max_iter = 7000)],
          'clf__C':[0.5, 1, 10, 50, 100, 500]},
          
          {'clf': [LogisticRegression(max_iter = 9000)],
           'clf__solver': ['newton-cg', 'lbfgs', 'liblinear'],
           'clf__C': [1, 100, 500, 800]
          }]

# RandomForest Hyperparameters
n_estimators = [100, 250, 400]
max_features = ['auto', 'sqrt']
max_depth = [30,60,90, None]
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
criterion = ['entropy', 'gini']


r_f_par = {   'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'criterion': criterion
           }

# %%
pipe2 = Pipeline([('clf', LinearSVC())])

# %% [markdown]
# As for TF-IDF method, Linear SVM, Logistic Regression and Random Forest algorithms were estimated and tuned through 3-fold grid and randomized search tools with ‘accuracy’ scoring.

# %%
search_sg = GridSearchCV(pipe2, params,cv = 3,return_train_score = True, n_jobs = -1, scoring = 'accuracy')
search_sg.fit(X_train_word_average_sg, y_train)
print(search_sg.best_params_)
# Out:
# {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 500, 'clf__solver': 'liblinear'}

# %%
df3 = pd.DataFrame.from_dict(search_sg.cv_results_)
df3[['params', 'mean_test_score', 'mean_train_score', 'rank_test_score']].sort_values(by=['mean_test_score'], ascending=False)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                             params  \
# 9   {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 500, 'clf__solver': 'liblinear'}
# 3   {'clf': LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=7000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 50}
# 4   {'clf': LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=7000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 100}
# 2   {'clf': LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=7000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 10}
# 5   {'clf': LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=7000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 500}
# 12  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__solver': 'liblinear'}
# 10  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__solver': 'newton-cg'}
# 11  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 100, 'clf__solver': 'lbfgs'}
# 7   {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 500, 'clf__solver': 'newton-cg'}
# 1   {'clf': LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=7000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 1}
# 13  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 10, 'clf__solver': 'newton-cg'}
# 8   {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 500, 'clf__solver': 'lbfgs'}
# 15  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 10, 'clf__solver': 'liblinear'}
# 14  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 10, 'clf__solver': 'lbfgs'}
# 0   {'clf': LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=7000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 0.5}
# 6   {'clf': LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#           intercept_scaling=1, loss='squared_hinge', max_iter=7000,
#           multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#           verbose=0), 'clf__C': 1000}
# 16  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__solver': 'newton-cg'}
# 17  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__solver': 'lbfgs'}
# 18  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 1.0, 'clf__solver': 'liblinear'}
# 19  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.1, 'clf__solver': 'newton-cg'}
# 20  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.1, 'clf__solver': 'lbfgs'}
# 21  {'clf': LogisticRegression(C=500, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=9000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='liblinear', tol=0.0001, verbose=0,
#                    warm_start=False), 'clf__C': 0.1, 'clf__solver': 'liblinear'}
#
#     mean_test_score  mean_train_score  rank_test_score
# 9   0.886075         0.888675          1
# 3   0.886000         0.888600          2
# 4   0.885950         0.888625          3
# 2   0.885750         0.888575          4
# 5   0.885600         0.888475          5
# 12  0.885500         0.888487          6
# 10  0.885500         0.888537          7
# 11  0.885450         0.888562          8
# 7   0.885200         0.888537          9
# 1   0.885200         0.887712          10
# 13  0.885150         0.888200          11
# 8   0.885125         0.888487          12
# 15  0.885100         0.887662          13
# 14  0.885075         0.888162          14
# 0   0.885050         0.887287          15
# 6   0.883600         0.885650          16
# 16  0.883050         0.884775          17
# 17  0.883050         0.884762          17
# 18  0.882300         0.883687          19
# 19  0.875300         0.875825          20
# 20  0.875300         0.875812          20
# 21  0.872900         0.873450          22

# %%
r_f_clf = RandomForestClassifier()
r_f2 = RandomizedSearchCV(r_f_clf, r_f_par, cv = 3, return_train_score = True, n_jobs = -1, scoring = 'accuracy')
r_f2.fit(X_train_word_average_sg,y_train)
print(r_f2.best_params_)
# Out:
# {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30, 'criterion': 'gini'}

# %%
df7 = pd.DataFrame.from_dict(r_f2.cv_results_)
df7[['params', 'mean_test_score', 'mean_train_score','mean_fit_time', 'rank_test_score']].sort_values(by=['mean_test_score'], ascending=False)
# Out:
#                                                                                                                                    params  \
# 2  {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30, 'criterion': 'gini'}
# 7  {'n_estimators': 250, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 90, 'criterion': 'entropy'}
# 5  {'n_estimators': 400, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 30, 'criterion': 'gini'}
# 3  {'n_estimators': 250, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 60, 'criterion': 'entropy'}
# 0  {'n_estimators': 250, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 9  {'n_estimators': 400, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 8  {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 90, 'criterion': 'gini'}
# 4  {'n_estimators': 100, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 1  {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 90, 'criterion': 'entropy'}
# 6  {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
#
#    mean_test_score  mean_train_score  mean_fit_time  rank_test_score
# 2  0.890225         0.999400          210.500233     1
# 7  0.889525         0.998237          150.769254     2
# 5  0.889250         0.995250          221.109260     3
# 3  0.889025         0.977188          146.604610     4
# 0  0.888850         0.990925          119.318242     5
# 9  0.888275         0.963050          134.553910     6
# 8  0.888100         0.981900          54.498798      7
# 4  0.887075         0.962150          49.541311      8
# 1  0.886325         0.967188          54.791506      9
# 6  0.885550         0.962475          51.079988      10

# %% [markdown]
# Although the highest score of about 88,8% achieved with Random Forest algorithm, this model has been overfitted with accuracy 99,99% on the training dataset.
# Thus, Logistic regression algorithm with accuracy scores 88,6% on validation and 88,8% on training datasets was selected as the best model.

# %%
best_lr = search_sg.best_estimator_

# %%
start = time.time()

best_lr.fit(X_train_word_average_sg,y_train)

elapsed = time.time() - start
print('\n Completed training in {} seconds.'.format(elapsed),end='\n\n')
# Out:
#  Completed training in 8.134909868240356 seconds.

# %% [markdown]
# Saving the best-performed model to the pkl-format file

# %%
joblib_file = "best_w2v.pkl"
joblib.dump(best_lr, joblib_file)
# Out:
# ['best_w2v.pkl']

# %% [markdown]
# # Evaluation on the test dataset

# %% [markdown]
# Transforming cleaned test dataset to the list of lists format

# %%
#load cleaned test data
clean_test_data = load_doc('clean_test_data.txt')

# %%
test_sent = [row.split() for row in clean_test_data]

# %% [markdown]
# Word averaging with devined earlier function

# %%
X_test_word_average_sg = word_averaging_list(w_model_sg.wv,np.array(test_sent))

# %% [markdown]
# Applying Logistic Regression algorithm with the best tuned hyperparameters on the test dataset, the accuracy score 88,7% has been achieved.

# %% [markdown]
# The best result has been achieved by sports news topic with 967 from 1000 correctly classified articles. The most classification errors (160) have been generated by Business topic.

# %%
# Load the best model
best_lr = joblib.load("best_w2v.pkl")

# %%
#Creating the list with unique category names
aux_df = test_data[['category_name', 'label']].drop_duplicates().sort_values('label')

#prediction on the cleaned test dataset
y_pred = best_lr.predict(X_test_word_average_sg)

print('Test dataset accuracy score:', accuracy_score(y_test, y_pred),'\n')
print(classification_report(y_test, y_pred, target_names=aux_df['category_name'].values))

con = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(12,9))
ax_cor_b = sns.heatmap(con.T, square=False, annot=True, fmt='d', cbar=False,
            xticklabels=aux_df['category_name'].values, 
            yticklabels=aux_df['category_name'].values,
            cmap="Blues")
plt.xlabel('true label')
plt.ylabel('predicted label')
plt.title('Confusion matrix')
plt.show()
# Out:
# Test dataset accuracy score: 0.887
#
#               precision    recall  f1-score   support
#
#        world       0.91      0.89      0.90      1000
#       sports       0.94      0.97      0.95      1000
#     business       0.85      0.84      0.84      1000
#     sci/tech       0.85      0.85      0.85      1000
#
#     accuracy                           0.89      4000
#    macro avg       0.89      0.89      0.89      4000
# weighted avg       0.89      0.89      0.89      4000

# %% [markdown]
# # Deep Learning Model

# %%
from tensorflow import keras
from keras.models import load_model
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Embedding, LSTM, GRU, TimeDistributed, Bidirectional, GlobalMaxPooling1D

from keras.callbacks import ModelCheckpoint
from keras.layers.convolutional import Conv1D, MaxPooling1D

# %% [markdown]
# The first step to develop a Deep Learning (DL) model is to import a 100-dimensional vector with 53,202 unique words Word2vec model, pre-trained in the previous section. The function below imports pre-trained model and returns words inside the dictionary.
# The function build by https://machinelearningmastery.com/develop-word-embedding-model-predicting-movie-review-sentiment/

# %%
# load embedding as a dict
def load_embedding(filename):
    # load embedding into memory, skip first line
    file = open(filename,'r')
    lines = file.readlines()[1:]
    file.close()
    # create a map of words to vectors
    embedding = dict()
    for line in lines:
        parts = line.split()
        # key is string word, value is numpy array for vector
        embedding[parts[0]] = asarray(parts[1:], dtype='float32')
    return embedding

# %%
imported_vocab = load_embedding('embedding_sg_word2vec.txt')

# %% [markdown]
# The next step is to encode the training data by assigning integer number to each unique word and then convert each row of the source text to sequences of corresponding integers. Encoding has been performed with Keras Tokenizer tool

# %%
#Load files and Tokenizer
#clean_data = load_doc('clean_data.txt')
#clean_test_data = load_doc('clean_test_data.txt')
#tokenizer1 = joblib.load('C_LSTM_tokenizer.pkl')

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(clean_data)

encoded_docs_tr = tokenizer1.texts_to_sequences(clean_data)
encoded_docs_te = tokenizer1.texts_to_sequences(clean_test_data)

# %%
#saving Tokenizer
#joblib.dump(tokenizer1, 'C_LSTM_tokenizer.pkl')
# Out:
# ['CNN_tokenizer.pkl']

# %% [markdown]
# Calling word_index attribute demonstrates how each unique word has been encoded with integer numbers

# %%
tokenizer1.word_index
# Out:
# {'new': 1,
#  'said': 2,
#  'us': 3,
#  'reuters': 4,
#  'ap': 5,
#  'first': 6,
#  'two': 7,
#  'world': 8,
#  'thursday': 9,
#  'oil': 10,
#  'monday': 11,
#  'wednesday': 12,
#  'tuesday': 13,
#  'company': 14,
#  'one': 15,
#  'friday': 16,
#  'last': 17,
#  'inc': 18,
#  'yesterday': 19,
#  'year': 20,
#  'york': 21,
#  'iraq': 22,
#  'million': 23,
#  'microsoft': 24,
#  'president': 25,
#  'says': 26,
#  'game': 27,
#  'corp': 28,
#  'united': 29,
#  'week': 30,
#  'government': 31,
#  'three': 32,
#  'prices': 33,
#  'could': 34,
#  'years': 35,
#  'time': 36,
#  'would': 37,
#  'security': 38,
#  'software': 39,
#  'sunday': 40,
#  'today': 41,
#  'afp': 42,
#  'group': 43,
#  'people': 44,
#  'quot': 45,
#  'may': 46,
#  'percent': 47,
#  'team': 48,
#  'next': 49,
#  'win': 50,
#  'back': 51,
#  'saturday': 52,
#  'night': 53,
#  'internet': 54,
#  'deal': 55,
#  'sales': 56,
#  'market': 57,
#  'season': 58,
#  'second': 59,
#  'minister': 60,
#  'china': 61,
#  'state': 62,
#  'announced': 63,
#  'former': 64,
#  'top': 65,
#  'international': 66,
#  'killed': 67,
#  'billion': 68,
#  'business': 69,
#  'washington': 70,
#  'news': 71,
#  'report': 72,
#  'profit': 73,
#  'day': 74,
#  'bush': 75,
#  'open': 76,
#  'plans': 77,
#  'record': 78,
#  'victory': 79,
#  'officials': 80,
#  'end': 81,
#  'stocks': 82,
#  'set': 83,
#  'states': 84,
#  'chief': 85,
#  'home': 86,
#  'talks': 87,
#  'european': 88,
#  'service': 89,
#  'court': 90,
#  'search': 91,
#  'city': 92,
#  'four': 93,
#  'lead': 94,
#  'technology': 95,
#  'reported': 96,
#  'cup': 97,
#  'computer': 98,
#  'american': 99,
#  'shares': 100,
#  'third': 101,
#  'online': 102,
#  'british': 103,
#  'league': 104,
#  'national': 105,
#  'red': 106,
#  'federal': 107,
#  'take': 108,
#  'network': 109,
#  'police': 110,
#  'prime': 111,
#  'google': 112,
#  'another': 113,
#  'major': 114,
#  'make': 115,
#  'ltbgtltbgt': 116,
#  'least': 117,
#  'help': 118,
#  'according': 119,
#  'space': 120,
#  'iraqi': 121,
#  'un': 122,
#  'web': 123,
#  'leader': 124,
#  'bank': 125,
#  'maker': 126,
#  'final': 127,
#  'coach': 128,
#  'companies': 129,
#  'made': 130,
#  'south': 131,
#  'plan': 132,
#  'india': 133,
#  'san': 134,
#  'country': 135,
#  'research': 136,
#  'japan': 137,
#  'music': 138,
#  'say': 139,
#  'bid': 140,
#  'get': 141,
#  'games': 142,
#  'hit': 143,
#  'big': 144,
#  'ibm': 145,
#  'election': 146,
#  'mobile': 147,
#  'largest': 148,
#  'way': 149,
#  'series': 150,
#  'london': 151,
#  'high': 152,
#  'expected': 153,
#  'industry': 154,
#  'co': 155,
#  'growth': 156,
#  'month': 157,
#  'still': 158,
#  'quarter': 159,
#  'five': 160,
#  'baghdad': 161,
#  'giant': 162,
#  'north': 163,
#  'since': 164,
#  'cut': 165,
#  'earnings': 166,
#  'services': 167,
#  'nuclear': 168,
#  'early': 169,
#  'sports': 170,
#  'phone': 171,
#  'href': 172,
#  'wireless': 173,
#  'gold': 174,
#  'months': 175,
#  'higher': 176,
#  'trade': 177,
#  'data': 178,
#  'test': 179,
#  'system': 180,
#  'john': 181,
#  'move': 182,
#  'military': 183,
#  'union': 184,
#  'players': 185,
#  'start': 186,
#  'lta': 187,
#  'official': 188,
#  'agreed': 189,
#  'loss': 190,
#  'buy': 191,
#  'attack': 192,
#  'australia': 193,
#  'dollar': 194,
#  'rose': 195,
#  'war': 196,
#  'left': 197,
#  'nations': 198,
#  'days': 199,
#  'weeks': 200,
#  'many': 201,
#  'press': 202,
#  'apple': 203,
#  'sox': 204,
#  'troops': 205,
#  'jobs': 206,
#  'stock': 207,
#  'palestinian': 208,
#  'latest': 209,
#  'gaza': 210,
#  'including': 211,
#  'olympic': 212,
#  'air': 213,
#  'play': 214,
#  'england': 215,
#  'found': 216,
#  'general': 217,
#  'ahead': 218,
#  'windows': 219,
#  'ago': 220,
#  'executive': 221,
#  'released': 222,
#  'oracle': 223,
#  'like': 224,
#  'users': 225,
#  'past': 226,
#  'intel': 227,
#  'global': 228,
#  'russia': 229,
#  'points': 230,
#  'economy': 231,
#  'forces': 232,
#  'russian': 233,
#  'israeli': 234,
#  'man': 235,
#  'football': 236,
#  'investors': 237,
#  'six': 238,
#  'reports': 239,
#  'go': 240,
#  'biggest': 241,
#  'price': 242,
#  'peace': 243,
#  'part': 244,
#  'canadian': 245,
#  'even': 246,
#  'firm': 247,
#  'economic': 248,
#  'update': 249,
#  'despite': 250,
#  'near': 251,
#  'rise': 252,
#  'pay': 253,
#  'athens': 254,
#  'iran': 255,
#  'west': 256,
#  'offer': 257,
#  'case': 258,
#  'held': 259,
#  'boston': 260,
#  'free': 261,
#  'drug': 262,
#  'release': 263,
#  'europe': 264,
#  'title': 265,
#  'peoplesoft': 266,
#  'pakistan': 267,
#  'public': 268,
#  'work': 269,
#  'beat': 270,
#  'nearly': 271,
#  'video': 272,
#  'much': 273,
#  'eu': 274,
#  'agency': 275,
#  'key': 276,
#  'strong': 277,
#  'use': 278,
#  'run': 279,
#  'australian': 280,
#  'uk': 281,
#  'media': 282,
#  'wins': 283,
#  'launch': 284,
#  'systems': 285,
#  'car': 286,
#  'street': 287,
#  'foreign': 288,
#  'head': 289,
#  'nasa': 290,
#  'support': 291,
#  'power': 292,
#  'financial': 293,
#  'attacks': 294,
#  'workers': 295,
#  'presidential': 296,
#  'number': 297,
#  'share': 298,
#  'contract': 299,
#  'round': 300,
#  'lower': 301,
#  'charges': 302,
#  'leaders': 303,
#  'close': 304,
#  'used': 305,
#  'linux': 306,
#  'america': 307,
#  'might': 308,
#  'digital': 309,
#  'fall': 310,
#  'bomb': 311,
#  'crude': 312,
#  'sun': 313,
#  'death': 314,
#  'francisco': 315,
#  'darfur': 316,
#  'rival': 317,
#  'fell': 318,
#  'scientists': 319,
#  'pc': 320,
#  'japanese': 321,
#  'face': 322,
#  'st': 323,
#  'called': 324,
#  'tokyo': 325,
#  'agreement': 326,
#  'player': 327,
#  'championship': 328,
#  'took': 329,
#  'wall': 330,
#  'french': 331,
#  'program': 332,
#  'seven': 333,
#  'october': 334,
#  'version': 335,
#  'leading': 336,
#  'following': 337,
#  'job': 338,
#  'long': 339,
#  'good': 340,
#  'right': 341,
#  'products': 342,
#  'life': 343,
#  'quote': 344,
#  'return': 345,
#  'november': 346,
#  'region': 347,
#  'put': 348,
#  'half': 349,
#  'around': 350,
#  'best': 351,
#  'killing': 352,
#  'customers': 353,
#  'chicago': 354,
#  'site': 355,
#  'due': 356,
#  'keep': 357,
#  'september': 358,
#  'trial': 359,
#  'israel': 360,
#  'also': 361,
#  'elections': 362,
#  'florida': 363,
#  'per': 364,
#  'center': 365,
#  'korea': 366,
#  'away': 367,
#  'party': 368,
#  'late': 369,
#  'race': 370,
#  'manager': 371,
#  'give': 372,
#  'yankees': 373,
#  'house': 374,
#  'study': 375,
#  'france': 376,
#  'vote': 377,
#  'campaign': 378,
#  'demand': 379,
#  'hurricane': 380,
#  'management': 381,
#  'kerry': 382,
#  'capital': 383,
#  'without': 384,
#  'pm': 385,
#  'dead': 386,
#  'increase': 387,
#  'central': 388,
#  'northern': 389,
#  'gets': 390,
#  'recent': 391,
#  'takes': 392,
#  'militants': 393,
#  'battle': 394,
#  'future': 395,
#  'fans': 396,
#  'commission': 397,
#  'email': 398,
#  'bill': 399,
#  'fourth': 400,
#  'meeting': 401,
#  'cuts': 402,
#  'southern': 403,
#  'judge': 404,
#  'strike': 405,
#  'net': 406,
#  'defense': 407,
#  'several': 408,
#  'hostage': 409,
#  'conference': 410,
#  'board': 411,
#  'costs': 412,
#  'consumer': 413,
#  'fight': 414,
#  'little': 415,
#  'office': 416,
#  'hopes': 417,
#  'whether': 418,
#  'amp': 419,
#  'nation': 420,
#  'told': 421,
#  'energy': 422,
#  'quarterly': 423,
#  'making': 424,
#  'baseball': 425,
#  'results': 426,
#  'giants': 427,
#  'worlds': 428,
#  'decision': 429,
#  'champion': 430,
#  'well': 431,
#  'using': 432,
#  'saying': 433,
#  'running': 434,
#  'line': 435,
#  'men': 436,
#  'champions': 437,
#  'sell': 438,
#  'army': 439,
#  'place': 440,
#  'straight': 441,
#  'thirdquarter': 442,
#  'michael': 443,
#  'chip': 444,
#  'show': 445,
#  'scored': 446,
#  'small': 447,
#  'arafat': 448,
#  'force': 449,
#  'health': 450,
#  'server': 451,
#  'britain': 452,
#  'sony': 453,
#  'winning': 454,
#  'school': 455,
#  'political': 456,
#  'california': 457,
#  'profile': 458,
#  'interest': 459,
#  'real': 460,
#  'rates': 461,
#  'rebels': 462,
#  'taking': 463,
#  'soldiers': 464,
#  'mark': 465,
#  'los': 466,
#  'department': 467,
#  'grand': 468,
#  'bankruptcy': 469,
#  'airlines': 470,
#  'ceo': 471,
#  'east': 472,
#  'likely': 473,
#  'violence': 474,
#  'become': 475,
#  'university': 476,
#  'field': 477,
#  'oct': 478,
#  'times': 479,
#  'accused': 480,
#  'source': 481,
#  'canada': 482,
#  'across': 483,
#  'call': 484,
#  'almost': 485,
#  'revenue': 486,
#  'lost': 487,
#  'among': 488,
#  'law': 489,
#  'profits': 490,
#  'claims': 491,
#  'information': 492,
#  'chinese': 493,
#  'unit': 494,
#  'control': 495,
#  'hits': 496,
#  'williams': 497,
#  'sudan': 498,
#  'takeover': 499,
#  'stores': 500,
#  'possible': 501,
#  'aid': 502,
#  'history': 503,
#  'look': 504,
#  'yet': 505,
#  'nov': 506,
#  'eight': 507,
#  'injured': 508,
#  'phones': 509,
#  'match': 510,
#  'hold': 511,
#  'desktop': 512,
#  'amid': 513,
#  'led': 514,
#  'angeles': 515,
#  'behind': 516,
#  'morning': 517,
#  'launched': 518,
#  'calls': 519,
#  'ipod': 520,
#  'boost': 521,
#  'drop': 522,
#  'access': 523,
#  'engine': 524,
#  'meet': 525,
#  'warned': 526,
#  'texas': 527,
#  'senior': 528,
#  'exchange': 529,
#  'star': 530,
#  'gas': 531,
#  'going': 532,
#  'stadium': 533,
#  'tax': 534,
#  'shot': 535,
#  'must': 536,
#  'weekend': 537,
#  'cash': 538,
#  'come': 539,
#  'tv': 540,
#  'david': 541,
#  'less': 542,
#  'club': 543,
#  'rate': 544,
#  'yahoo': 545,
#  'houston': 546,
#  'paris': 547,
#  'operating': 548,
#  'outlook': 549,
#  'wants': 550,
#  'television': 551,
#  'barrel': 552,
#  'radio': 553,
#  'trading': 554,
#  'probe': 555,
#  'better': 556,
#  'find': 557,
#  'got': 558,
#  'see': 559,
#  'change': 560,
#  'production': 561,
#  'sale': 562,
#  'reach': 563,
#  'product': 564,
#  'chairman': 565,
#  'cell': 566,
#  'toronto': 567,
#  'thousands': 568,
#  'reserve': 569,
#  'action': 570,
#  'afghanistan': 571,
#  'makes': 572,
#  'fire': 573,
#  'german': 574,
#  'posted': 575,
#  'rally': 576,
#  'helped': 577,
#  'opposition': 578,
#  'communications': 579,
#  'signed': 580,
#  'seen': 581,
#  'stop': 582,
#  'food': 583,
#  'germany': 584,
#  'came': 585,
#  'began': 586,
#  'tour': 587,
#  'tech': 588,
#  'fuel': 589,
#  'begin': 590,
#  'concerns': 591,
#  'markets': 592,
#  'indian': 593,
#  'offering': 594,
#  'august': 595,
#  'soon': 596,
#  'women': 597,
#  'teams': 598,
#  'gains': 599,
#  'white': 600,
#  'showed': 601,
#  'networks': 602,
#  'low': 603,
#  'al': 604,
#  'coast': 605,
#  'old': 606,
#  'ltd': 607,
#  'afghan': 608,
#  'supply': 609,
#  'heart': 610,
#  'countries': 611,
#  'nfl': 612,
#  'secretary': 613,
#  'investment': 614,
#  'ready': 615,
#  'ended': 616,
#  'blair': 617,
#  'store': 618,
#  'division': 619,
#  'african': 620,
#  'black': 621,
#  'arrested': 622,
#  'list': 623,
#  'medal': 624,
#  'performance': 625,
#  'sign': 626,
#  'looking': 627,
#  'olympics': 628,
#  'forecast': 629,
#  'visit': 630,
#  'madrid': 631,
#  'insurance': 632,
#  'yards': 633,
#  'station': 634,
#  'stake': 635,
#  'miami': 636,
#  'competition': 637,
#  'died': 638,
#  'charged': 639,
#  'threat': 640,
#  'spain': 641,
#  'local': 642,
#  'computers': 643,
#  'money': 644,
#  'need': 645,
#  'far': 646,
#  'step': 647,
#  'human': 648,
#  'great': 649,
#  'fund': 650,
#  'opening': 651,
#  'earlier': 652,
#  'association': 653,
#  'council': 654,
#  'executives': 655,
#  'terror': 656,
#  'beijing': 657,
#  'sept': 658,
#  'charge': 659,
#  'western': 660,
#  'rivals': 661,
#  'drive': 662,
#  'airways': 663,
#  'others': 664,
#  'nine': 665,
#  'yukos': 666,
#  'missing': 667,
#  'fighting': 668,
#  'ever': 669,
#  'weapons': 670,
#  'family': 671,
#  'airline': 672,
#  'euro': 673,
#  'outside': 674,
#  'dell': 675,
#  'gave': 676,
#  'continue': 677,
#  'retailer': 678,
#  'within': 679,
#  'efforts': 680,
#  'analysts': 681,
#  'aimed': 682,
#  'fears': 683,
#  'bowl': 684,
#  'already': 685,
#  'authorities': 686,
#  'americans': 687,
#  'getting': 688,
#  'hours': 689,
#  'administration': 690,
#  'effort': 691,
#  'chance': 692,
#  'trying': 693,
#  'enough': 694,
#  'ruling': 695,
#  'raised': 696,
#  'seattle': 697,
#  'rights': 698,
#  'hard': 699,
#  'finally': 700,
#  'development': 701,
#  'flight': 702,
#  'push': 703,
#  'cisco': 704,
#  'sees': 705,
#  'legal': 706,
#  'growing': 707,
#  'filed': 708,
#  'operations': 709,
#  'children': 710,
#  'corporate': 711,
#  'cost': 712,
#  'bay': 713,
#  'nba': 714,
#  'storage': 715,
#  'problems': 716,
#  'focus': 717,
#  'paul': 718,
#  'members': 719,
#  'college': 720,
#  'consumers': 721,
#  'failed': 722,
#  'suicide': 723,
#  'private': 724,
#  'pressure': 725,
#  'continued': 726,
#  'africa': 727,
#  'coming': 728,
#  'rules': 729,
#  'mission': 730,
#  'known': 731,
#  'target': 732,
#  'spending': 733,
#  'rebel': 734,
#  'name': 735,
#  'george': 736,
#  'crisis': 737,
#  'moscow': 738,
#  'personal': 739,
#  'green': 740,
#  'retail': 741,
#  'toward': 742,
#  'holiday': 743,
#  'sharon': 744,
#  'taken': 745,
#  'palestinians': 746,
#  'jones': 747,
#  'researchers': 748,
#  'ban': 749,
#  'popular': 750,
#  'reached': 751,
#  'devices': 752,
#  'officer': 753,
#  'basketball': 754,
#  'winter': 755,
#  'available': 756,
#  'quarterback': 757,
#  'delta': 758,
#  'nokia': 759,
#  'fraud': 760,
#  'kills': 761,
#  'asian': 762,
#  'firms': 763,
#  'injury': 764,
#  'suspected': 765,
#  'hope': 766,
#  'staff': 767,
#  'arsenal': 768,
#  'electronics': 769,
#  'lawsuit': 770,
#  'survey': 771,
#  'dollars': 772,
#  'soccer': 773,
#  'main': 774,
#  'warning': 775,
#  'designed': 776,
#  'labor': 777,
#  'kill': 778,
#  'goal': 779,
#  'side': 780,
#  'starting': 781,
#  'powerful': 782,
#  'defeat': 783,
#  'calif': 784,
#  'blue': 785,
#  'approved': 786,
#  'groups': 787,
#  'provide': 788,
#  'accounting': 789,
#  'shows': 790,
#  'italian': 791,
#  'planned': 792,
#  'park': 793,
#  'rising': 794,
#  'try': 795,
#  'storm': 796,
#  'large': 797,
#  'satellite': 798,
#  'fresh': 799,
#  'securities': 800,
#  'walmart': 801,
#  'career': 802,
#  'turn': 803,
#  'tony': 804,
#  'losses': 805,
#  'boeing': 806,
#  'selling': 807,
#  'policy': 808,
#  'build': 809,
#  'never': 810,
#  'challenge': 811,
#  'giving': 812,
#  'islamic': 813,
#  'muslim': 814,
#  'faces': 815,
#  'blast': 816,
#  'chips': 817,
#  'asia': 818,
#  'bring': 819,
#  'offers': 820,
#  'cp': 821,
#  'davis': 822,
#  'singh': 823,
#  'went': 824,
#  'guard': 825,
#  'town': 826,
#  'attempt': 827,
#  'yasser': 828,
#  'detroit': 829,
#  'working': 830,
#  'holding': 831,
#  'short': 832,
#  'goes': 833,
#  'lines': 834,
#  'employees': 835,
#  'annual': 836,
#  'allow': 837,
#  'tournament': 838,
#  'risk': 839,
#  'businesses': 840,
#  'signs': 841,
#  'manchester': 842,
#  'hundreds': 843,
#  'drugs': 844,
#  'debate': 845,
#  'atlanta': 846,
#  'speed': 847,
#  'experts': 848,
#  'seeks': 849,
#  'named': 850,
#  'launches': 851,
#  'order': 852,
#  'pilots': 853,
#  'astros': 854,
#  'debt': 855,
#  'enterprise': 856,
#  'current': 857,
#  'sets': 858,
#  'safety': 859,
#  'claim': 860,
#  'worth': 861,
#  'sent': 862,
#  'fallujah': 863,
#  'broadband': 864,
#  'gain': 865,
#  'credit': 866,
#  'island': 867,
#  'sold': 868,
#  'congress': 869,
#  'want': 870,
#  'issues': 871,
#  'every': 872,
#  'investigation': 873,
#  'strip': 874,
#  'december': 875,
#  'water': 876,
#  'post': 877,
#  'najaf': 878,
#  'alleged': 879,
#  'seeking': 880,
#  'applications': 881,
#  'track': 882,
#  'disney': 883,
#  'newsfactor': 884,
#  'point': 885,
#  'ivan': 886,
#  'process': 887,
#  'warns': 888,
#  'added': 889,
#  'xp': 890,
#  'finance': 891,
#  'prison': 892,
#  'rises': 893,
#  'full': 894,
#  'ireland': 895,
#  'road': 896,
#  'cricket': 897,
#  'philadelphia': 898,
#  'leave': 899,
#  'building': 900,
#  'let': 901,
#  'area': 902,
#  'hostages': 903,
#  'hand': 904,
#  'stay': 905,
#  'singapore': 906,
#  'posts': 907,
#  'regulators': 908,
#  'unveiled': 909,
#  'offensive': 910,
#  'merger': 911,
#  'closer': 912,
#  'miss': 913,
#  'ground': 914,
#  'louis': 915,
#  'poll': 916,
#  'changes': 917,
#  'ryder': 918,
#  'minutes': 919,
#  'given': 920,
#  'opened': 921,
#  'issue': 922,
#  'middle': 923,
#  'woods': 924,
#  'kashmir': 925,
#  'runs': 926,
#  'young': 927,
#  'mike': 928,
#  'turned': 929,
#  'code': 930,
#  'expectations': 931,
#  'nasdaq': 932,
#  'fired': 933,
#  'militant': 934,
#  'confirmed': 935,
#  'tennis': 936,
#  'huge': 937,
#  'average': 938,
#  'democratic': 939,
#  'sites': 940,
#  'hp': 941,
#  'comes': 942,
#  'dow': 943,
#  'suspended': 944,
#  'insurgents': 945,
#  'sprint': 946,
#  'concern': 947,
#  'spokesman': 948,
#  'file': 949,
#  'putin': 950,
#  'join': 951,
#  'debut': 952,
#  'minnesota': 953,
#  'course': 954,
#  'claimed': 955,
#  'event': 956,
#  'playing': 957,
#  'increased': 958,
#  'project': 959,
#  'body': 960,
#  'mars': 961,
#  'golf': 962,
#  'evidence': 963,
#  'greece': 964,
#  'settle': 965,
#  'amd': 966,
#  'moon': 967,
#  'formula': 968,
#  'aug': 969,
#  'hospital': 970,
#  'sources': 971,
#  'rule': 972,
#  'banks': 973,
#  'streak': 974,
#  'vs': 975,
#  'clear': 976,
#  'prize': 977,
#  'bad': 978,
#  'travel': 979,
#  'companys': 980,
#  'files': 981,
#  'wounded': 982,
#  'watch': 983,
#  'brazil': 984,
#  'urged': 985,
#  'plane': 986,
#  'equipment': 987,
#  'asked': 988,
#  'forward': 989,
#  'camp': 990,
#  'captain': 991,
#  'needs': 992,
#  'continues': 993,
#  'role': 994,
#  'howard': 995,
#  'homes': 996,
#  'medical': 997,
#  'create': 998,
#  'losing': 999,
#  'italy': 1000,
#  ...}

# %% [markdown]
# One of the dimensions of the Keras embedding layer is the vocabulary size. This number equal to the number of unique words + 1 (because of Keras indexing from zero) is 53203

# %%
vocab_size = len(tokenizer1.word_index) + 1
vocab_size
# Out:
# 53203

# %% [markdown]
# Keras embedding layer has been built by mapping encoded integers to the vocabulary with pre-trained weights. The mapping process has been performed with get_weight_matrix function, where weight matrix with dimensions (53203, 100) mapped pre-trained weights with integer numbers.
#
# The function build by https://machinelearningmastery.com/develop-word-embedding-model-predicting-movie-review-sentiment/

# %%
# create a weight matrix for the Embedding layer from a loaded embedding
def get_weight_matrix(embedding, vocab):
    # total vocabulary size plus 0 for unknown words
    vocab_size = len(vocab) + 1
    # define weight matrix dimensions with all 0
    weight_matrix = zeros((vocab_size, 100))
    # step vocab, store vectors using the Tokenizer's integer mapping
    for word, i in vocab.items():
        weight_matrix[i] = embedding.get(word)
    return weight_matrix

# %%
embedding_vectors = get_weight_matrix(imported_vocab, tokenizer1.word_index)

# %% [markdown]
# Finally, training and testing datasets with appropriate to Keras format might be created with a defined earlier encoded-word dictionary. One of the Keras requirement is that input data should be a vector in the same length, therefore training and testing datasets zero-padded to 90 (maximum length of the vector in the training dataset)

# %%
max_length = max([len(s.split()) for s in clean_data])
max_length
# Out:
# 90

# %%
Xtrain = pad_sequences(encoded_docs_tr, maxlen=max_length, padding='post')
Xtest = pad_sequences(encoded_docs_te, maxlen=max_length, padding='post')

# %%
Xtrain.shape
# Out:
# (40000, 90)

# %% [markdown]
# Class attributes on both train and test datasets should be one-hot encoded

# %%
#load label encoder
#le = joblib.load('label_encoder.pkl')

# %%
le = preprocessing.LabelEncoder()
train_data['labeling'] = le.fit_transform(train_data['label'])
test_data['labeling'] = le.transform(test_data['label'])
num_classes = np.max(train_data['labeling']) + 1

# %%
#saving label encoder
#joblib.dump(le, 'label_encoder.pkl')

# %%
ytrain = keras.utils.to_categorical(train_data['labeling'],num_classes)
ytest = keras.utils.to_categorical(test_data['labeling'],num_classes)

# %% [markdown]
# In the present work, news articles classification task was performed with C-LSTM Neural Network model, which consists of both CNN and LSTM layers.

# %% [markdown]
# The following parameters were applied to train C-LSTM model:
# “categorical_crossentropy” loss function – because of multiclass nature of the classification task and the one-hot representation of the labels.
# "softmax" output activation function, as it accommodates multiple classes into the normalized probabilistic vector with the total sum one.
# “accuracy” performance measure, since classes in the dataset well balanced.
# “batch_size” equal to 128, in order to increase the training speed of the model.

# %% [markdown]
# Another hyperparameters such as filters number, kernel size, dropout rate, optimizer, activation function and the number of hidden layers were tuned with Talos library https://autonomio.github.io/talos/#/

# %% [markdown]
# First step is define the function that builds, compiles and fits the Keras model

# %%
def clf_model(x_train, y_train, x_val, y_val, params):
    model_CNN6 = Sequential()
    model_CNN6.add(Embedding(vocab_size, 100, weights=[embedding_vectors], input_length=max_length, trainable=False))
    model_CNN6.add(Dropout(0.3))
    model_CNN6.add(Conv1D(filters=params['filters'], kernel_size = params['kernel_size'], activation='relu'))
    model_CNN6.add(MaxPooling1D(pool_size=2))
    model_CNN6.add(Dropout(0.3))
    model_CNN6.add(LSTM(64, recurrent_dropout=0.15))
    model_CNN6.add(Dropout(0.3))
    model_CNN6.add(Dense(16, activation='relu'))


    model_CNN6.add(Dense(4, activation='softmax'))
    
    model_CNN6.compile(loss='categorical_crossentropy', optimizer=params['optimizer'], metrics=['accuracy'])

    history = model_CNN6.fit(x_train, y_train, 
                        validation_data=[x_val, y_val],
                        batch_size=128,
                        callbacks=[talos.utils.live()],
                        epochs=10,
                        verbose=0)

    return history, model_CNN6

# %% [markdown]
# Hyperparameter space

# %%
p = {'filters': [64, 128, 256],
     'kernel_size': [4, 5, 8],
     'optimizer': ['Nadam', 'Adam']
    }

# %% [markdown]
# After defining the function and hyperparameters space, Talos might be initiated with Scan command

# %% [markdown]
# 20% of the training dataset was selected for validation

# %%
exp8 = talos.Scan(x=Xtrain,
               y=ytrain,
               val_split = 0.2,
               model=clf_model,
               params=p,
               experiment_name='clf8',
               seed = 44,
               round_limit = 18
                 )
# Out:
# 100%|██████████| 18/18 [3:35:22<00:00, 822.24s/it]

# %%
exp8.data.head(18).sort_values(by=['val_accuracy'], ascending=False)
# Out:
#     round_epochs  val_loss  val_accuracy      loss  accuracy  filters  \
# 17            10  0.286478      0.899000  0.269526  0.905781      256
# 16            10  0.298538      0.895625  0.296623  0.900719      256
# 2             10  0.290606      0.895500  0.280066  0.903188      128
# 10            10  0.300019      0.895500  0.288677  0.902344      256
# 14            10  0.293536      0.894750  0.284947  0.902594      256
# 8             10  0.308003      0.893750  0.311851  0.894781      128
# 4             10  0.315393      0.893375  0.309617  0.895094      128
# 7             10  0.304281      0.893000  0.310762  0.895063      256
# 12            10  0.318829      0.891125  0.326161  0.890063      128
# 3             10  0.307992      0.891125  0.310003  0.896031      256
# 15            10  0.321082      0.891000  0.334669  0.886594       64
# 13            10  0.317294      0.889625  0.322137  0.891688      128
# 9             10  0.323350      0.888375  0.320613  0.890000       64
# 5             10  0.322759      0.888250  0.328162  0.890250       64
# 6             10  0.319459      0.887500  0.325117  0.890719      128
# 1             10  0.350608      0.886250  0.371882  0.877281       64
# 0             10  0.336040      0.886125  0.344987  0.884875       64
# 11            10  0.328732      0.883125  0.297502  0.898406       64
#
#     kernel_size optimizer
# 17            8     Nadam
# 16            4     Nadam
# 2             8     Nadam
# 10            8      Adam
# 14            5     Nadam
# 8             8      Adam
# 4             5     Nadam
# 7             4      Adam
# 12            5      Adam
# 3             5      Adam
# 15            8      Adam
# 13            4     Nadam
# 9             5     Nadam
# 5             4     Nadam
# 6             4      Adam
# 1             4      Adam
# 0             5      Adam
# 11            8     Nadam

# %% [markdown]
# The best combinations of hyperparameters provided by round 14, with validation accuracy equal about 97,7 %.

# %% [markdown]
# A four-dimensional bar grid for visualizing hyperparameters relationships

# %%
analyze_object = talos.Analyze(exp8)
analyze_object.plot_bars('kernel_size', 'val_accuracy', 'filters','optimizer')

# %%
#saving talos results
talos.Deploy(exp8, 'clf9', metric = 'val_accuracy')
# Out:
# Deploy package clf9 have been saved.

# %%
#restore talos results
talos.Restore('clf9')

# %% [markdown]
# According to Talos results, the best combinations of hyperparameters represented with Nadam optimizer, 256 filters and 8 kernel size with validation accuracy 89,90 %. Next, C-LSTM model was trained with selected best hyperparameters (except kernel size, which was checked by trial and error approach), 26 epochs and batch size equal to 128

# %%
random.seed(93)

model_CNN5 = Sequential()
model_CNN5.add(Embedding(vocab_size, 100, weights=[embedding_vectors], input_length=max_length, trainable=False))

model_CNN5.add(Dropout(0.3))
model_CNN5.add(Conv1D(filters=256, kernel_size = 5, activation='relu'))
model_CNN5.add(MaxPooling1D(pool_size=2))
model_CNN5.add(Dropout(0.3))

model_CNN5.add(LSTM(64,recurrent_dropout=0.15))

model_CNN5.add(Dropout(0.3))

model_CNN5.add(Dense(16, activation='relu'))

model_CNN5.add(Dense(num_classes, activation='softmax'))

print(model_CNN5.summary())


# compile network
model_CNN5.compile(loss = 'categorical_crossentropy', optimizer = 'Nadam', metrics = ['accuracy'])

start = time.time()
# fit network
history = model_CNN5.fit(Xtrain, ytrain, epochs = 26, batch_size = 128, verbose=1, validation_split = 0.2)


pd.DataFrame(history.history).plot(figsize=(10, 5))
plt.legend(loc=6, prop={'size': 7})
plt.grid(True)

elapsed = time.time() - start
print('\n Completed training in {} seconds.'.format(elapsed),end='\n\n')
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_16 (Embedding)     (None, 90, 100)           5320300
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 90, 100)           0
# _________________________________________________________________
# conv1d_15 (Conv1D)           (None, 86, 256)           128256
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, 43, 256)           0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 43, 256)           0
# _________________________________________________________________
# lstm_32 (LSTM)               (None, 64)                82176
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 16)                1040
# _________________________________________________________________
# dense_20 (Dense)             (None, 4)                 68
# =================================================================
# Total params: 5,531,840
# Trainable params: 211,540
# Non-trainable params: 5,320,300
# _________________________________________________________________
# None
# Train on 32000 samples, validate on 8000 samples
# Epoch 1/26
# 32000/32000 [==============================] - 92s 3ms/step - loss: 0.7208 - accuracy: 0.6923 - val_loss: 0.4323 - val_accuracy: 0.8586
# Epoch 2/26
# 32000/32000 [==============================] - 90s 3ms/step - loss: 0.4099 - accuracy: 0.8668 - val_loss: 0.3529 - val_accuracy: 0.8814
# Epoch 3/26
# 32000/32000 [==============================] - 91s 3ms/step - loss: 0.3721 - accuracy: 0.8768 - val_loss: 0.3348 - val_accuracy: 0.8869
# Epoch 4/26
# 32000/32000 [==============================] - 91s 3ms/step - loss: 0.3503 - accuracy: 0.8824 - val_loss: 0.3281 - val_accuracy: 0.8854
# Epoch 5/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.3346 - accuracy: 0.8867 - val_loss: 0.3170 - val_accuracy: 0.8915
# Epoch 6/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.3232 - accuracy: 0.8900 - val_loss: 0.3047 - val_accuracy: 0.8915
# Epoch 7/26
# 32000/32000 [==============================] - 90s 3ms/step - loss: 0.3080 - accuracy: 0.8950 - val_loss: 0.2962 - val_accuracy: 0.8938
# Epoch 8/26
# 32000/32000 [==============================] - 98s 3ms/step - loss: 0.2985 - accuracy: 0.8977 - val_loss: 0.2882 - val_accuracy: 0.8982
# Epoch 9/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2914 - accuracy: 0.8986 - val_loss: 0.2835 - val_accuracy: 0.9001
# Epoch 10/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2822 - accuracy: 0.9026 - val_loss: 0.2790 - val_accuracy: 0.8991
# Epoch 11/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2723 - accuracy: 0.9056 - val_loss: 0.2880 - val_accuracy: 0.8979
# Epoch 12/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2672 - accuracy: 0.9078 - val_loss: 0.2854 - val_accuracy: 0.8961
# Epoch 13/26
# 32000/32000 [==============================] - 87s 3ms/step - loss: 0.2592 - accuracy: 0.9097 - val_loss: 0.2751 - val_accuracy: 0.8999
# Epoch 14/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2478 - accuracy: 0.9133 - val_loss: 0.2737 - val_accuracy: 0.9026
# Epoch 15/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2489 - accuracy: 0.9134 - val_loss: 0.2850 - val_accuracy: 0.8997
# Epoch 16/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2421 - accuracy: 0.9167 - val_loss: 0.2707 - val_accuracy: 0.9032
# Epoch 17/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2387 - accuracy: 0.9162 - val_loss: 0.2705 - val_accuracy: 0.9032
# Epoch 18/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2321 - accuracy: 0.9187 - val_loss: 0.2677 - val_accuracy: 0.9043
# Epoch 19/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2256 - accuracy: 0.9225 - val_loss: 0.2725 - val_accuracy: 0.9046
# Epoch 20/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2212 - accuracy: 0.9216 - val_loss: 0.2808 - val_accuracy: 0.9015
# Epoch 21/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2175 - accuracy: 0.9235 - val_loss: 0.2774 - val_accuracy: 0.9036
# Epoch 22/26
# 32000/32000 [==============================] - 87s 3ms/step - loss: 0.2158 - accuracy: 0.9251 - val_loss: 0.2764 - val_accuracy: 0.9015
# Epoch 23/26
# 32000/32000 [==============================] - 89s 3ms/step - loss: 0.2097 - accuracy: 0.9263 - val_loss: 0.2659 - val_accuracy: 0.9045
# Epoch 24/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2044 - accuracy: 0.9288 - val_loss: 0.2859 - val_accuracy: 0.9053
# Epoch 25/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.2037 - accuracy: 0.9279 - val_loss: 0.2812 - val_accuracy: 0.9044
# Epoch 26/26
# 32000/32000 [==============================] - 88s 3ms/step - loss: 0.1978 - accuracy: 0.9314 - val_loss: 0.2673 - val_accuracy: 0.9056
#
#  Completed training in 2316.2732326984406 seconds.

# %%
#loading the model
#model_CNN5 = keras.models.load_model('model_CNN8.h5')

# %% [markdown]
# Finally, applying the trained model on the test dataset, the accuracy score 91.47% has been achieved

# %%
# evaluate the model
loss, acc = model_CNN5.evaluate(Xtest, ytest, verbose=0)
print('Test Accuracy: %f' % (acc*100))
# Out:
# Test Accuracy: 91.474998

# %%
#saving the model
#model_CNN5.save('model_CNN8.h5')
